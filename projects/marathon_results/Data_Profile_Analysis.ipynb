# %% [markdown]
# # Data Profile Analysis
#
# This notebook analyzes and profiles files stored in the `temp_page_cache` and `race_results` directories.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np
import csv
import os
import json
from pathlib import Path
from collections import defaultdict
import warnings

# Disable PyArrow string type to avoid extension type conflicts
pd.options.mode.string_storage = "python"
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## 2. Load Data from temp_page_cache

# %%
temp_cache_path = "/Users/thatcher/dev/analysis/projects/marathon_results/temp_page_cache"

# Explore temp_page_cache directory structure
if os.path.exists(temp_cache_path):
    print(f"temp_page_cache directory exists")
    print(f"Total items: {len(os.listdir(temp_cache_path))}\n")
    
    # List first 20 items
    items = os.listdir(temp_cache_path)[:20]
    for item in items:
        item_path = os.path.join(temp_cache_path, item)
        if os.path.isdir(item_path):
            print(f"[DIR]  {item} - {len(os.listdir(item_path))} items")
        else:
            size = os.path.getsize(item_path)
            print(f"[FILE] {item} - {size:,} bytes")
else:
    print("temp_page_cache directory not found")
# Out:
# temp_page_cache directory exists
# Total items: 1851
#
# [DIR]  earth_day_challenge_marathon - 4 items
# [DIR]  black_bear_marathon - 3 items
# [DIR]  jackson_river_scenic_trail_marathon - 4 items
# [DIR]  indian - 1 items
# [DIR]  az_legs_for_literacy_marathon - 1 items
# [DIR]  steamboat_marathon - 23 items
# [DIR]  mooathon - 7 items
# [DIR]  olympics_2000_(women) - 1 items
# [DIR]  rutland_marathon - 4 items
# [DIR]  rust_buster_marathon - 1 items
# [DIR]  nesbit_park_trails_classic - 1 items
# [DIR]  belfast_city_marathon - 19 items
# [DIR]  marathon-to-marathon - 18 items
# [DIR]  the_instant_classic_marathon_trail_run - 7 items
# [DIR]  beaver_canyon_marathon,_half_marathon_and_10k - 2 items
# [DIR]  zoom!_yah!_yah!_indoor_marathon - 15 items
# [DIR]  naked_prussian - 3 items
# [DIR]  resurgo_marathon - 1 items
# [DIR]  mountain_marathon - 9 items
# [DIR]  mid-atlantic_cross_country_challenge - 1 items

# %% [markdown]
# ## 3. Load Data from race_results

# %%
race_results_path = "/Users/thatcher/dev/analysis/projects/marathon_results/race_results"

# Explore race_results directory structure
if os.path.exists(race_results_path):
    print(f"race_results directory exists")
    items = os.listdir(race_results_path)
    print(f"Total items: {len(items)}\n")
    
    # Analyze file types and sizes
    file_types = defaultdict(list)
    total_size = 0
    
    for item in items:
        item_path = os.path.join(race_results_path, item)
        if os.path.isfile(item_path):
            ext = os.path.splitext(item)[1] or "no_extension"
            size = os.path.getsize(item_path)
            file_types[ext].append((item, size))
            total_size += size
    
    print(f"Total size: {total_size:,} bytes ({total_size / (1024**2):.2f} MB)\n")
    print("File types:")
    for ext, files in sorted(file_types.items()):
        print(f"  {ext}: {len(files)} files")
    
    # Show sample files
    print("\nSample files:")
    for item in sorted(items)[:10]:
        item_path = os.path.join(race_results_path, item)
        if os.path.isfile(item_path):
            size = os.path.getsize(item_path)
            print(f"  {item} - {size:,} bytes")
else:
    print("race_results directory not found")
# Out:
# race_results directory exists
# Total items: 1836
#
# Total size: 420,714,492 bytes (401.22 MB)
#
# File types:
#   .parquet: 1836 files
#
# Sample files:
#   "last_chance_for_boston"_marathon.parquet - 52,370 bytes
#   "running_for_the_bay!"_marathon.parquet - 51,394 bytes
#   11-11-11_marathon_of_sarasota.parquet - 10,437 bytes
#   2004_usa_olympic_team_trials_-_men's_marathon.parquet - 10,253 bytes
#   2004_usa_olympic_team_trials_-_women's_marathon.parquet - 12,478 bytes
#   2008_u.s._olympic_team_trials_-_men's_marathon.parquet - 12,305 bytes
#   2012_u.s._olympic_team_trials_-_men's_marathon.parquet - 11,288 bytes
#   2012_u.s._olympic_team_trials_-_women's_marathon.parquet - 14,866 bytes
#   2014_commonwealth_games_marathon_-_men.parquet - 7,004 bytes
#   2014_commonwealth_games_marathon_-_women.parquet - 6,831 bytes

# %% [markdown]
# ## 4. Profile race_results Data

# %%
# Load and analyze parquet files from race_results
parquet_files = [f for f in os.listdir(race_results_path) if f.endswith('.parquet')]

print(f"Total parquet files: {len(parquet_files)}\n")

# Profile first few files
profile_data = []
for i, filename in enumerate(sorted(parquet_files)[:5]):
    try:
        filepath = os.path.join(race_results_path, filename)
        df = pd.read_parquet(filepath)
        
        profile_info = {
            'filename': filename,
            'rows': df.shape[0],
            'columns': df.shape[1],
            'column_names': list(df.columns),
            'dtypes': df.dtypes.to_dict(),
            'memory_usage_mb': df.memory_usage(deep=True).sum() / (1024**2),
            'missing_values': df.isnull().sum().to_dict()
        }
        profile_data.append(profile_info)
        
        print(f"File: {filename}")
        print(f"  Shape: {df.shape[0]} rows × {df.shape[1]} columns")
        print(f"  Memory usage: {profile_info['memory_usage_mb']:.2f} MB")
        print(f"  Columns: {', '.join(df.columns[:5])}{'...' if df.shape[1] > 5 else ''}")
        print()
    except Exception as e:
        print(f"Error reading {filename}: {str(e)}\n")
# Out:
# Total parquet files: 1836
#
# File: "last_chance_for_boston"_marathon.parquet
#   Shape: 1402 rows × 13 columns
#   Memory usage: 0.93 MB
#   Columns: Last Name, First Name (Sex/Age), Time, OverAllPlace, Sex Place/Div Place, DIV...
#
# File: "running_for_the_bay!"_marathon.parquet
#   Shape: 1279 rows × 12 columns
#   Memory usage: 0.82 MB
#   Columns: Last Name, First Name (Sex/Age), Time, OverAllPlace, Sex Place/Div Place, DIV...
#
# File: 11-11-11_marathon_of_sarasota.parquet
#   Shape: 66 rows × 9 columns
#   Memory usage: 0.03 MB
#   Columns: Last Name, First Name (Sex/Age), Time, OverAllPlace, Sex Place, City, State, Country...
#
# File: 2004_usa_olympic_team_trials_-_men's_marathon.parquet
#   Shape: 71 rows × 9 columns
#   Memory usage: 0.04 MB
#   Columns: Last Name, First Name (Sex/Age), Time, OverAllPlace, Sex Place, City, State, Country...
#
# File: 2004_usa_olympic_team_trials_-_women's_marathon.parquet
#   Shape: 200 rows × 9 columns
#   Memory usage: 0.10 MB
#   Columns: Last Name, First Name (Sex/Age), Time, OverAllPlace, Sex Place, City, State, Country...
#
# File: "last_chance_for_boston"_marathon.parquet
#   Shape: 1402 rows × 13 columns
#   Memory usage: 0.93 MB
#   Columns: Last Name, First Name (Sex/Age), Time, OverAllPlace, Sex Place/Div Place, DIV...
#
# File: "running_for_the_bay!"_marathon.parquet
#   Shape: 1279 rows × 12 columns
#   Memory usage: 0.82 MB
#   Columns: Last Name, First Name (Sex/Age), Time, OverAllPlace, Sex Place/Div Place, DIV...
#
# File: 11-11-11_marathon_of_sarasota.parquet
#   Shape: 66 rows × 9 columns
#   Memory usage: 0.03 MB
#   Columns: Last Name, First Name (Sex/Age), Time, OverAllPlace, Sex Place, City, State, Country...
#
# File: 2004_usa_olympic_team_trials_-_men's_marathon.parquet
#   Shape: 71 rows × 9 columns
#   Memory usage: 0.04 MB
#   Columns: Last Name, First Name (Sex/Age), Time, OverAllPlace, Sex Place, City, State, Country...
#
# File: 2004_usa_olympic_team_trials_-_women's_marathon.parquet
#   Shape: 200 rows × 9 columns
#   Memory usage: 0.10 MB
#   Columns: Last Name, First Name (Sex/Age), Time, OverAllPlace, Sex Place, City, State, Country...

# %% [markdown]
# ## 5. Generate Summary Statistics

# %%
# Generate comprehensive summary statistics
print("=" * 60)
print("RACE RESULTS SUMMARY")
print("=" * 60)

# Overall statistics
total_parquet_files = len(parquet_files)
total_races = len(os.listdir(race_results_path))

print(f"\nDirectory Statistics:")
print(f"  Total items: {total_races}")
print(f"  Parquet files: {total_parquet_files}")

# Load all files and aggregate statistics
column_concordance = defaultdict(int)
total_rows = 0
total_cols = 0

for race_file in parquet_files[:50]:  # Sample first 50 files
    try:
        filepath = os.path.join(race_results_path, race_file)
        df = pd.read_parquet(filepath)
        
        total_rows += df.shape[0]
        total_cols += df.shape[1]
        
        for col in df.columns:
            column_concordance[col] += 1
    except Exception as e:
        pass

print(f"\nAggregated Statistics (from sample):")
print(f"  Total rows analyzed: {total_rows:,}")
print(f"  Average columns per file: {total_cols / max(1, len(parquet_files[:50])):.1f}")

print(f"\nMost Common Columns:")
sorted_cols = sorted(column_concordance.items(), key=lambda x: x[1], reverse=True)
for col, count in sorted_cols[:10]:
    print(f"  {col}: {count} files")
# Out:
# ============================================================
# RACE RESULTS SUMMARY
# ============================================================
#
# Directory Statistics:
#   Total items: 1836
#   Parquet files: 1836
#
# Aggregated Statistics (from sample):
#   Total rows analyzed: 567,778
#   Average columns per file: 10.6
#
# Most Common Columns:
#   Last Name, First Name (Sex/Age): 50 files
#   OverAllPlace: 50 files
#   date: 50 files
#   race: 50 files
#   Time: 49 files
#   BQ*: 44 files
#   AG Time*: 43 files
#   Sex Place/Div Place: 39 files
#   DIV: 39 files
#   City, State, Country: 35 files
#
# Aggregated Statistics (from sample):
#   Total rows analyzed: 567,778
#   Average columns per file: 10.6
#
# Most Common Columns:
#   Last Name, First Name (Sex/Age): 50 files
#   OverAllPlace: 50 files
#   date: 50 files
#   race: 50 files
#   Time: 49 files
#   BQ*: 44 files
#   AG Time*: 43 files
#   Sex Place/Div Place: 39 files
#   DIV: 39 files
#   City, State, Country: 35 files

# %% [markdown]
# # Approach
#
# Data Manipulation
# -----------------
# The end goal is to get a feature set of run descriptor (age, sex), home (city, state), outcome (time), event descriptors (race, date), and weather conditioners (total rainfall, weekend rainfall, last month rainfall, temperature, etc.).
#
# Along the way rows (and races) will have to be filtered.  I would like to keep a record of this in some way, to examine the results for bias.  As a goal, each operation that results in a filtering should output metadata on what is filtered (number of rows, reason, from what file/race/record).
#
# Steps
# -----
# 1) Iterate through race files, determine for each how to extract (age, sex, time, race, date, city, state)
# 2) Determine mapping of city, state -> OrderedList(weather stations) to use for weather data
# 3) Featurize weather data to (weather station) -> List(weather conditioners)
# 4) Join the data together to get starting data frame
#
#
# Research
# --------
# Once we have the data manipulated into a form that is able to be researched, the goal is to explore a number of questions related to how, for a given runner, the weather in their "home town" before a race affects their race results.  And then some extra details around that, like "toughest" town, race with toughest runners, difference in age/sex on whether people are affected by weather

# %% [markdown]
# ## 1) Iterate through race files, determine for each how to extract (age, sex, time, race, date, city, state)

# %%
processed_race_files = set()

race_records_home = "/Users/thatcher/dev/analysis/projects/marathon_results/data/race_records"
race_records_skipped = "/Users/thatcher/dev/analysis/projects/marathon_results/data/race_records_skipped.csv"
## Helper Functions
def extract_age(name_string):
    """
    Extract age from formats like:
      - "Smith, John (M/45)" -> age = 45
      - "Smith, John (M45)" -> age = 45
    Returns the age as integer, or None if not found
    """
    try:
        if pd.isna(name_string):
            return None
        
        name_str = str(name_string)
        
        # Find content within parentheses
        if '(' not in name_str or ')' not in name_str:
            return None
        
        # Extract content between ( and )
        paren_content = name_str[name_str.find('(') + 1 : name_str.find(')')]
        
        # Handle both formats: "M/45" and "M45"
        if '/' in paren_content:
            # Format: (Sex/Age)
            age_part = paren_content.split('/')[-1].strip()
        else:
            # Format: (SexAge) - extract just the numeric part
            age_part = ''.join(c for c in paren_content if c.isdigit())
        
        if age_part:
            return int(age_part)
            
    except (ValueError, AttributeError, IndexError):
        return None
    return None
        
def extract_sex(name_string):
    """
    Extract sex from formats like:
      - "Smith, John (M/45)" -> sex = M
      - "Smith, John (M45)" -> sex = M
    Returns the sex as string, or None if not found
    """
    try:
        if pd.isna(name_string):
            return None
        
        name_str = str(name_string)
        
        # Find content within parentheses
        if '(' not in name_str or ')' not in name_str:
            return None
        
        # Extract content between ( and )
        paren_content = name_str[name_str.find('(') + 1 : name_str.find(')')]
        
        # Handle both formats: "M/45" and "M45"
        if '/' in paren_content:
            # Format: (Sex/Age)
            sex_part = paren_content.split('/')[0].strip()
        else:
            # Format: (SexAge) - extract just the non-numeric part
            sex_part = ''.join(c for c in paren_content if not c.isdigit()).strip()
        
        if sex_part:
            return sex_part
            
    except (ValueError, AttributeError, IndexError):
        return None
    return None

def extract_city(location_string):
    """
    Extract city from format like: "City, State, Country"
    Returns the city as string, or None if not found
    """
    try:
        if pd.isna(location_string):
            return None
        return location_string.split(",")[0].strip()
    except (ValueError, AttributeError, IndexError):
        return None
    return None

def extract_state(location_string):
    """
    Extract state from format like: "City, State, Country"
    Returns the state as string, or None if not found
    """
    try:
        if pd.isna(location_string):
            return None
        return location_string.split(",")[1].strip()
    except (ValueError, AttributeError, IndexError):
        return None
    return None

skipped_races = set()
with open(race_records_skipped,'r') as handle:
    reader = csv.DictReader(handle)
    skipped_races = set([r["race_file"] for r in reader])

for race_file in parquet_files:
    if race_file in skipped_races:
        print(f"Skipping {race_file}, reason in {race_records_skipped}")
        continue 

    output_path = os.path.join(race_records_home, race_file)
    if os.path.exists(output_path):
        print(f"Skipping {race_file}, already exists in output")
        continue

    filepath = os.path.join(race_results_path, race_file)
    df = pd.read_parquet(filepath)
    
    record_column_vectors = {
        "age":None,
        "sex":None,
        "time":None,
        "race":None,
        "date":None,
        "city":None,
        "state":None
    }
    
    # Extract age from 'Last Name, First Name (Sex/Age)' column
    if 'Last Name, First Name (Sex/Age)' in df.columns:
        record_column_vectors["age"] = df['Last Name, First Name (Sex/Age)'].apply(extract_age)
        record_column_vectors["sex"] = df['Last Name, First Name (Sex/Age)'].apply(extract_sex)
    
    if "Time" in df.columns:
        record_column_vectors["time"] = df['Time']
        # todo: ensure that time is reported in a standard way
    elif "Net Time" in df.columns:
        record_column_vectors["time"] = df['Net Time']
    
    if "race" in df.columns:
        record_column_vectors["race"] = df['race']
    if "date" in df.columns:
        record_column_vectors["date"] = df['date']
    
    if 'City, State, Country' in df.columns:
        record_column_vectors["city"] = df['City, State, Country'].apply(extract_city)
        record_column_vectors["state"] = df['City, State, Country'].apply(extract_state)
    elif 'City, State' in df.columns:
        record_column_vectors["city"] = df['City, State'].apply(extract_city)
        record_column_vectors["state"] = df['City, State'].apply(extract_state)

    unmappable_attributes = set([k for k,v in record_column_vectors.items() if v is None])
    if len(unmappable_attributes) > 0:
        error = f"missing attributs: {unmappable_attributes}, available columns: {df.columns}"
        print(f"Unable to process file: {race_file}")
        print(f" {error}")
        with open(race_records_skipped,'a') as w_handle:
            writer = csv.writer(w_handle)
            writer.writerow([race_file, len(df), error])
        
        if len(df) > 100000:
            raise Exception("Check, missed big race")
    
    # Create DataFrame from column vectors
    record_frame = pd.DataFrame(record_column_vectors,
                                columns = record_column_vectors.keys())
    record_frame.to_parquet(output_path)
    
    print(f"Processed: {race_file}")
    print(f"  Records: {len(record_frame)}")
    print(f"  Shape: {record_frame.shape}")
    print(f"  Sample:\n{record_frame.head(3)}\n")
# Out:
# Processed: dog_lake_marathon.parquet
#   Records: 189
#   Shape: (189, 7)
#   Sample:
#     age sex     time               race      date             city state
# 0  50.0   M  3:01:39  dog_lake_marathon  10_15_16  Apache Junction    AZ
# 1  39.0   M  3:08:34  dog_lake_marathon  10_15_16        Kennewick    WA
# 2  27.0   M  3:16:29  dog_lake_marathon  10_15_16           Yakima    WA
#
# Skipping georgina_spring_fling_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: pacific_crest_marathon.parquet
#   Records: 2903
#   Shape: (2903, 7)
#   Sample:
#     age sex     time                    race     date   city state
# 0  27.0   M  2:37:45  pacific_crest_marathon  6_29_02   Bend    OR
# 1  33.0   M  2:55:30  pacific_crest_marathon  6_29_02   Bend    OR
# 2  37.0   M  2:59:20  pacific_crest_marathon  6_29_02  Salem    OR
#
# Processed: nebraska_marathon.parquet
#   Records: 558
#   Shape: (558, 7)
#   Sample:
#     age sex     time               race      date          city state
# 0  39.0   M  3:46:08  nebraska_marathon  10_14_18         Omaha    NE
# 1  46.0   M  3:49:25  nebraska_marathon  10_14_18   Sun Prairie    WI
# 2  45.0   M  3:49:25  nebraska_marathon  10_14_18  Grand Island    NE
#
# Skipping olympics_2020_(women).parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: las_vegas_deja_vu_marathon.parquet
#   Records: 27
#   Shape: (27, 7)
#   Sample:
#    age sex     time                        race      date city state
# 0   44   M  3:18:26  las_vegas_deja_vu_marathon  11_28_15  NaN   NaN
# 1   52   M  3:38:12  las_vegas_deja_vu_marathon  11_28_15  NaN   NaN
# 2   37   F  3:42:32  las_vegas_deja_vu_marathon  11_28_15  NaN   NaN
#
# Processed: bellingham_bay_marathon.parquet
#   Records: 4700
#   Shape: (4700, 7)
#   Sample:
#     age sex     time                     race     date city state
# 0  30.0   F  3:52:40  bellingham_bay_marathon  9_25_11  NaN   NaN
# 1  48.0   F  3:52:40  bellingham_bay_marathon  9_25_11  NaN   NaN
# 2  19.0   M  3:52:42  bellingham_bay_marathon  9_25_11  NaN   NaN
#
# Processed: central_park_marathon.parquet
#   Records: 1200
#   Shape: (1200, 7)
#   Sample:
#     age sex     time                   race     date             city state
# 0  39.0   M  3:44:24  central_park_marathon  2_23_14  JACKSON HEIGHTS    NY
# 1  27.0   F  3:44:35  central_park_marathon  2_23_14         LANSDALE    PA
# 2  23.0   F  3:44:37  central_park_marathon  2_23_14     WHITE PLAINS    NY
#
# Processed: california_wine_country_marathon.parquet
#   Records: 900
#   Shape: (900, 7)
#   Sample:
#    age sex     time                              race      date        city  \
# 0   43   M  4:31:02  california_wine_country_marathon  10_10_10  Santa Rosa
# 1   49   F  4:31:43  california_wine_country_marathon  10_10_10  Santa Rosa
# 2   28   M  4:32:52  california_wine_country_marathon  10_10_10   Pittsburg
#
#   state
# 0    CA
# 1    CA
# 2    CA
#
# Processed: sogonapmit_marathon.parquet
#   Records: 353
#   Shape: (353, 7)
#   Sample:
#     age sex     time                 race     date city state
# 0  37.0   F  3:51:23  sogonapmit_marathon  7_27_13  NaN   NaN
# 1  46.0   M  3:51:29  sogonapmit_marathon  7_27_13  NaN   NaN
# 2  20.0   M  3:52:45  sogonapmit_marathon  7_27_13  NaN   NaN
#
# Processed: rivanna_greenbelt_october__marathon.parquet
#   Records: 7
#   Shape: (7, 7)
#   Sample:
#    age sex     time                                 race     date  \
# 0   28   M  2:30:13  rivanna_greenbelt_october__marathon  10_4_14
# 1   25   M  2:59:20  rivanna_greenbelt_october__marathon  10_4_14
# 2   31   M  3:16:31  rivanna_greenbelt_october__marathon  10_4_14
#
#               city state
# 0         Danville    VA
# 1  Charlottesville    VA
# 2     Williamsburg    VA
#
# Processed: bemidji_blue_ox_marathon.parquet
#   Records: 2000
#   Shape: (2000, 7)
#   Sample:
#    age sex     time                      race      date          city state
# 0   44   M  3:45:56  bemidji_blue_ox_marathon  10_14_17       Scandia    MN
# 1   41   M  3:46:00  bemidji_blue_ox_marathon  10_14_17  Eden Prairie    MN
# 2   48   M  3:47:04  bemidji_blue_ox_marathon  10_14_17      Winnipeg   NaN
#
# Processed: alaska_series_-_day_3.parquet
#   Records: 59
#   Shape: (59, 7)
#   Sample:
#     age sex     time                   race     date         city state
# 0   NaN   F  5:03:50  alaska_series_-_day_3  7_27_23                NaN
# 1  56.0   M  5:24:12  alaska_series_-_day_3  7_27_23  Kents Store    VA
# 2   NaN   F  5:30:35  alaska_series_-_day_3  7_27_23                NaN
#
# Processed: mount_desert_island_marathon.parquet
#   Records: 13699
#   Shape: (13699, 7)
#   Sample:
#     age sex     time                          race      date        city state
# 0  29.0   M  3:35:57  mount_desert_island_marathon  10_16_11  Titusville    FL
# 1  46.0   M  3:36:02  mount_desert_island_marathon  10_16_11     Chester    NH
# 2  44.0   F  3:36:22  mount_desert_island_marathon  10_16_11   Littleton    MA
#
# Processed: missoula_marathon.parquet
#   Records: 14482
#   Shape: (14482, 7)
#   Sample:
#     age sex     time               race     date         city state
# 0  44.0   M  3:52:22  missoula_marathon  7_15_07   Northville    MI
# 1  53.0   M  3:52:41  missoula_marathon  7_15_07     Missoula    MT
# 2  25.0   M  3:53:14  missoula_marathon  7_15_07  Grand Blanc    MI
#
# Skipping abingdon_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping morgan_hill_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: dust_bowl_series_marathon_-_kansas.parquet
#   Records: 389
#   Shape: (389, 7)
#   Sample:
#     age sex     time                                race     date     city  \
# 0  36.0   M  3:17:59  dust_bowl_series_marathon_-_kansas  3_24_17  Madison
# 1  46.0   M  3:47:41  dust_bowl_series_marathon_-_kansas  3_24_17   Warren
# 2  51.0   F  4:24:58  dust_bowl_series_marathon_-_kansas  3_24_17   Conway
#
#   state
# 0    AL
# 1    PA
# 2    AR
#
# Processed: spring_chance_bq.2_marathon_-_sunday.parquet
#   Records: 200
#   Shape: (200, 7)
#   Sample:
#    age sex     time                                  race     date  \
# 0   32   M  2:59:45  spring_chance_bq.2_marathon_-_sunday  4_18_21
# 1   40   M  3:00:03  spring_chance_bq.2_marathon_-_sunday  4_18_21
# 2   41   M  3:01:02  spring_chance_bq.2_marathon_-_sunday  4_18_21
#
#             city state
# 0     Naperville    IL
# 1  San Francisco    CA
# 2        Hammond    IN
#
# Processed: chosen:_marathon_for_adoption.parquet
#   Records: 1000
#   Shape: (1000, 7)
#   Sample:
#    age sex     time                           race      date     city state
# 0  NaN   M  4:33:09  chosen:_marathon_for_adoption  10_25_14  Houston    TX
# 1  NaN   F  4:33:23  chosen:_marathon_for_adoption  10_25_14   Temple    TX
# 2  NaN   M  4:33:33  chosen:_marathon_for_adoption  10_25_14   Austin    TX
#
# Skipping turkey_track_trail_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: california_international_marathon.parquet
#   Records: 111870
#   Shape: (111870, 7)
#   Sample:
#     age sex     time                               race     date        city  \
# 0  32.0   F  3:28:05  california_international_marathon  12_8_19  Greenville
# 1  51.0   F  3:28:06  california_international_marathon  12_8_19      Folsom
# 2  53.0   M  3:28:07  california_international_marathon  12_8_19      novato
#
#   state
# 0    SC
# 1    CA
# 2    CA
#
# Processed: haulin'_aspen_trail_marathon.parquet
#   Records: 2434
#   Shape: (2434, 7)
#   Sample:
#     age sex     time                          race     date       city state
# 0  38.0   F  4:02:16  haulin'_aspen_trail_marathon  8_13_06  Sammamish    WA
# 1  40.0   F  4:05:09  haulin'_aspen_trail_marathon  8_13_06   Portland    OR
# 2  46.0   M  4:05:13  haulin'_aspen_trail_marathon  8_13_06      Sandy    OR
#
# Processed: horse_capital_marathon.parquet
#   Records: 2000
#   Shape: (2000, 7)
#   Sample:
#    age sex     time                    race     date         city state
# 0   32   M  4:18:54  horse_capital_marathon  4_15_23  Paintsville    KY
# 1   58   M  4:18:32  horse_capital_marathon  4_15_23      Detroit    MI
# 2   17   F  4:19:58  horse_capital_marathon  4_15_23    Lexington    KY
#
# Processed: california_international_marathon.parquet
#   Records: 111870
#   Shape: (111870, 7)
#   Sample:
#     age sex     time                               race     date        city  \
# 0  32.0   F  3:28:05  california_international_marathon  12_8_19  Greenville
# 1  51.0   F  3:28:06  california_international_marathon  12_8_19      Folsom
# 2  53.0   M  3:28:07  california_international_marathon  12_8_19      novato
#
#   state
# 0    SC
# 1    CA
# 2    CA
#
# Processed: haulin'_aspen_trail_marathon.parquet
#   Records: 2434
#   Shape: (2434, 7)
#   Sample:
#     age sex     time                          race     date       city state
# 0  38.0   F  4:02:16  haulin'_aspen_trail_marathon  8_13_06  Sammamish    WA
# 1  40.0   F  4:05:09  haulin'_aspen_trail_marathon  8_13_06   Portland    OR
# 2  46.0   M  4:05:13  haulin'_aspen_trail_marathon  8_13_06      Sandy    OR
#
# Processed: horse_capital_marathon.parquet
#   Records: 2000
#   Shape: (2000, 7)
#   Sample:
#    age sex     time                    race     date         city state
# 0   32   M  4:18:54  horse_capital_marathon  4_15_23  Paintsville    KY
# 1   58   M  4:18:32  horse_capital_marathon  4_15_23      Detroit    MI
# 2   17   F  4:19:58  horse_capital_marathon  4_15_23    Lexington    KY
#
# Processed: disney_world_marathon.parquet
#   Records: 290029
#   Shape: (290029, 7)
#   Sample:
#     age sex     time                   race    date city state
# 0  30.0   M  4:28:12  disney_world_marathon  1_6_02  NaN   NaN
# 1  40.0   F  4:28:13  disney_world_marathon  1_6_02  NaN   NaN
# 2  45.0   M  4:28:14  disney_world_marathon  1_6_02  NaN   NaN
#
# Skipping eden_project_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: new_england_series_-_ri.parquet
#   Records: 408
#   Shape: (408, 7)
#   Sample:
#     age sex     time                     race     date           city  state
# 0  33.0   M  3:59:01  new_england_series_-_ri  6_25_19            Lee     NH
# 1  34.0   M  4:04:52  new_england_series_-_ri  6_25_19  Cottage Grove     WI
# 2  51.0   M  4:05:48  new_england_series_-_ri  6_25_19        Beijing  China
#
# Processed: leading_ladies'_marathon.parquet
#   Records: 2526
#   Shape: (2526, 7)
#   Sample:
#    age sex     time                      race     date city state
# 0  NaN   F  3:54:08  leading_ladies'_marathon  8_17_14  NaN   NaN
# 1  NaN   F  3:55:34  leading_ladies'_marathon  8_17_14  NaN   NaN
# 2  NaN   F  3:56:20  leading_ladies'_marathon  8_17_14  NaN   NaN
#
# Processed: porcupine_mountains_trail_marathon.parquet
#   Records: 170
#   Shape: (170, 7)
#   Sample:
#     age sex     time                                race     date  \
# 0  None   M  4:00:06  porcupine_mountains_trail_marathon  9_20_14
# 1  None   M  4:12:09  porcupine_mountains_trail_marathon  9_20_14
# 2  None   M  4:27:39  porcupine_mountains_trail_marathon  9_20_14
#
#           city state
# 0     Houghton    MI
# 1       Wausau    WI
# 2  Grand Haven    MI
#
# Skipping nagoya_int'l_women's_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: run_for_the_ranch_marathon.parquet
#   Records: 1917
#   Shape: (1917, 7)
#   Sample:
#    age sex     time                        race      date       city state
# 0   35   M  2:48:12  run_for_the_ranch_marathon  12_31_06   Columbus    OH
# 1   33   M  2:55:16  run_for_the_ranch_marathon  12_31_06    Fremont    NE
# 2   30   M  3:07:42  run_for_the_ranch_marathon  12_31_06  Arlington    VA
#
# Skipping loch_ness_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: rock_'n'_roll_country_music_marathon.parquet
#   Records: 18495
#   Shape: (18495, 7)
#   Sample:
#    age sex     time                                  race     date city state
# 0  NaN   F  5:28:07  rock_'n'_roll_country_music_marathon  4_30_16  NaN   NaN
# 1  NaN   M  5:28:08  rock_'n'_roll_country_music_marathon  4_30_16  NaN   NaN
# 2  NaN   F  5:28:11  rock_'n'_roll_country_music_marathon  4_30_16  NaN   NaN
#
# Processed: first_call_spring_marathon.parquet
#   Records: 58
#   Shape: (58, 7)
#   Sample:
#    age sex     time                        race     date       city state
# 0   29   F  3:16:49  first_call_spring_marathon  5_11_13    Redmond    WA
# 1   32   M  3:29:29  first_call_spring_marathon  5_11_13  Beaverton    OR
# 2   41   M  3:41:41  first_call_spring_marathon  5_11_13     Auburn    WA
#
# Processed: first_day_of_winter_marathon.parquet
#   Records: 26
#   Shape: (26, 7)
#   Sample:
#    age sex     time                          race      date          city  \
# 0   40   M  3:44:07  first_day_of_winter_marathon  12_20_15      Hilliard
# 1   40   M  4:06:31  first_day_of_winter_marathon  12_20_15      Wellston
# 2   43   F  4:40:03  first_day_of_winter_marathon  12_20_15  Lake Village
#
#   state
# 0    OH
# 1    OH
# 2    IN
#
# Skipping run_barbados_marathon_weekend.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: meridian_marathon,_leo_run_to_remember.parquet
#   Records: 255
#   Shape: (255, 7)
#   Sample:
#    age sex     time                                    race      date  \
# 0   39   M  2:55:10  meridian_marathon,_leo_run_to_remember  11_15_14
# 1   34   M  3:11:59  meridian_marathon,_leo_run_to_remember  11_15_14
# 2   35   M  3:18:51  meridian_marathon,_leo_run_to_remember  11_15_14
#
#         city state
# 0  Niceville    FL
# 1    Tuscola    TX
# 2     Oxford    MS
#
# Processed: grand_rapids_marathon.parquet
#   Records: 22400
#   Shape: (22400, 7)
#   Sample:
#     age sex     time                   race      date        city state
# 0  29.0   M  3:16:23  grand_rapids_marathon  10_16_11    Rockford    MI
# 1  34.0   M  3:16:58  grand_rapids_marathon  10_16_11     Lansing    MI
# 2  23.0   M  3:17:10  grand_rapids_marathon  10_16_11  Farmington    MI
#
# Skipping hot_mama!_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: nebraska_state_fair_marathon.parquet
#   Records: 1426
#   Shape: (1426, 7)
#   Sample:
#    age sex     time                          race     date city state
# 0  NaN   F  3:44:18  nebraska_state_fair_marathon  8_26_23  NaN   NaN
# 1  NaN   F  3:45:54  nebraska_state_fair_marathon  8_26_23  NaN   NaN
# 2  NaN   F  3:46:16  nebraska_state_fair_marathon  8_26_23  NaN   NaN
#
# Skipping smoky_mountain_left_turn_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: rock_creek_park_marathon_and_relay.parquet
#   Records: 81
#   Shape: (81, 7)
#   Sample:
#     age sex     time                                race      date  \
# 0  33.0   M  3:06:24  rock_creek_park_marathon_and_relay  11_13_05
# 1  41.0   M  3:08:56  rock_creek_park_marathon_and_relay  11_13_05
# 2  35.0   F  3:12:54  rock_creek_park_marathon_and_relay  11_13_05
#
#          city state
# 0               NaN
# 1  Alexandria    VA
# 2               NaN
#
# Skipping chattanooga_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: disney_world_marathon.parquet
#   Records: 290029
#   Shape: (290029, 7)
#   Sample:
#     age sex     time                   race    date city state
# 0  30.0   M  4:28:12  disney_world_marathon  1_6_02  NaN   NaN
# 1  40.0   F  4:28:13  disney_world_marathon  1_6_02  NaN   NaN
# 2  45.0   M  4:28:14  disney_world_marathon  1_6_02  NaN   NaN
#
# Skipping eden_project_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: new_england_series_-_ri.parquet
#   Records: 408
#   Shape: (408, 7)
#   Sample:
#     age sex     time                     race     date           city  state
# 0  33.0   M  3:59:01  new_england_series_-_ri  6_25_19            Lee     NH
# 1  34.0   M  4:04:52  new_england_series_-_ri  6_25_19  Cottage Grove     WI
# 2  51.0   M  4:05:48  new_england_series_-_ri  6_25_19        Beijing  China
#
# Processed: leading_ladies'_marathon.parquet
#   Records: 2526
#   Shape: (2526, 7)
#   Sample:
#    age sex     time                      race     date city state
# 0  NaN   F  3:54:08  leading_ladies'_marathon  8_17_14  NaN   NaN
# 1  NaN   F  3:55:34  leading_ladies'_marathon  8_17_14  NaN   NaN
# 2  NaN   F  3:56:20  leading_ladies'_marathon  8_17_14  NaN   NaN
#
# Processed: porcupine_mountains_trail_marathon.parquet
#   Records: 170
#   Shape: (170, 7)
#   Sample:
#     age sex     time                                race     date  \
# 0  None   M  4:00:06  porcupine_mountains_trail_marathon  9_20_14
# 1  None   M  4:12:09  porcupine_mountains_trail_marathon  9_20_14
# 2  None   M  4:27:39  porcupine_mountains_trail_marathon  9_20_14
#
#           city state
# 0     Houghton    MI
# 1       Wausau    WI
# 2  Grand Haven    MI
#
# Skipping nagoya_int'l_women's_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: run_for_the_ranch_marathon.parquet
#   Records: 1917
#   Shape: (1917, 7)
#   Sample:
#    age sex     time                        race      date       city state
# 0   35   M  2:48:12  run_for_the_ranch_marathon  12_31_06   Columbus    OH
# 1   33   M  2:55:16  run_for_the_ranch_marathon  12_31_06    Fremont    NE
# 2   30   M  3:07:42  run_for_the_ranch_marathon  12_31_06  Arlington    VA
#
# Skipping loch_ness_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: rock_'n'_roll_country_music_marathon.parquet
#   Records: 18495
#   Shape: (18495, 7)
#   Sample:
#    age sex     time                                  race     date city state
# 0  NaN   F  5:28:07  rock_'n'_roll_country_music_marathon  4_30_16  NaN   NaN
# 1  NaN   M  5:28:08  rock_'n'_roll_country_music_marathon  4_30_16  NaN   NaN
# 2  NaN   F  5:28:11  rock_'n'_roll_country_music_marathon  4_30_16  NaN   NaN
#
# Processed: first_call_spring_marathon.parquet
#   Records: 58
#   Shape: (58, 7)
#   Sample:
#    age sex     time                        race     date       city state
# 0   29   F  3:16:49  first_call_spring_marathon  5_11_13    Redmond    WA
# 1   32   M  3:29:29  first_call_spring_marathon  5_11_13  Beaverton    OR
# 2   41   M  3:41:41  first_call_spring_marathon  5_11_13     Auburn    WA
#
# Processed: first_day_of_winter_marathon.parquet
#   Records: 26
#   Shape: (26, 7)
#   Sample:
#    age sex     time                          race      date          city  \
# 0   40   M  3:44:07  first_day_of_winter_marathon  12_20_15      Hilliard
# 1   40   M  4:06:31  first_day_of_winter_marathon  12_20_15      Wellston
# 2   43   F  4:40:03  first_day_of_winter_marathon  12_20_15  Lake Village
#
#   state
# 0    OH
# 1    OH
# 2    IN
#
# Skipping run_barbados_marathon_weekend.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: meridian_marathon,_leo_run_to_remember.parquet
#   Records: 255
#   Shape: (255, 7)
#   Sample:
#    age sex     time                                    race      date  \
# 0   39   M  2:55:10  meridian_marathon,_leo_run_to_remember  11_15_14
# 1   34   M  3:11:59  meridian_marathon,_leo_run_to_remember  11_15_14
# 2   35   M  3:18:51  meridian_marathon,_leo_run_to_remember  11_15_14
#
#         city state
# 0  Niceville    FL
# 1    Tuscola    TX
# 2     Oxford    MS
#
# Processed: grand_rapids_marathon.parquet
#   Records: 22400
#   Shape: (22400, 7)
#   Sample:
#     age sex     time                   race      date        city state
# 0  29.0   M  3:16:23  grand_rapids_marathon  10_16_11    Rockford    MI
# 1  34.0   M  3:16:58  grand_rapids_marathon  10_16_11     Lansing    MI
# 2  23.0   M  3:17:10  grand_rapids_marathon  10_16_11  Farmington    MI
#
# Skipping hot_mama!_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: nebraska_state_fair_marathon.parquet
#   Records: 1426
#   Shape: (1426, 7)
#   Sample:
#    age sex     time                          race     date city state
# 0  NaN   F  3:44:18  nebraska_state_fair_marathon  8_26_23  NaN   NaN
# 1  NaN   F  3:45:54  nebraska_state_fair_marathon  8_26_23  NaN   NaN
# 2  NaN   F  3:46:16  nebraska_state_fair_marathon  8_26_23  NaN   NaN
#
# Skipping smoky_mountain_left_turn_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: rock_creek_park_marathon_and_relay.parquet
#   Records: 81
#   Shape: (81, 7)
#   Sample:
#     age sex     time                                race      date  \
# 0  33.0   M  3:06:24  rock_creek_park_marathon_and_relay  11_13_05
# 1  41.0   M  3:08:56  rock_creek_park_marathon_and_relay  11_13_05
# 2  35.0   F  3:12:54  rock_creek_park_marathon_and_relay  11_13_05
#
#          city state
# 0               NaN
# 1  Alexandria    VA
# 2               NaN
#
# Skipping chattanooga_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: five_points_of_life_marathon.parquet
#   Records: 2872
#   Shape: (2872, 7)
#   Sample:
#    age sex     time                          race     date         city state
# 0  NaN   M  4:17:20  five_points_of_life_marathon  2_19_12        Ocala    FL
# 1  NaN   F  4:18:21  five_points_of_life_marathon  2_19_12  Gainesville    FL
# 2  NaN   M  4:19:03  five_points_of_life_marathon  2_19_12     Sarasota    FL
#
# Processed: el_paso_marathon.parquet
#   Records: 5373
#   Shape: (5373, 7)
#   Sample:
#     age sex     time              race    date     city state
# 0  48.0   M  4:27:23  el_paso_marathon  3_2_08  El Paso    TX
# 1  33.0   M  4:27:11  el_paso_marathon  3_2_08  Socorro    TX
# 2  25.0   F  4:28:07  el_paso_marathon  3_2_08   Euless    TX
#
# Skipping revel_big_bear_and_half_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: ridge_runner_races.parquet
#   Records: 1208
#   Shape: (1208, 7)
#   Sample:
#     age sex     time                race    date           city state
# 0  21.0   M  2:59:24  ridge_runner_races  6_4_05    Chapel Hill    NC
# 1  32.0   M  3:04:34  ridge_runner_races  6_4_05  Campbell Hall    NY
# 2  41.0   M  3:16:48  ridge_runner_races  6_4_05       Columbus    OH
#
# Processed: run_crandic_marathon.parquet
#   Records: 1300
#   Shape: (1300, 7)
#   Sample:
#    age sex     time                  race     date city state
# 0  NaN   M  3:44:30  run_crandic_marathon  4_24_22  NaN   NaN
# 1  NaN   M  3:44:36  run_crandic_marathon  4_24_22  NaN   NaN
# 2  NaN   M  3:44:37  run_crandic_marathon  4_24_22  NaN   NaN
#
# Processed: asbury_park_relay_marathon.parquet
#   Records: 351
#   Shape: (351, 7)
#   Sample:
#    age sex     time                        race      date       city state
# 0   34   M  2:30:28  asbury_park_relay_marathon  10_16_11   NEW YORK    NY
# 1   22   M  2:42:47  asbury_park_relay_marathon  10_16_11  MANALAPAN    NJ
# 2   34   M  3:08:10  asbury_park_relay_marathon  10_16_11       YORK    PA
#
# Skipping run_for_the_elk_marathon_race_festival.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: richland_run_fest_marathon.parquet
#   Records: 134
#   Shape: (134, 7)
#   Sample:
#     age sex     time                        race     date city state
# 0  40.0   M  3:06:38  richland_run_fest_marathon  2_25_17  NaN   NaN
# 1  26.0   M  3:18:07  richland_run_fest_marathon  2_25_17  NaN   NaN
# 2  43.0   M  3:21:39  richland_run_fest_marathon  2_25_17  NaN   NaN
#
# Processed: washington's_birthday_marathon.parquet
#   Records: 3399
#   Shape: (3399, 7)
#   Sample:
#     age sex     time                            race     date        city  \
# 0  34.0   F  4:13:17  washington's_birthday_marathon  2_15_09  Alexandria
# 1  42.0   F  4:13:49  washington's_birthday_marathon  2_15_09    Sterling
# 2  60.0   M  4:14:24  washington's_birthday_marathon  2_15_09     Corning
#
#   state
# 0    VA
# 1    VA
# 2    NY
#
# Skipping the_hampshire_hoppit_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping northwest_passage_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: via_marathon_(formerly_the_lehigh_valley_hospital_marathon_for_via).parquet
#   Records: 8096
#   Shape: (8096, 7)
#   Sample:
#    age sex     time                                               race  \
# 0  NaN   F  3:14:47  via_marathon_(formerly_the_lehigh_valley_hospi...
# 1  NaN   M  3:14:52  via_marathon_(formerly_the_lehigh_valley_hospi...
# 2  NaN   M  3:14:59  via_marathon_(formerly_the_lehigh_valley_hospi...
#
#       date       city state
# 0  9_13_15   Macungie    PA
# 1  9_13_15  Cambridge    MA
# 2  9_13_15  Lexington    MA
#
# Skipping kielder_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping leona_valley_trail_races_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: charleston_salmon_run.parquet
#   Records: 37
#   Shape: (37, 7)
#   Sample:
#    age sex     time                   race     date         city state
# 0   42   F  3:22:45  charleston_salmon_run  10_6_18       Bandon    OR
# 1   39   M  3:28:01  charleston_salmon_run  10_6_18   Eatonville    WA
# 2   42   M  3:35:39  charleston_salmon_run  10_6_18  Springfield    OR
#
# Processed: more_marathon.parquet
#   Records: 1300
#   Shape: (1300, 7)
#   Sample:
#     age sex     time           race     date          city state
# 0  53.0   F  4:29:49  more_marathon  3_26_06     ST. JAMES    NY
# 1  42.0   F  4:30:17  more_marathon  3_26_06  HAMPTON BAYS    NY
# 2  48.0   F  4:30:55  more_marathon  3_26_06     PAWCATUCK    CT
#
# Processed: center_of_the_nation_marathon_-_wyoming.parquet
#   Records: 674
#   Shape: (674, 7)
#   Sample:
#     age sex     time                                     race     date city  \
# 0  29.0   M  3:37:13  center_of_the_nation_marathon_-_wyoming  9_20_14  NaN
# 1  31.0   M  3:49:48  center_of_the_nation_marathon_-_wyoming  9_20_14  NaN
# 2  34.0   F  3:57:14  center_of_the_nation_marathon_-_wyoming  9_20_14  NaN
#
#   state
# 0   NaN
# 1   NaN
# 2   NaN
#
# Processed: toronto_indoor_run4rkids_marathon.parquet
#   Records: 87
#   Shape: (87, 7)
#   Sample:
#     age sex     time                               race    date         city  \
# 0  None   M  3:06:46  toronto_indoor_run4rkids_marathon  1_5_13  Mississauga
# 1  None   M  3:14:24  toronto_indoor_run4rkids_marathon  1_5_13     Pembroke
# 2  None   M  3:18:42  toronto_indoor_run4rkids_marathon  1_5_13       London
#
#   state
# 0    ON
# 1    ON
# 2    ON
#
# Processed: florida_gulf_beaches_marathon.parquet
#   Records: 3948
#   Shape: (3948, 7)
#   Sample:
#     age sex     time                           race     date    city state
# 0  42.0   M  3:46:26  florida_gulf_beaches_marathon  2_16_03  APOPKA    FL
# 1  49.0   M  3:46:29  florida_gulf_beaches_marathon  2_16_03  EUSTIS    FL
# 2  56.0   M  3:46:46  florida_gulf_beaches_marathon  2_16_03   TAMPA    FL
#
# Skipping waterfalls_of_big_basin.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping lake_mead_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: jackson_hole_marathon.parquet
#   Records: 2591
#   Shape: (2591, 7)
#   Sample:
#     age sex     time                   race     date      city state
# 0  36.0   F  4:44:32  jackson_hole_marathon  9_26_20     Enola    PA
# 1  58.0   M  4:44:53  jackson_hole_marathon  9_26_20  Mesquite    TX
# 2  46.0   M  4:45:07  jackson_hole_marathon  9_26_20   Houston    TX
#
# Skipping mississauga_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: stone_cat_marathon_and_50_mile_trail_races.parquet
#   Records: 3100
#   Shape: (3100, 7)
#   Sample:
#     age sex     time                                        race     date  \
# 0  36.0   M  4:01:44  stone_cat_marathon_and_50_mile_trail_races  11_8_03
# 1  27.0   F  4:01:55  stone_cat_marathon_and_50_mile_trail_races  11_8_03
# 2  48.0   M  4:02:58  stone_cat_marathon_and_50_mile_trail_races  11_8_03
#
#   city state
# 0  NaN   NaN
# 1  NaN   NaN
# 2  NaN   NaN
#
# Processed: martian_marathon.parquet
#   Records: 6500
#   Shape: (6500, 7)
#   Sample:
#    age sex time              race     date city state
# 0  NaN   M  NaN  martian_marathon  4_15_23  NaN   NaN
# 1  NaN   F  NaN  martian_marathon  4_15_23  NaN   NaN
# 2  NaN   M  NaN  martian_marathon  4_15_23  NaN   NaN
#
# Skipping the_longhorn_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: gansett_fall_marathon.parquet
#   Records: 4
#   Shape: (4, 7)
#   Sample:
#    age sex     time                   race      date           city state
# 0   33   F  3:20:26  gansett_fall_marathon  10_26_13   Philadelphia    PA
# 1   55   M  3:39:17  gansett_fall_marathon  10_26_13  Winston-Salem    NC
# 2   53   M  3:39:22  gansett_fall_marathon  10_26_13     Cincinnati    OH
#
# Processed: five_points_of_life_marathon.parquet
#   Records: 2872
#   Shape: (2872, 7)
#   Sample:
#    age sex     time                          race     date         city state
# 0  NaN   M  4:17:20  five_points_of_life_marathon  2_19_12        Ocala    FL
# 1  NaN   F  4:18:21  five_points_of_life_marathon  2_19_12  Gainesville    FL
# 2  NaN   M  4:19:03  five_points_of_life_marathon  2_19_12     Sarasota    FL
#
# Processed: el_paso_marathon.parquet
#   Records: 5373
#   Shape: (5373, 7)
#   Sample:
#     age sex     time              race    date     city state
# 0  48.0   M  4:27:23  el_paso_marathon  3_2_08  El Paso    TX
# 1  33.0   M  4:27:11  el_paso_marathon  3_2_08  Socorro    TX
# 2  25.0   F  4:28:07  el_paso_marathon  3_2_08   Euless    TX
#
# Skipping revel_big_bear_and_half_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: ridge_runner_races.parquet
#   Records: 1208
#   Shape: (1208, 7)
#   Sample:
#     age sex     time                race    date           city state
# 0  21.0   M  2:59:24  ridge_runner_races  6_4_05    Chapel Hill    NC
# 1  32.0   M  3:04:34  ridge_runner_races  6_4_05  Campbell Hall    NY
# 2  41.0   M  3:16:48  ridge_runner_races  6_4_05       Columbus    OH
#
# Processed: run_crandic_marathon.parquet
#   Records: 1300
#   Shape: (1300, 7)
#   Sample:
#    age sex     time                  race     date city state
# 0  NaN   M  3:44:30  run_crandic_marathon  4_24_22  NaN   NaN
# 1  NaN   M  3:44:36  run_crandic_marathon  4_24_22  NaN   NaN
# 2  NaN   M  3:44:37  run_crandic_marathon  4_24_22  NaN   NaN
#
# Processed: asbury_park_relay_marathon.parquet
#   Records: 351
#   Shape: (351, 7)
#   Sample:
#    age sex     time                        race      date       city state
# 0   34   M  2:30:28  asbury_park_relay_marathon  10_16_11   NEW YORK    NY
# 1   22   M  2:42:47  asbury_park_relay_marathon  10_16_11  MANALAPAN    NJ
# 2   34   M  3:08:10  asbury_park_relay_marathon  10_16_11       YORK    PA
#
# Skipping run_for_the_elk_marathon_race_festival.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: richland_run_fest_marathon.parquet
#   Records: 134
#   Shape: (134, 7)
#   Sample:
#     age sex     time                        race     date city state
# 0  40.0   M  3:06:38  richland_run_fest_marathon  2_25_17  NaN   NaN
# 1  26.0   M  3:18:07  richland_run_fest_marathon  2_25_17  NaN   NaN
# 2  43.0   M  3:21:39  richland_run_fest_marathon  2_25_17  NaN   NaN
#
# Processed: washington's_birthday_marathon.parquet
#   Records: 3399
#   Shape: (3399, 7)
#   Sample:
#     age sex     time                            race     date        city  \
# 0  34.0   F  4:13:17  washington's_birthday_marathon  2_15_09  Alexandria
# 1  42.0   F  4:13:49  washington's_birthday_marathon  2_15_09    Sterling
# 2  60.0   M  4:14:24  washington's_birthday_marathon  2_15_09     Corning
#
#   state
# 0    VA
# 1    VA
# 2    NY
#
# Skipping the_hampshire_hoppit_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping northwest_passage_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: via_marathon_(formerly_the_lehigh_valley_hospital_marathon_for_via).parquet
#   Records: 8096
#   Shape: (8096, 7)
#   Sample:
#    age sex     time                                               race  \
# 0  NaN   F  3:14:47  via_marathon_(formerly_the_lehigh_valley_hospi...
# 1  NaN   M  3:14:52  via_marathon_(formerly_the_lehigh_valley_hospi...
# 2  NaN   M  3:14:59  via_marathon_(formerly_the_lehigh_valley_hospi...
#
#       date       city state
# 0  9_13_15   Macungie    PA
# 1  9_13_15  Cambridge    MA
# 2  9_13_15  Lexington    MA
#
# Skipping kielder_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping leona_valley_trail_races_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: charleston_salmon_run.parquet
#   Records: 37
#   Shape: (37, 7)
#   Sample:
#    age sex     time                   race     date         city state
# 0   42   F  3:22:45  charleston_salmon_run  10_6_18       Bandon    OR
# 1   39   M  3:28:01  charleston_salmon_run  10_6_18   Eatonville    WA
# 2   42   M  3:35:39  charleston_salmon_run  10_6_18  Springfield    OR
#
# Processed: more_marathon.parquet
#   Records: 1300
#   Shape: (1300, 7)
#   Sample:
#     age sex     time           race     date          city state
# 0  53.0   F  4:29:49  more_marathon  3_26_06     ST. JAMES    NY
# 1  42.0   F  4:30:17  more_marathon  3_26_06  HAMPTON BAYS    NY
# 2  48.0   F  4:30:55  more_marathon  3_26_06     PAWCATUCK    CT
#
# Processed: center_of_the_nation_marathon_-_wyoming.parquet
#   Records: 674
#   Shape: (674, 7)
#   Sample:
#     age sex     time                                     race     date city  \
# 0  29.0   M  3:37:13  center_of_the_nation_marathon_-_wyoming  9_20_14  NaN
# 1  31.0   M  3:49:48  center_of_the_nation_marathon_-_wyoming  9_20_14  NaN
# 2  34.0   F  3:57:14  center_of_the_nation_marathon_-_wyoming  9_20_14  NaN
#
#   state
# 0   NaN
# 1   NaN
# 2   NaN
#
# Processed: toronto_indoor_run4rkids_marathon.parquet
#   Records: 87
#   Shape: (87, 7)
#   Sample:
#     age sex     time                               race    date         city  \
# 0  None   M  3:06:46  toronto_indoor_run4rkids_marathon  1_5_13  Mississauga
# 1  None   M  3:14:24  toronto_indoor_run4rkids_marathon  1_5_13     Pembroke
# 2  None   M  3:18:42  toronto_indoor_run4rkids_marathon  1_5_13       London
#
#   state
# 0    ON
# 1    ON
# 2    ON
#
# Processed: florida_gulf_beaches_marathon.parquet
#   Records: 3948
#   Shape: (3948, 7)
#   Sample:
#     age sex     time                           race     date    city state
# 0  42.0   M  3:46:26  florida_gulf_beaches_marathon  2_16_03  APOPKA    FL
# 1  49.0   M  3:46:29  florida_gulf_beaches_marathon  2_16_03  EUSTIS    FL
# 2  56.0   M  3:46:46  florida_gulf_beaches_marathon  2_16_03   TAMPA    FL
#
# Skipping waterfalls_of_big_basin.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping lake_mead_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: jackson_hole_marathon.parquet
#   Records: 2591
#   Shape: (2591, 7)
#   Sample:
#     age sex     time                   race     date      city state
# 0  36.0   F  4:44:32  jackson_hole_marathon  9_26_20     Enola    PA
# 1  58.0   M  4:44:53  jackson_hole_marathon  9_26_20  Mesquite    TX
# 2  46.0   M  4:45:07  jackson_hole_marathon  9_26_20   Houston    TX
#
# Skipping mississauga_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: stone_cat_marathon_and_50_mile_trail_races.parquet
#   Records: 3100
#   Shape: (3100, 7)
#   Sample:
#     age sex     time                                        race     date  \
# 0  36.0   M  4:01:44  stone_cat_marathon_and_50_mile_trail_races  11_8_03
# 1  27.0   F  4:01:55  stone_cat_marathon_and_50_mile_trail_races  11_8_03
# 2  48.0   M  4:02:58  stone_cat_marathon_and_50_mile_trail_races  11_8_03
#
#   city state
# 0  NaN   NaN
# 1  NaN   NaN
# 2  NaN   NaN
#
# Processed: martian_marathon.parquet
#   Records: 6500
#   Shape: (6500, 7)
#   Sample:
#    age sex time              race     date city state
# 0  NaN   M  NaN  martian_marathon  4_15_23  NaN   NaN
# 1  NaN   F  NaN  martian_marathon  4_15_23  NaN   NaN
# 2  NaN   M  NaN  martian_marathon  4_15_23  NaN   NaN
#
# Skipping the_longhorn_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: gansett_fall_marathon.parquet
#   Records: 4
#   Shape: (4, 7)
#   Sample:
#    age sex     time                   race      date           city state
# 0   33   F  3:20:26  gansett_fall_marathon  10_26_13   Philadelphia    PA
# 1   55   M  3:39:17  gansett_fall_marathon  10_26_13  Winston-Salem    NC
# 2   53   M  3:39:22  gansett_fall_marathon  10_26_13     Cincinnati    OH
#
# Processed: space_coast_marathon.parquet
#   Records: 20297
#   Shape: (20297, 7)
#   Sample:
#    age sex     time                  race      date city state
# 0  NaN   M  3:06:17  space_coast_marathon  11_26_00  NaN   NaN
# 1  NaN   M  3:08:39  space_coast_marathon  11_26_00  NaN   NaN
# 2  NaN   M  3:13:14  space_coast_marathon  11_26_00  NaN   NaN
#
# Skipping turtle_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping holiday_series_-_day_12.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping yukon_arctic_ultra.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: indianapolis_monumental_marathon.parquet
#   Records: 54200
#   Shape: (54200, 7)
#   Sample:
#    age sex     time                              race      date city state
# 0  NaN   F  4:03:08  indianapolis_monumental_marathon  10_28_23  NaN   NaN
# 1  NaN   F  4:03:08  indianapolis_monumental_marathon  10_28_23  NaN   NaN
# 2  NaN   M  4:03:09  indianapolis_monumental_marathon  10_28_23  NaN   NaN
#
# Processed: enchanted_forest.parquet
#   Records: 111
#   Shape: (111, 7)
#   Sample:
#    age sex     time              race     date        city state
# 0   37   M  4:18:12  enchanted_forest  7_30_22  Los Alamos    NM
# 1   40   F  4:33:58  enchanted_forest  7_30_22    El Prado    NM
# 2   53   M  4:40:58  enchanted_forest  7_30_22    Santa Fe    NM
#
# Skipping breck_crest_mountain_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: nashville_nc_running_festival_marathon.parquet
#   Records: 20
#   Shape: (20, 7)
#   Sample:
#     age sex     time                                    race      date  \
# 0  None   M  3:08:48  nashville_nc_running_festival_marathon  10_28_23
# 1  None   M  3:10:38  nashville_nc_running_festival_marathon  10_28_23
# 2  None   M  3:32:08  nashville_nc_running_festival_marathon  10_28_23
#
#           city state
# 0    Fort Mill    SC
# 1  Rocky Mount    NC
# 2   Chesapeake    VA
#
# Processed: logan_marathon.parquet
#   Records: 1100
#   Shape: (1100, 7)
#   Sample:
#     age sex     time            race     date         city state
# 0  None   M  3:58:42  logan_marathon  9_17_22  West Jordan    UT
# 1  None   M  3:59:17  logan_marathon  9_17_22  North Logan    UT
# 2  None   M  3:59:43  logan_marathon  9_17_22        Logan    UT
#
# Skipping 2016_u.s._olympic_team_trials_-_men's_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: big_beach_marathon.parquet
#   Records: 2500
#   Shape: (2500, 7)
#   Sample:
#     age sex     time                race     date     city state
# 0  37.0   M  4:23:54  big_beach_marathon  1_27_19   Oregon    WI
# 1  37.0   F  4:23:54  big_beach_marathon  1_27_19   Oregon    WI
# 2  31.0   F  4:23:58  big_beach_marathon  1_27_19  Alameda    CA
#
# Skipping sussex_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: dirty_south_marathon.parquet
#   Records: 400
#   Shape: (400, 7)
#   Sample:
#     age sex     time                  race      date       city state
# 0  46.0   F  3:46:31  dirty_south_marathon  11_15_15  Choudrant    LA
# 1  32.0   M  3:46:58  dirty_south_marathon  11_15_15   Beaumont    TX
# 2  47.0   F  3:47:42  dirty_south_marathon  11_15_15              NaN
#
# Processed: wildwood_trail_marathon.parquet
#   Records: 389
#   Shape: (389, 7)
#   Sample:
#    age sex     time                     race     date        city state
# 0   21   M  3:35:45  wildwood_trail_marathon  12_8_19  Broomfield    CO
# 1   36   M  3:36:16  wildwood_trail_marathon  12_8_19     Ofallon    IL
# 2   46   M  3:37:16  wildwood_trail_marathon  12_8_19   St Peters    MO
#
# Skipping leeds_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: genoa_peak_madathon.parquet
#   Records: 29
#   Shape: (29, 7)
#   Sample:
#    age sex     time                 race    date            city state
# 0   37   M  4:40:57  genoa_peak_madathon  8_8_15    Gardnerville    NV
# 1   50   M  5:06:29  genoa_peak_madathon  8_8_15  Olympic Valley    CA
# 2   48   M  5:53:25  genoa_peak_madathon  8_8_15            Reno    NV
#
# Processed: screaming_pumpkin_marathon.parquet
#   Records: 158
#   Shape: (158, 7)
#   Sample:
#     age sex     time                        race      date          city state
# 0   NaN   M  3:10:37  screaming_pumpkin_marathon  10_26_12                 NaN
# 1  11.0   M  4:03:51  screaming_pumpkin_marathon  10_26_12  Walnut Shade    MO
# 2  57.0   M  4:03:51  screaming_pumpkin_marathon  10_26_12  Walnut Shade    MO
#
# Processed: clarence_demar_marathon.parquet
#   Records: 7400
#   Shape: (7400, 7)
#   Sample:
#     age sex     time                     race     date          city state
# 0  52.0   M  4:09:28  clarence_demar_marathon  9_25_11     Lunenburg    MA
# 1  44.0   M  4:10:19  clarence_demar_marathon  9_25_11     Mansfield    MA
# 2  43.0   M  4:11:16  clarence_demar_marathon  9_25_11  Lisbon Falls    ME
#
# Skipping antarctic_ice_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: space_coast_marathon.parquet
#   Records: 20297
#   Shape: (20297, 7)
#   Sample:
#    age sex     time                  race      date city state
# 0  NaN   M  3:06:17  space_coast_marathon  11_26_00  NaN   NaN
# 1  NaN   M  3:08:39  space_coast_marathon  11_26_00  NaN   NaN
# 2  NaN   M  3:13:14  space_coast_marathon  11_26_00  NaN   NaN
#
# Skipping turtle_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping holiday_series_-_day_12.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping yukon_arctic_ultra.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: indianapolis_monumental_marathon.parquet
#   Records: 54200
#   Shape: (54200, 7)
#   Sample:
#    age sex     time                              race      date city state
# 0  NaN   F  4:03:08  indianapolis_monumental_marathon  10_28_23  NaN   NaN
# 1  NaN   F  4:03:08  indianapolis_monumental_marathon  10_28_23  NaN   NaN
# 2  NaN   M  4:03:09  indianapolis_monumental_marathon  10_28_23  NaN   NaN
#
# Processed: enchanted_forest.parquet
#   Records: 111
#   Shape: (111, 7)
#   Sample:
#    age sex     time              race     date        city state
# 0   37   M  4:18:12  enchanted_forest  7_30_22  Los Alamos    NM
# 1   40   F  4:33:58  enchanted_forest  7_30_22    El Prado    NM
# 2   53   M  4:40:58  enchanted_forest  7_30_22    Santa Fe    NM
#
# Skipping breck_crest_mountain_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: nashville_nc_running_festival_marathon.parquet
#   Records: 20
#   Shape: (20, 7)
#   Sample:
#     age sex     time                                    race      date  \
# 0  None   M  3:08:48  nashville_nc_running_festival_marathon  10_28_23
# 1  None   M  3:10:38  nashville_nc_running_festival_marathon  10_28_23
# 2  None   M  3:32:08  nashville_nc_running_festival_marathon  10_28_23
#
#           city state
# 0    Fort Mill    SC
# 1  Rocky Mount    NC
# 2   Chesapeake    VA
#
# Processed: logan_marathon.parquet
#   Records: 1100
#   Shape: (1100, 7)
#   Sample:
#     age sex     time            race     date         city state
# 0  None   M  3:58:42  logan_marathon  9_17_22  West Jordan    UT
# 1  None   M  3:59:17  logan_marathon  9_17_22  North Logan    UT
# 2  None   M  3:59:43  logan_marathon  9_17_22        Logan    UT
#
# Skipping 2016_u.s._olympic_team_trials_-_men's_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: big_beach_marathon.parquet
#   Records: 2500
#   Shape: (2500, 7)
#   Sample:
#     age sex     time                race     date     city state
# 0  37.0   M  4:23:54  big_beach_marathon  1_27_19   Oregon    WI
# 1  37.0   F  4:23:54  big_beach_marathon  1_27_19   Oregon    WI
# 2  31.0   F  4:23:58  big_beach_marathon  1_27_19  Alameda    CA
#
# Skipping sussex_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: dirty_south_marathon.parquet
#   Records: 400
#   Shape: (400, 7)
#   Sample:
#     age sex     time                  race      date       city state
# 0  46.0   F  3:46:31  dirty_south_marathon  11_15_15  Choudrant    LA
# 1  32.0   M  3:46:58  dirty_south_marathon  11_15_15   Beaumont    TX
# 2  47.0   F  3:47:42  dirty_south_marathon  11_15_15              NaN
#
# Processed: wildwood_trail_marathon.parquet
#   Records: 389
#   Shape: (389, 7)
#   Sample:
#    age sex     time                     race     date        city state
# 0   21   M  3:35:45  wildwood_trail_marathon  12_8_19  Broomfield    CO
# 1   36   M  3:36:16  wildwood_trail_marathon  12_8_19     Ofallon    IL
# 2   46   M  3:37:16  wildwood_trail_marathon  12_8_19   St Peters    MO
#
# Skipping leeds_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: genoa_peak_madathon.parquet
#   Records: 29
#   Shape: (29, 7)
#   Sample:
#    age sex     time                 race    date            city state
# 0   37   M  4:40:57  genoa_peak_madathon  8_8_15    Gardnerville    NV
# 1   50   M  5:06:29  genoa_peak_madathon  8_8_15  Olympic Valley    CA
# 2   48   M  5:53:25  genoa_peak_madathon  8_8_15            Reno    NV
#
# Processed: screaming_pumpkin_marathon.parquet
#   Records: 158
#   Shape: (158, 7)
#   Sample:
#     age sex     time                        race      date          city state
# 0   NaN   M  3:10:37  screaming_pumpkin_marathon  10_26_12                 NaN
# 1  11.0   M  4:03:51  screaming_pumpkin_marathon  10_26_12  Walnut Shade    MO
# 2  57.0   M  4:03:51  screaming_pumpkin_marathon  10_26_12  Walnut Shade    MO
#
# Processed: clarence_demar_marathon.parquet
#   Records: 7400
#   Shape: (7400, 7)
#   Sample:
#     age sex     time                     race     date          city state
# 0  52.0   M  4:09:28  clarence_demar_marathon  9_25_11     Lunenburg    MA
# 1  44.0   M  4:10:19  clarence_demar_marathon  9_25_11     Mansfield    MA
# 2  43.0   M  4:11:16  clarence_demar_marathon  9_25_11  Lisbon Falls    ME
#
# Skipping antarctic_ice_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: bataan_memorial_death_march.parquet
#   Records: 48700
#   Shape: (48700, 7)
#   Sample:
#    age sex time                         race     date city state
# 0  NaN   F  NaN  bataan_memorial_death_march  3_19_23  NaN   NaN
# 1  NaN   F  NaN  bataan_memorial_death_march  3_19_23  NaN   NaN
# 2  NaN   F  NaN  bataan_memorial_death_march  3_19_23  NaN   NaN
#
# ...
#
#   state
# 0   NaN
# 1    ON
# 2    NY
#
# Processed: freedom_marathon.parquet
#   Records: 105
#   Shape: (105, 7)
#   Sample:
#     age sex     time              race    date city state
# 0  40.0   M  2:55:32  freedom_marathon  7_3_11  NaN   NaN
# 1  50.0   M  3:22:53  freedom_marathon  7_3_11  NaN   NaN
# 2  34.0   M  3:48:21  freedom_marathon  7_3_11  NaN   NaN
#
# Skipping endurancelife_coastal_trail_series_marathon_-_dorset.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: leadville_trail_marathon.parquet
#   Records: 9898
#   Shape: (9898, 7)
#   Sample:
#    age sex     time                      race     date              city state
# 0  NaN   M  5:49:42  leadville_trail_marathon  7_11_09  Colorado Springs    CO
# 1  NaN   M  5:51:01  leadville_trail_marathon  7_11_09             Tulsa    OK
# 2  NaN   M  5:51:04  leadville_trail_marathon  7_11_09        Wheatridge    CO
#
# Skipping millbrook_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: dances_with_dirt_green_swamp.parquet
#   Records: 200
#   Shape: (200, 7)
#   Sample:
#    age sex     time                          race     date city state
# 0  NaN   M  3:36:18  dances_with_dirt_green_swamp  3_24_12  NaN   NaN
# 1  NaN   M  4:04:45  dances_with_dirt_green_swamp  3_24_12  NaN   NaN
# 2  NaN   F  4:15:42  dances_with_dirt_green_swamp  3_24_12  NaN   NaN
#
# Processed: timp_trail_marathon.parquet
#   Records: 1487
#   Shape: (1487, 7)
#   Sample:
#     age sex     time                 race     date city state
# 0  22.0   M  4:00:24  timp_trail_marathon  5_18_13  NaN   NaN
# 1  17.0   M  4:04:25  timp_trail_marathon  5_18_13  NaN   NaN
# 2  31.0   M  4:06:03  timp_trail_marathon  5_18_13  NaN   NaN
#
# Processed: colorado_fall_equinox_marathon.parquet
#   Records: 503
#   Shape: (503, 7)
#   Sample:
#    age sex     time                            race     date      city state
# 0   25   M  3:32:16  colorado_fall_equinox_marathon  9_17_23  LONGMONT    CO
# 1   24   M  3:39:04  colorado_fall_equinox_marathon  9_17_23  STERLING    CO
# 2   41   M  3:44:43  colorado_fall_equinox_marathon  9_17_23    DENVER    CO
#
# Processed: idaho_falls_mad_marathon.parquet
#   Records: 603
#   Shape: (603, 7)
#   Sample:
#     age sex     time                      race     date         city state
# 0  39.0   M  3:04:33  idaho_falls_mad_marathon  7_30_22        Boise    ID
# 1  33.0   M  3:13:23  idaho_falls_mad_marathon  7_30_22      Bozeman    MT
# 2  36.0   M  3:32:22  idaho_falls_mad_marathon  7_30_22  Idaho Falls    ID
#
# Processed: edmonton_festival_marathon.parquet
#   Records: 2500
#   Shape: (2500, 7)
#   Sample:
#     age sex     time                        race     date           city state
# 0  None   M  3:44:52  edmonton_festival_marathon  6_21_03  SHERWOOD PARK    AB
# 1  None   M  3:45:20  edmonton_festival_marathon  6_21_03       EDMONTON    AB
# 2  None   M  3:45:53  edmonton_festival_marathon  6_21_03        CALGARY    AB
#
# Processed: miracle_match_marathon.parquet
#   Records: 2336
#   Shape: (2336, 7)
#   Sample:
#    age sex     time                    race     date city state
# 0  NaN   M  3:02:37  miracle_match_marathon  1_27_19  NaN   NaN
# 1  NaN   M  3:10:52  miracle_match_marathon  1_27_19  NaN   NaN
# 2  NaN   F  3:11:34  miracle_match_marathon  1_27_19  NaN   NaN
#
# Processed: bend_marathon.parquet
#   Records: 79
#   Shape: (79, 7)
#   Sample:
#    age sex     time           race     date     city state
# 0   38   M  2:59:32  bend_marathon  10_1_11     Bend    OR
# 1   38   M  3:13:58  bend_marathon  10_1_11  Sisters    OR
# 2   33   M  3:19:42  bend_marathon  10_1_11  Redmond    OR
#
# Skipping milton_keynes_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping sudbury_rocks!!!_race,_run_or_walk_for_diabetes.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping olympics_2000_(men).parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping mt_hood_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: the_instant_classic_marathon_trail_run.parquet
#   Records: 704
#   Shape: (704, 7)
#   Sample:
#     age sex     time                                    race     date  \
# 0  55.0   M  3:57:58  the_instant_classic_marathon_trail_run  3_17_12
# 1  42.0   M  3:58:28  the_instant_classic_marathon_trail_run  3_17_12
# 2  55.0   M  4:04:23  the_instant_classic_marathon_trail_run  3_17_12
#
#          city state
# 0      Mebane    NC
# 1  Glen Allen    VA
# 2  Midlothian    VA
#
# Processed: provo_river_relay_marathon.parquet
#   Records: 34
#   Shape: (34, 7)
#   Sample:
#    age sex     time                        race     date   city state
# 0   42   M  3:03:40  provo_river_relay_marathon  8_28_10  Ivins    UT
# 1   38   M  3:31:22  provo_river_relay_marathon  8_28_10  Ogden    UT
# 2   21   M  3:32:36  provo_river_relay_marathon  8_28_10  Provo    UT
#
# Processed: the_san_francisco_marathon.parquet
#   Records: 104218
#   Shape: (104218, 7)
#   Sample:
#     age sex     time                        race    date       city state
# 0  54.0   M  4:38:49  the_san_francisco_marathon  8_3_08    Fremont    CA
# 1  28.0   M  4:39:33  the_san_francisco_marathon  8_3_08   San Jose    CA
# 2  33.0   F  5:17:22  the_san_francisco_marathon  8_3_08  Sheboygan    WI
#
# Processed: the_kauai_marathon.parquet
#   Records: 3798
#   Shape: (3798, 7)
#   Sample:
#     age sex     time                race    date          city state
# 0  39.0   M  4:23:35  the_kauai_marathon  9_1_19         Kapaa    HI
# 1  45.0   M  4:24:37  the_kauai_marathon  9_1_19  Robbinsville    NJ
# 2  59.0   M  4:24:54  the_kauai_marathon  9_1_19         Menan    ID
#
# Skipping the_christmas_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping run_the_caldera_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: dupont_city_trail_marathon.parquet
#   Records: 214
#   Shape: (214, 7)
#   Sample:
#     age sex     time                        race    date        city state
# 0  29.0   M  3:18:16  dupont_city_trail_marathon  3_7_20  Mill Creek    WA
# 1  51.0   M  3:30:26  dupont_city_trail_marathon  3_7_20   Sammamish    WA
# 2  51.0   M  3:32:03  dupont_city_trail_marathon  3_7_20   Sammamish    WA
#
# Processed: white_continent_marathon.parquet
#   Records: 252
#   Shape: (252, 7)
#   Sample:
#     age sex     time                      race     date          city    state
# 0  44.0   M  3:56:43  white_continent_marathon  1_28_20  Redwood City       CA
# 1  37.0   M  4:27:42  white_continent_marathon  1_28_20     San Diego       CA
# 2  39.0   M  4:56:44  white_continent_marathon  1_28_20   Kirkkonummi  Finland
#
# Processed: coast_guard_marathon.parquet
#   Records: 700
#   Shape: (700, 7)
#   Sample:
#     age sex     time                  race    date       city state
# 0  48.0   M  4:23:28  coast_guard_marathon  3_4_23    Edenton    NC
# 1  73.0   M  4:24:08  coast_guard_marathon  3_4_23  Melbourne    FL
# 2  49.0   M  4:25:17  coast_guard_marathon  3_4_23  Blacklick    OH
#
# Skipping waterford_viking_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping run_barbados_festival_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: louisville_marathon,_half_marathon_&_10k.parquet
#   Records: 700
#   Shape: (700, 7)
#   Sample:
#    age sex     time                                      race     date city  \
# 0   42   M  4:21:12  louisville_marathon,_half_marathon_&_10k  11_7_21  NaN
# 1   32   F  4:21:37  louisville_marathon,_half_marathon_&_10k  11_7_21  NaN
# 2   49   F  4:22:46  louisville_marathon,_half_marathon_&_10k  11_7_21  NaN
#
#   state
# 0   NaN
# 1   NaN
# 2   NaN
#
# Processed: prairie_fire_wichita_marathon.parquet
#   Records: 6999
#   Shape: (6999, 7)
#   Sample:
#     age sex     time                           race      date     city state
# 0  50.0   M  3:40:49  prairie_fire_wichita_marathon  10_10_10  WICHITA    KS
# 1  35.0   F  3:40:50  prairie_fire_wichita_marathon  10_10_10  WICHITA    KS
# 2  49.0   M  3:41:03  prairie_fire_wichita_marathon  10_10_10  GODDARD    KS
#
# Processed: the_endurrun_marathon.parquet
#   Records: 449
#   Shape: (449, 7)
#   Sample:
#     age sex     time                   race     date         city state
# 0  44.0   M  2:55:13  the_endurrun_marathon  8_17_14       Guelph    ON
# 1  32.0   M  2:55:19  the_endurrun_marathon  8_17_14         Ajax    ON
# 2  39.0   M  2:56:37  the_endurrun_marathon  8_17_14  Summerstown    ON
#
# Processed: prairie_series_-_mo.parquet
#   Records: 93
#   Shape: (93, 7)
#   Sample:
#     age sex     time                 race     date        city state
# 0  40.0   M  3:33:49  prairie_series_-_mo  5_15_21   Rochester    MN
# 1  26.0   M  3:41:38  prairie_series_-_mo  5_15_21   Nashville    TN
# 2  43.0   M  4:29:43  prairie_series_-_mo  5_15_21  Washington    DC
#
# Processed: anchorage_runfest_humpy's_marathon_(prev._big_wild_life_runs_marathon).parquet
#   Records: 500
#   Shape: (500, 7)
#   Sample:
#     age sex     time                                               race  \
# 0  37.0   M  4:30:43  anchorage_runfest_humpy's_marathon_(prev._big_...
# 1  41.0   F  4:30:41  anchorage_runfest_humpy's_marathon_(prev._big_...
# 2  31.0   F  4:30:52  anchorage_runfest_humpy's_marathon_(prev._big_...
#
#       date                city state
# 0  8_21_22  AnchorageAnchorage    AK
# 1  8_21_22           Kirkville    NY
# 2  8_21_22       Hoosick Falls    NY
#
# Processed: frisco_railroad_run_(formerly_the_frisco_marathon).parquet
#   Records: 385
#   Shape: (385, 7)
#   Sample:
#    age sex     time                                               race  \
# 0   45   M  3:56:59  frisco_railroad_run_(formerly_the_frisco_marat...
# 1   24   M  3:57:28  frisco_railroad_run_(formerly_the_frisco_marat...
# 2   46   M  3:57:50  frisco_railroad_run_(formerly_the_frisco_marat...
#
#       date       city state
# 0  4_24_21  STRAFFORD    MO
# 1  4_24_21    BUFFALO    MO
# 2  4_24_21      ALTON    IL
#
# Processed: trapline_marathon.parquet
#   Records: 230
#   Shape: (230, 7)
#   Sample:
#    age sex     time               race      date                city   state
# 0  NaN   M  2:45:59  trapline_marathon  10_10_21        Frederickton  Canada
# 1  NaN   M  2:48:11  trapline_marathon  10_10_21  Happy Valley-Goose  Canada
# 2  NaN   M  3:54:23  trapline_marathon  10_10_21       Labrador City      NL
#
# Processed: potsdam_raquette_river_marathon.parquet
#   Records: 73
#   Shape: (73, 7)
#   Sample:
#     age sex     time                             race     date         city  \
# 0  39.0   M  2:59:51  potsdam_raquette_river_marathon  8_31_03
# 1  40.0   M  3:45:49  potsdam_raquette_river_marathon  8_31_03   Gloucester
# 2  38.0   M  3:51:08  potsdam_raquette_river_marathon  8_31_03  Burnt Hills
#
#   state
# 0   NaN
# 1    ON
# 2    NY
#
# Processed: freedom_marathon.parquet
#   Records: 105
#   Shape: (105, 7)
#   Sample:
#     age sex     time              race    date city state
# 0  40.0   M  2:55:32  freedom_marathon  7_3_11  NaN   NaN
# 1  50.0   M  3:22:53  freedom_marathon  7_3_11  NaN   NaN
# 2  34.0   M  3:48:21  freedom_marathon  7_3_11  NaN   NaN
#
# Skipping endurancelife_coastal_trail_series_marathon_-_dorset.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: leadville_trail_marathon.parquet
#   Records: 9898
#   Shape: (9898, 7)
#   Sample:
#    age sex     time                      race     date              city state
# 0  NaN   M  5:49:42  leadville_trail_marathon  7_11_09  Colorado Springs    CO
# 1  NaN   M  5:51:01  leadville_trail_marathon  7_11_09             Tulsa    OK
# 2  NaN   M  5:51:04  leadville_trail_marathon  7_11_09        Wheatridge    CO
#
# Skipping millbrook_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: dances_with_dirt_green_swamp.parquet
#   Records: 200
#   Shape: (200, 7)
#   Sample:
#    age sex     time                          race     date city state
# 0  NaN   M  3:36:18  dances_with_dirt_green_swamp  3_24_12  NaN   NaN
# 1  NaN   M  4:04:45  dances_with_dirt_green_swamp  3_24_12  NaN   NaN
# 2  NaN   F  4:15:42  dances_with_dirt_green_swamp  3_24_12  NaN   NaN
#
# Processed: timp_trail_marathon.parquet
#   Records: 1487
#   Shape: (1487, 7)
#   Sample:
#     age sex     time                 race     date city state
# 0  22.0   M  4:00:24  timp_trail_marathon  5_18_13  NaN   NaN
# 1  17.0   M  4:04:25  timp_trail_marathon  5_18_13  NaN   NaN
# 2  31.0   M  4:06:03  timp_trail_marathon  5_18_13  NaN   NaN
#
# Processed: colorado_fall_equinox_marathon.parquet
#   Records: 503
#   Shape: (503, 7)
#   Sample:
#    age sex     time                            race     date      city state
# 0   25   M  3:32:16  colorado_fall_equinox_marathon  9_17_23  LONGMONT    CO
# 1   24   M  3:39:04  colorado_fall_equinox_marathon  9_17_23  STERLING    CO
# 2   41   M  3:44:43  colorado_fall_equinox_marathon  9_17_23    DENVER    CO
#
# Processed: idaho_falls_mad_marathon.parquet
#   Records: 603
#   Shape: (603, 7)
#   Sample:
#     age sex     time                      race     date         city state
# 0  39.0   M  3:04:33  idaho_falls_mad_marathon  7_30_22        Boise    ID
# 1  33.0   M  3:13:23  idaho_falls_mad_marathon  7_30_22      Bozeman    MT
# 2  36.0   M  3:32:22  idaho_falls_mad_marathon  7_30_22  Idaho Falls    ID
#
# Processed: edmonton_festival_marathon.parquet
#   Records: 2500
#   Shape: (2500, 7)
#   Sample:
#     age sex     time                        race     date           city state
# 0  None   M  3:44:52  edmonton_festival_marathon  6_21_03  SHERWOOD PARK    AB
# 1  None   M  3:45:20  edmonton_festival_marathon  6_21_03       EDMONTON    AB
# 2  None   M  3:45:53  edmonton_festival_marathon  6_21_03        CALGARY    AB
#
# Processed: miracle_match_marathon.parquet
#   Records: 2336
#   Shape: (2336, 7)
#   Sample:
#    age sex     time                    race     date city state
# 0  NaN   M  3:02:37  miracle_match_marathon  1_27_19  NaN   NaN
# 1  NaN   M  3:10:52  miracle_match_marathon  1_27_19  NaN   NaN
# 2  NaN   F  3:11:34  miracle_match_marathon  1_27_19  NaN   NaN
#
# Processed: bend_marathon.parquet
#   Records: 79
#   Shape: (79, 7)
#   Sample:
#    age sex     time           race     date     city state
# 0   38   M  2:59:32  bend_marathon  10_1_11     Bend    OR
# 1   38   M  3:13:58  bend_marathon  10_1_11  Sisters    OR
# 2   33   M  3:19:42  bend_marathon  10_1_11  Redmond    OR
#
# Skipping milton_keynes_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping sudbury_rocks!!!_race,_run_or_walk_for_diabetes.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping olympics_2000_(men).parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Skipping mt_hood_marathon.parquet, reason in /Users/thatcher/dev/analysis/projects/marathon_results/race_records_skipped.csv
# Processed: the_instant_classic_marathon_trail_run.parquet
#   Records: 704
#   Shape: (704, 7)
#   Sample:
#     age sex     time                                    race     date  \
# 0  55.0   M  3:57:58  the_instant_classic_marathon_trail_run  3_17_12
# 1  42.0   M  3:58:28  the_instant_classic_marathon_trail_run  3_17_12
# 2  55.0   M  4:04:23  the_instant_classic_marathon_trail_run  3_17_12
#
#          city state
# 0      Mebane    NC
# 1  Glen Allen    VA
# 2  Midlothian    VA
#
# Processed: provo_river_relay_marathon.parquet
#   Records: 34
#   Shape: (34, 7)
#   Sample:
#    age sex     time                        race     date   city state
# 0   42   M  3:03:40  provo_river_relay_marathon  8_28_10  Ivins    UT
# 1   38   M  3:31:22  provo_river_relay_marathon  8_28_10  Ogden    UT
# 2   21   M  3:32:36  provo_river_relay_marathon  8_28_10  Provo    UT

# %% [markdown]
# ## Scrap analysis of big marathon (Boston) to smoke test whether processing worked

# %%
# Load and profile boston_marathon.parquet from race_records

boston_file = os.path.join(race_records_home, "boston_marathon.parquet")

if os.path.exists(boston_file):
    print("=" * 70)
    print("BOSTON MARATHON PROFILE")
    print("=" * 70)
    
    boston_df = pd.read_parquet(boston_file)
    
    # Basic information
    print(f"\nBasic Information:")
    print(f"  Shape: {boston_df.shape[0]} rows × {boston_df.shape[1]} columns")
    print(f"  Memory usage: {boston_df.memory_usage(deep=True).sum() / (1024**2):.2f} MB")
    
    # Column overview
    print(f"\nColumns and Data Types:")
    for col in boston_df.columns:
        dtype = boston_df[col].dtype
        null_count = boston_df[col].isnull().sum()
        null_pct = (null_count / len(boston_df)) * 100
        print(f"  {col:15} - {str(dtype):15} - {null_count:6} nulls ({null_pct:5.2f}%)")
    
    # Statistical summary
    print(f"\nStatistical Summary:")
    print(boston_df.describe())
    
    # Missing values
    print(f"\nMissing Values:")
    missing = boston_df.isnull().sum()
    if missing.sum() > 0:
        print(missing[missing > 0])
    else:
        print("  No missing values")
    
    # Sample data
    print(f"\nSample Records (first 10):")
    print(boston_df.head(10).to_string())
    
    # Value distributions
    print(f"\nValue Distributions:")
    print(f"  Unique ages: {boston_df['age'].nunique()} - Range: {boston_df['age'].min()} to {boston_df['age'].max()}")
    print(f"  Unique sexes: {boston_df['sex'].nunique()} - Values: {boston_df['sex'].unique()}")
    print(f"  Unique cities: {boston_df['city'].nunique()}")
    print(f"  Unique states: {boston_df['state'].nunique()}")
    print(f"  Unique dates: {boston_df['date'].nunique()}")
    
    # Time analysis
    print(f"\nTime Statistics:")
    print(f"  Min time: {boston_df['time'].min()}")
    print(f"  Max time: {boston_df['time'].max()}")
    
else:
    print(f"File not found: {boston_file}")
    print(f"Available files in {race_records_home}:")
    if os.path.exists(race_records_home):
        files = [f for f in os.listdir(race_records_home) if f.endswith('.parquet')]
        for f in sorted(files)[:10]:
            print(f"  {f}")
    else:
        print(f"  Directory does not exist yet")
# Out:
# ======================================================================
# BOSTON MARATHON PROFILE
# ======================================================================
#
# Basic Information:
#   Shape: 454282 rows × 7 columns
#   Memory usage: 144.14 MB
#
# Columns and Data Types:
#   age             - float64         -  66902 nulls (14.73%)
#   sex             - str             -      0 nulls ( 0.00%)
#   time            - str             -  72200 nulls (15.89%)
#   race            - str             -      0 nulls ( 0.00%)
#   date            - str             -      0 nulls ( 0.00%)
#   city            - str             -  66800 nulls (14.70%)
#   state           - str             -  66876 nulls (14.72%)
#
# Statistical Summary:
#                  age
# count  387380.000000
# mean       41.483791
# std        10.910682
# min        18.000000
# 25%        33.000000
# 50%        41.000000
# 75%        49.000000
# max        87.000000
#
# Missing Values:
# age      66902
# time     72200
# city     66800
# state    66876
# dtype: int64
#
# Sample Records (first 10):
#     age sex     time             race     date        city state
# 0  47.0   M  4:19:54  boston_marathon  4_16_12    Palacios    TX
# 1  40.0   F  4:19:54  boston_marathon  4_16_12  Flemington    NJ
# 2  45.0   F  4:19:55  boston_marathon  4_16_12        Reno    NV
# 3  31.0   F  4:19:55  boston_marathon  4_16_12   Camarillo    CA
# 4  30.0   F  4:19:55  boston_marathon  4_16_12   Watertown    MA
# 5  40.0   M  4:19:55  boston_marathon  4_16_12  Flemington    NJ
# 6  48.0   M  4:19:55  boston_marathon  4_16_12      Irvine    CA
# 7  51.0   M  4:19:55  boston_marathon  4_16_12      Saline    MI
# 8  42.0   M  4:19:56  boston_marathon  4_16_12   Smackover    AR
# 9  40.0   F  4:19:56  boston_marathon  4_16_12  Whitehouse    OH
#
# Value Distributions:
#   Unique ages: 68 - Range: 18.0 to 87.0
#   Unique sexes: 115 - Values: <StringArray>
# [       'M',        'F',    'sandy',     'toni',     'eric',    'Jimmy',
#      'bill',      'meg',      'ken',    'rusty',
#  ...
#    't. Jay',  'charlie',    'Amyot',   'barney',    'brian',    'annie',
#    'naichi', 'penelope',     'jane',     'pepe']
# Length: 115, dtype: str
#   Unique cities: 21429
#   Unique states: 846
#   Unique dates: 21
#
# Time Statistics:
#   Min time: 2:03:02
#   Max time: 8:58:53
#   Memory usage: 144.14 MB
#
# Columns and Data Types:
#   age             - float64         -  66902 nulls (14.73%)
#   sex             - str             -      0 nulls ( 0.00%)
#   time            - str             -  72200 nulls (15.89%)
#   race            - str             -      0 nulls ( 0.00%)
#   date            - str             -      0 nulls ( 0.00%)
#   city            - str             -  66800 nulls (14.70%)
#   state           - str             -  66876 nulls (14.72%)
#
# Statistical Summary:
#                  age
# count  387380.000000
# mean       41.483791
# std        10.910682
# min        18.000000
# 25%        33.000000
# 50%        41.000000
# 75%        49.000000
# max        87.000000
#
# Missing Values:
# age      66902
# time     72200
# city     66800
# state    66876
# dtype: int64
#
# Sample Records (first 10):
#     age sex     time             race     date        city state
# 0  47.0   M  4:19:54  boston_marathon  4_16_12    Palacios    TX
# 1  40.0   F  4:19:54  boston_marathon  4_16_12  Flemington    NJ
# 2  45.0   F  4:19:55  boston_marathon  4_16_12        Reno    NV
# 3  31.0   F  4:19:55  boston_marathon  4_16_12   Camarillo    CA
# 4  30.0   F  4:19:55  boston_marathon  4_16_12   Watertown    MA
# 5  40.0   M  4:19:55  boston_marathon  4_16_12  Flemington    NJ
# 6  48.0   M  4:19:55  boston_marathon  4_16_12      Irvine    CA
# 7  51.0   M  4:19:55  boston_marathon  4_16_12      Saline    MI
# 8  42.0   M  4:19:56  boston_marathon  4_16_12   Smackover    AR
# 9  40.0   F  4:19:56  boston_marathon  4_16_12  Whitehouse    OH
#
# Value Distributions:
#   Unique ages: 68 - Range: 18.0 to 87.0
#   Unique sexes: 115 - Values: <StringArray>
# [       'M',        'F',    'sandy',     'toni',     'eric',    'Jimmy',
#      'bill',      'meg',      'ken',    'rusty',
#  ...
#    't. Jay',  'charlie',    'Amyot',   'barney',    'brian',    'annie',
#    'naichi', 'penelope',     'jane',     'pepe']
# Length: 115, dtype: str
#   Unique cities: 21429
#   Unique states: 846
#   Unique dates: 21
#
# Time Statistics:
#   Min time: 2:03:02
#   Max time: 8:58:53

# %% [markdown]
# ### Filter all of the race records for files that have sufficient information for analysis, convert time to minutes

# %%
def time_to_minutes(time_str):
    """
    Convert time string from HH:MM:SS format to total minutes
    """
    try:
        if pd.isna(time_str):
            return None
        time_str = str(time_str).strip()
        parts = time_str.split(':')
        if len(parts) == 3:
            hours, minutes, seconds = int(parts[0]), int(parts[1]), float(parts[2])
            return hours * 60 + minutes + seconds / 60
        elif len(parts) == 2:
            minutes, seconds = int(parts[0]), float(parts[1])
            return minutes + seconds / 60
        else:
            return None
    except (ValueError, AttributeError, IndexError):
        return None

output_csv = "/Users/thatcher/dev/analysis/projects/marathon_results/data/race_records_final.csv"

# Initialize CSV with header on first write
first_write = True

for file in sorted(os.listdir(race_records_home)):
    if not file.endswith('.parquet'):
        continue
        
    full_path = os.path.join(race_records_home, file)
    print(f"Processing {file}...")
    df = pd.read_parquet(full_path)
    
    # Filter for records with both city and state
    candidate_records = df[(df['city'].notna()) & (df['state'].notna())]
    
    # Convert time column from HH:MM:SS to total minutes
    candidate_records = candidate_records.copy()
    candidate_records['time'] = candidate_records['time'].apply(time_to_minutes)
    
    # Incrementally write to CSV
    if len(candidate_records) > 0:
        candidate_records.to_csv(
            output_csv,
            mode='w' if first_write else 'a',
            header=first_write,
            index=False
        )
        print(f"  Written {len(candidate_records)} records")
        first_write = False
    else:
        print(f"  No records with complete city/state")

print(f"\nFinished! Results saved to {output_csv}")
# Out:
# Looking at dog_lake_marathon.parquet...
# Looking at pacific_crest_marathon.parquet...
# Looking at nebraska_marathon.parquet...
# Looking at las_vegas_deja_vu_marathon.parquet...
# Looking at bellingham_bay_marathon.parquet...
# Looking at central_park_marathon.parquet...
# Looking at california_wine_country_marathon.parquet...
# Looking at sogonapmit_marathon.parquet...
# Looking at rivanna_greenbelt_october__marathon.parquet...
# Looking at bemidji_blue_ox_marathon.parquet...
# Looking at alaska_series_-_day_3.parquet...
# Looking at mount_desert_island_marathon.parquet...
# Looking at missoula_marathon.parquet...
# Looking at dust_bowl_series_marathon_-_kansas.parquet...
# Looking at spring_chance_bq.2_marathon_-_sunday.parquet...
# Looking at chosen:_marathon_for_adoption.parquet...
# Looking at california_international_marathon.parquet...
# Looking at haulin'_aspen_trail_marathon.parquet...
# Looking at horse_capital_marathon.parquet...
# Looking at disney_world_marathon.parquet...
# Looking at new_england_series_-_ri.parquet...
# Looking at leading_ladies'_marathon.parquet...
# Looking at porcupine_mountains_trail_marathon.parquet...
# Looking at run_for_the_ranch_marathon.parquet...
# Looking at rock_'n'_roll_country_music_marathon.parquet...
# Looking at first_call_spring_marathon.parquet...
# Looking at first_day_of_winter_marathon.parquet...
# Looking at meridian_marathon,_leo_run_to_remember.parquet...
# Looking at grand_rapids_marathon.parquet...
# Looking at nebraska_state_fair_marathon.parquet...
# Looking at rock_creek_park_marathon_and_relay.parquet...
# Looking at five_points_of_life_marathon.parquet...
# Looking at the_instant_classic_marathon_trail_run.parquet...
# Looking at provo_river_relay_marathon.parquet...

# %%
full_records.to_csv("/Users/thatcher/dev/analysis/projects/marathon_results/data/race_records_final.csv")

# %% [markdown]
# ## Profile boston_marathon.parquet from race_results (Before Processing)

# %%
# Load and profile boston_marathon.parquet from race_results (original)

boston_raw_file = os.path.join(race_results_path, "boston_marathon.parquet")

if os.path.exists(boston_raw_file):
    print("=" * 70)
    print("BOSTON MARATHON PROFILE (RAW DATA)")
    print("=" * 70)
    
    boston_raw_df = pd.read_parquet(boston_raw_file)
    
    # Basic information
    print(f"\nBasic Information:")
    print(f"  Shape: {boston_raw_df.shape[0]} rows × {boston_raw_df.shape[1]} columns")
    print(f"  Memory usage: {boston_raw_df.memory_usage(deep=True).sum() / (1024**2):.2f} MB")
    
    # Column overview
    print(f"\nColumns:")
    for col in boston_raw_df.columns:
        dtype = boston_raw_df[col].dtype
        null_count = boston_raw_df[col].isnull().sum()
        null_pct = (null_count / len(boston_raw_df)) * 100
        print(f"  {col:30} - {str(dtype):15} - {null_count:6} nulls ({null_pct:5.2f}%)")
    
    # Sample data
    print(f"\nSample Records (first 5):")
    print(boston_raw_df.head(5).to_string())
    
else:
    print(f"File not found: {boston_raw_file}")
# Out:
# ======================================================================
# BOSTON MARATHON PROFILE (RAW DATA)
# ======================================================================
#
# Basic Information:
#   Shape: 454282 rows × 13 columns
#
# Basic Information:
#   Shape: 454282 rows × 13 columns
#   Memory usage: 300.97 MB
#
# Columns:
#   Last Name, First Name (Sex/Age) - str             -      0 nulls ( 0.00%)
#   Time                           - str             -  72200 nulls (15.89%)
#   OverAllPlace                   - str             -      0 nulls ( 0.00%)
#   Sex Place/Div Place            - str             -  15400 nulls ( 3.39%)
#   DIV                            - str             -  66800 nulls (14.70%)
#   City, State, Country           - str             -  66800 nulls (14.70%)
#   AG Time*                       - str             -  66800 nulls (14.70%)
#   BQ*                            - str             -  29098 nulls ( 6.41%)
#   date                           - str             -      0 nulls ( 0.00%)
#   Net Time                       - str             - 220300 nulls (48.49%)
#   Sex Place                      - str             - 438882 nulls (96.61%)
#   Country                        - str             - 387482 nulls (85.30%)
#   race                           - str             -      0 nulls ( 0.00%)
#
# Sample Records (first 5):
#   Last Name, First Name (Sex/Age)     Time OverAllPlace Sex Place/Div Place     DIV City, State, Country AG Time* BQ*     date Net Time Sex Place Country             race
# 0            Paul A Sturgis (M47)  4:19:54        12401         8067 / 1543  M45-49    Palacios, TX, USA  3:59:03  BQ  4_16_12      NaN       NaN     NaN  boston_marathon
# 1             Alysia G Puma (F40)  4:19:54        12402          4335 / 820  F40-44  Flemington, NJ, USA  4:07:34  BQ  4_16_12      NaN       NaN     NaN  boston_marathon
# 2             Joanna Harmon (F45)  4:19:55        12403          4336 / 574  F45-49        Reno, NV, USA  3:54:17  BQ  4_16_12      NaN       NaN     NaN  boston_marathon
# 3          Nicole Hackbarth (F31)  4:19:55        12404         4337 / 2646   F0-39   Camarillo, CA, USA  4:19:30  BQ  4_16_12      NaN       NaN     NaN  boston_marathon
# 4             Kristin Pizzi (F30)  4:19:55        12405         4338 / 2647   F0-39   Watertown, MA, USA  4:19:48  BQ  4_16_12      NaN       NaN     NaN  boston_marathon
#   Memory usage: 300.97 MB
#
# Columns:
#   Last Name, First Name (Sex/Age) - str             -      0 nulls ( 0.00%)
#   Time                           - str             -  72200 nulls (15.89%)
#   OverAllPlace                   - str             -      0 nulls ( 0.00%)
#   Sex Place/Div Place            - str             -  15400 nulls ( 3.39%)
#   DIV                            - str             -  66800 nulls (14.70%)
#   City, State, Country           - str             -  66800 nulls (14.70%)
#   AG Time*                       - str             -  66800 nulls (14.70%)
#   BQ*                            - str             -  29098 nulls ( 6.41%)
#   date                           - str             -      0 nulls ( 0.00%)
#   Net Time                       - str             - 220300 nulls (48.49%)
#   Sex Place                      - str             - 438882 nulls (96.61%)
#   Country                        - str             - 387482 nulls (85.30%)
#   race                           - str             -      0 nulls ( 0.00%)
#
# Sample Records (first 5):
#   Last Name, First Name (Sex/Age)     Time OverAllPlace Sex Place/Div Place     DIV City, State, Country AG Time* BQ*     date Net Time Sex Place Country             race
# 0            Paul A Sturgis (M47)  4:19:54        12401         8067 / 1543  M45-49    Palacios, TX, USA  3:59:03  BQ  4_16_12      NaN       NaN     NaN  boston_marathon
# 1             Alysia G Puma (F40)  4:19:54        12402          4335 / 820  F40-44  Flemington, NJ, USA  4:07:34  BQ  4_16_12      NaN       NaN     NaN  boston_marathon
# 2             Joanna Harmon (F45)  4:19:55        12403          4336 / 574  F45-49        Reno, NV, USA  3:54:17  BQ  4_16_12      NaN       NaN     NaN  boston_marathon
# 3          Nicole Hackbarth (F31)  4:19:55        12404         4337 / 2646   F0-39   Camarillo, CA, USA  4:19:30  BQ  4_16_12      NaN       NaN     NaN  boston_marathon
# 4             Kristin Pizzi (F30)  4:19:55        12405         4338 / 2647   F0-39   Watertown, MA, USA  4:19:48  BQ  4_16_12      NaN       NaN     NaN  boston_marathon

# %%
# Examine all files in race_records and find those with None/missing age and sex

print("=" * 70)
print("EXAMINING RACE RECORDS FOR MISSING AGE AND SEX")
print("=" * 70)

if os.path.exists(race_records_home):
    race_record_files = [f for f in os.listdir(race_records_home) if f.endswith('.parquet')]
    print(f"\nTotal race record files: {len(race_record_files)}\n")
    
    files_with_issues = []
    
    for race_file in sorted(race_record_files):
        filepath = os.path.join(race_records_home, race_file)
        try:
            df = pd.read_parquet(filepath)
            
            # Check for None/null values in age and sex columns
            age_nulls = df['age'].isnull().sum()
            sex_nulls = df['sex'].isnull().sum()
            
            if age_nulls > 0 or sex_nulls > 0:
                files_with_issues.append({
                    'file': race_file,
                    'total_rows': len(df),
                    'age_nulls': age_nulls,
                    'sex_nulls': sex_nulls,
                    'age_null_pct': (age_nulls / len(df)) * 100,
                    'sex_null_pct': (sex_nulls / len(df)) * 100
                })
        except Exception as e:
            print(f"Error reading {race_file}: {str(e)}")
    
    # Display results
    if len(files_with_issues) > 0:
        print(f"Found {len(files_with_issues)} files with missing age/sex:\n")
        print(f"{'File':<50} {'Total Rows':>12} {'Age Nulls':>12} {'Sex Nulls':>12}")
        print("-" * 88)
        
        for issue in files_with_issues:
            print(f"{issue['file']:<50} {issue['total_rows']:>12} {issue['age_nulls']:>12} ({issue['age_null_pct']:>5.2f}%) {issue['sex_nulls']:>6} ({issue['sex_null_pct']:>5.2f}%)")
        
        # Summary
        total_affected_rows = sum([i['age_nulls'] + i['sex_nulls'] for i in files_with_issues])
        print("-" * 88)
        print(f"\nSummary:")
        print(f"  Files with issues: {len(files_with_issues)}/{len(race_record_files)}")
        print(f"  Total affected records: {total_affected_rows}")
    else:
        print(f"✓ All {len(race_record_files)} files have complete age and sex data!")
else:
    print(f"race_records directory not found: {race_records_home}")
# Out:
# ======================================================================
# EXAMINING RACE RECORDS FOR MISSING AGE AND SEX
# ======================================================================
#
# Total race record files: 1817
#
# Found 1811 files with missing age/sex:
#
# File                                                 Total Rows    Age Nulls    Sex Nulls
# ----------------------------------------------------------------------------------------
# "last_chance_for_boston"_marathon.parquet                  1402         1402 (100.00%)   1402 (100.00%)
# "running_for_the_bay!"_marathon.parquet                    1279         1279 (100.00%)   1279 (100.00%)
# 11-11-11_marathon_of_sarasota.parquet                        66           66 (100.00%)     66 (100.00%)
# 2004_usa_olympic_team_trials_-_men's_marathon.parquet           71           71 (100.00%)     71 (100.00%)
# 2004_usa_olympic_team_trials_-_women's_marathon.parquet          200          200 (100.00%)    200 (100.00%)
# 2008_u.s._olympic_team_trials_-_men's_marathon.parquet          200          200 (100.00%)    200 (100.00%)
# 2012_u.s._olympic_team_trials_-_men's_marathon.parquet           85           85 (100.00%)     85 (100.00%)
# 2012_u.s._olympic_team_trials_-_women's_marathon.parquet          200          200 (100.00%)    200 (100.00%)
# 2014_commonwealth_games_marathon_-_men.parquet               24           24 (100.00%)     24 (100.00%)
# 2014_commonwealth_games_marathon_-_women.parquet             17           17 (100.00%)     17 (100.00%)
# 2016_u.s._olympic_team_trials_-_men's_marathon.parquet          200          200 (100.00%)    200 (100.00%)
# 2016_u.s._olympic_team_trials_-_women's_marathon.parquet          200          200 (100.00%)    200 (100.00%)
# 2018_commonwealth_games_-_men.parquet                        17           17 (100.00%)     17 (100.00%)
# 2018_commonwealth_games_-_women.parquet                      16           16 (100.00%)     16 (100.00%)
# 2019_pan_american_games_marathon_-_men's.parquet             16           16 (100.00%)     16 (100.00%)
# 2019_pan_american_games_marathon_-_women's.parquet           16           16 (100.00%)     16 (100.00%)
# 2020_australia_olympic_team_trials.parquet                    7            7 (100.00%)      7 (100.00%)
# 2020_g.b._olympic_team_trials_-_men's_marathon.parquet           12           12 (100.00%)     12 (100.00%)
# 2020_g.b._olympic_team_trials_-_women's_marathon.parquet            8            8 (100.00%)      8 (100.00%)
# 2020_u.s._olympic_team_trials_-_men's_marathon.parquet          200          200 (100.00%)    200 (100.00%)
# 2020_u.s._olympic_team_trials_-_women's_marathon.parquet          400          400 (100.00%)    400 (100.00%)
# 2022_commonwealth_games_-_men.parquet                        17           17 (100.00%)     17 (100.00%)
# 2022_commonwealth_games_-_women.parquet                      16           16 (100.00%)     16 (100.00%)
# 2022_european_marathon_championships_-_men.parquet           62           62 (100.00%)     62 (100.00%)
# 2022_european_marathon_championships_-_women.parquet           52           52 (100.00%)     52 (100.00%)
# 2022_new_zealand_marathon_championships.parquet              31           31 (100.00%)     31 (100.00%)
# 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer.parquet        15100        15100 (100.00%)  15100 (100.00%)
# 3_bridges_marathon.parquet                                 2700         2700 (100.00%)   2700 (100.00%)
# 3_marathons_in_3_days_-_day_1.parquet                        84           84 (100.00%)     84 (100.00%)
# 3_marathons_in_3_days_-_day_2.parquet                        79           79 (100.00%)     79 (100.00%)
# 3_marathons_in_3_days_-_day_3.parquet                        52           52 (100.00%)     52 (100.00%)
# 3rd_marshall_university_marathon.parquet                    500          500 (100.00%)    500 (100.00%)
# a2a_arbuckles_to_ardmore_race_for_mercy.parquet            1419         1419 (100.00%)   1419 (100.00%)
# a_run_through_time.parquet                                 2899         2899 (100.00%)   2899 (100.00%)
# abebe_bikila_day_international_peace_marathon.parquet         1805         1805 (100.00%)   1805 (100.00%)
# achilles_marathon.parquet                                    48           48 (100.00%)     48 (100.00%)
# adams_county_marathon.parquet                               129          129 (100.00%)    129 (100.00%)
# adelaide_festival_city_marathon.parquet                    8300         8300 (100.00%)   8300 (100.00%)
# adirondack_marathon.parquet                                5793         5793 (100.00%)   5793 (100.00%)
# air_force_marathon.parquet                                36883        36883 (100.00%)  36883 (100.00%)
# air_new_zealand_queenstown_international_marathon.parquet        12600        12600 (100.00%)  12597 (99.98%)
# akron_marathon.parquet                                    21998        21998 (100.00%)  21998 (100.00%)
# alaska_series_-_day_1.parquet                                58           58 (100.00%)     58 (100.00%)
# alaska_series_-_day_2.parquet                                46           46 (100.00%)     46 (100.00%)
# alaska_series_-_day_3.parquet                                59           59 (100.00%)     59 (100.00%)
# alaska_series_-_day_4.parquet                                36           36 (100.00%)     36 (100.00%)
# albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon).parquet         6100         6100 (100.00%)   6100 (100.00%)
# alice_springs_marathon.parquet                              410          410 (100.00%)    410 (100.00%)
# all-out_beat_the_heat_marathon.parquet                      359          359 (100.00%)    359 (100.00%)
# all-out_fallfest_marathon.parquet                           327          327 (100.00%)    327 (100.00%)
# all_american_marathon.parquet                              3996         3996 (100.00%)   3996 (100.00%)
# almond_bowl_marathon.parquet                                146          146 (100.00%)    146 (100.00%)
# aloha_series_-_day_1.parquet                                 51           51 (100.00%)     51 (100.00%)
# aloha_series_-_day_2.parquet                                 33           33 (100.00%)     33 (100.00%)
# aloha_series_-_day_3.parquet                                 29           29 (100.00%)     29 (100.00%)
# aloha_series_-_day_4.parquet                                 33           33 (100.00%)     33 (100.00%)
# alpharetta_marathon.parquet                                 300          300 (100.00%)    300 (100.00%)
# american_birkebeiner_trail_run.parquet                     1083         1083 (100.00%)   1083 (100.00%)
# american_discovery_trail_marathon.parquet                  5700         5700 (100.00%)   5700 (100.00%)
# american_heroes_run.parquet                                  66           66 (100.00%)     66 (100.00%)
# anchorage_runfest_humpy's_marathon_(prev._big_wild_life_runs_marathon).parquet          500          500 (100.00%)    500 (100.00%)
# andrew_jackson_marathon.parquet                            1546         1546 (100.00%)   1546 (100.00%)
# andy_payne_marathon.parquet                                1006         1006 (100.00%)   1006 (100.00%)
# angel_fire_adventure_marathon.parquet                       186          186 (100.00%)    186 (100.00%)
# ann_arbor_marathon.parquet                                 4000         4000 (100.00%)   4000 (100.00%)
# antarctic_ice_marathon.parquet                              438          438 (100.00%)    438 (100.00%)
# cayman_islands_marathon.parquet                            1437         1437 (100.00%)   1437 (100.00%)
# center_of_the_nation_marathon_-_colorado.parquet            224          224 (100.00%)    224 (100.00%)
# center_of_the_nation_marathon_-_montana.parquet             641          641 (100.00%)    641 (100.00%)
# center_of_the_nation_marathon_-_nebraska.parquet            618          618 (100.00%)    618 (100.00%)
# center_of_the_nation_marathon_-_north_dakota.parquet          641          641 (100.00%)    641 (100.00%)
# center_of_the_nation_marathon_-_south_dakota.parquet          646          646 (100.00%)    646 (100.00%)
# center_of_the_nation_marathon_-_wyoming.parquet             674          674 (100.00%)    674 (100.00%)
# central_park_marathon.parquet                              1200         1200 (100.00%)   1200 (100.00%)
# central_states_marathon.parquet                             174          174 (100.00%)    174 (100.00%)
# century_marathon.parquet                                     87           87 (100.00%)     87 (100.00%)
# charles_river_marathon.parquet                             1161         1161 (100.00%)   1161 (100.00%)
# charleston_marathon.parquet                                8400         8400 (100.00%)   8400 (100.00%)
# charleston_salmon_run.parquet                                37           37 (100.00%)     37 (100.00%)
# charlevoix_marathon.parquet                                4000         4000 (100.00%)   4000 (100.00%)
# charlotte's_thunder_road_marathon.parquet                 17495        17495 (100.00%)  17495 (100.00%)
# charlotte_marathon.parquet                                 3100         3100 (100.00%)   3100 (100.00%)
# charlottesville_marathon.parquet                           6800         6800 (100.00%)   6800 (100.00%)
# chasing_the_unicorn.parquet                                1214         1214 (100.00%)   1214 (100.00%)
# chelmsford_parks_marathon.parquet                          5700         5700 (100.00%)   5700 (100.00%)
# cherry_blossom_festival_marathon.parquet                   1199         1199 (100.00%)   1199 (100.00%)
# chesapeake_bay_bridge_marathon.parquet                     1499         1499 (100.00%)   1499 (100.00%)
# chessie_trail_marathon.parquet                              178          178 (100.00%)    178 (100.00%)
# chester_marathon.parquet                                  29258        29258 (100.00%)  29258 (100.00%)
# cheyenne_marathon:_run_the_legend.parquet                   461          461 (100.00%)    461 (100.00%)
# chicago_marathon.parquet                                 797446       797446 (100.00%) 797435 (100.00%)
# chicagoland_marathon.parquet                               4800         4800 (100.00%)   4797 (99.94%)
# chickamauga_battlefield_marathon.parquet                   8899         8899 (100.00%)   8899 (100.00%)
# chili_pepper_series_-_day_1.parquet                          68           68 (100.00%)     68 (100.00%)
# chili_pepper_series_-_day_2.parquet                          56           56 (100.00%)     56 (100.00%)
# chili_pepper_series_-_day_3.parquet                          13           13 (100.00%)     13 (100.00%)
# chili_pepper_series_-_day_4.parquet                          12           12 (100.00%)     12 (100.00%)
# china_coast_marathon.parquet                               5100         5100 (100.00%)   5100 (100.00%)
# chisholm_trail_marathon.parquet                             200          200 (100.00%)    200 (100.00%)
# chosen:_marathon_for_adoption.parquet                      1000         1000 (100.00%)   1000 (100.00%)
# chris_jarvis_autumn_river_run.parquet                        58           58 (100.00%)     58 (100.00%)
# christmas_marathon.parquet                                  509          509 (100.00%)    509 (100.00%)
# chronicle_marathon.parquet                                 2400         2400 (100.00%)   2400 (100.00%)
# cincinnati_flying_pig_marathon.parquet                    87083        87083 (100.00%)  87081 (100.00%)
# day_of_the_dead_marathon_series_day_4.parquet                83           83 (100.00%)     83 (100.00%)
# day_of_the_dead_marathon_series_day_5.parquet                30           30 (100.00%)     30 (100.00%)
# day_of_the_dead_marathon_series_day_6.parquet                24           24 (100.00%)     24 (100.00%)
# day_of_the_dead_marathon_series_day_7-_el_maraton_del_rio_grande.parquet           43           43 (100.00%)     43 (100.00%)
# day_of_the_tread_marathon.parquet                           117          117 (100.00%)    117 (100.00%)
# deadwood-mickelson_trail_marathon.parquet                  6575         6575 (100.00%)   6574 (99.98%)
# death_valley_borax_marathon.parquet                        2617         2617 (100.00%)   2617 (100.00%)
# death_valley_trail_marathon.parquet                        4055         4055 (100.00%)   4055 (100.00%)
# delaware_&_lehigh_heritage_marathon.parquet                 700          700 (100.00%)    700 (100.00%)
# delaware_marathon.parquet                                  9000         9000 (100.00%)   9000 (100.00%)
# delaware_trail_marathon_(formerly_the_triple_crown_trail_marathon).parquet          449          449 (100.00%)    449 (100.00%)
# deloitte_challenge_kzn_durban_city_marathon.parquet          800          800 (100.00%)    800 (100.00%)
# denver_marathon_(2000-2004).parquet                        1100         1100 (100.00%)   1100 (100.00%)
# des_moines_marathon.parquet                               26797        26797 (100.00%)  26797 (100.00%)
# des_moines_st._paddy's_marathon.parquet                     340          340 (100.00%)    340 (100.00%)
# des_plaines_river_trail_marathon.parquet                   2937         2937 (100.00%)   2937 (100.00%)
# deseret_marathon.parquet                                    700          700 (100.00%)    700 (100.00%)
# deseret_news_classic_marathon.parquet                      4800         4800 (100.00%)   4800 (100.00%)
# desert_classic_marathon.parquet                            2622         2622 (100.00%)   2622 (100.00%)
# desert_rats_trail_running_festival.parquet                  166          166 (100.00%)    166 (100.00%)
# destin_marathon.parquet                                     300          300 (100.00%)    300 (100.00%)
# detroit_free_press_international_marathon.parquet         35297        35297 (100.00%)  35296 (100.00%)
# detroit_international_marathon.parquet                    36099        36099 (100.00%)  36097 (99.99%)
# devil_after_dark_marathon.parquet                           155          155 (100.00%)    155 (100.00%)
# devil_after_dark_marathon_-_morning.parquet                  16           16 (100.00%)     16 (100.00%)
# diablo_marathon_&_50_mile_endurance_run.parquet             350          350 (100.00%)    350 (100.00%)
# diablo_trail_marathon.parquet                               275          275 (100.00%)    275 (100.00%)
# diamond_valley_lake_challenge.parquet                      1172         1172 (100.00%)   1172 (100.00%)
# dick's_greater_binghamton_marathon.parquet                  397          397 (100.00%)    397 (100.00%)
# dick_beardsley_marathon.parquet                             400          400 (100.00%)    400 (100.00%)
# dingle_marathon.parquet                                    5592         5592 (100.00%)   5592 (100.00%)
# dirty_south_marathon.parquet                                400          400 (100.00%)    400 (100.00%)
# disney_world_marathon.parquet                            290029       290029 (100.00%) 290027 (100.00%)
# dog_lake_marathon.parquet                                   189          189 (100.00%)    189 (100.00%)
# dolittle_marathon.parquet                                   475          475 (100.00%)    475 (100.00%)
# dorchester_marathon.parquet                                 700          700 (100.00%)    700 (100.00%)
# double_decker_marathon.parquet                               48           48 (100.00%)     48 (100.00%)
# downtown_river_run_marathon.parquet                         588          588 (100.00%)    588 (100.00%)
# drake_well_marathon.parquet                                1315         1315 (100.00%)   1315 (100.00%)
# driftless_trail_marathon.parquet                             58           58 (100.00%)     58 (100.00%)
# duchy_marathon.parquet                                     1999         1999 (100.00%)   1999 (100.00%)
# duke_city_marathon.parquet                                 9198         9198 (100.00%)   9198 (100.00%)
# dundee_running_adventure_marathon_(dram).parquet            100          100 (100.00%)    100 (100.00%)
# dunedin_marathon.parquet                                    400          400 (100.00%)    400 (100.00%)
# dupont_city_trail_marathon.parquet                          214          214 (100.00%)    214 (100.00%)
# dupont_forest_trail_marathon.parquet                        600          600 (100.00%)    600 (100.00%)
# durango_marathon.parquet                                   1351         1351 (100.00%)   1351 (100.00%)
# dust_bowl_series_marathon_-_colorado.parquet                353          353 (100.00%)    353 (100.00%)
# dust_bowl_series_marathon_-_kansas.parquet                  389          389 (100.00%)    389 (100.00%)
# dust_bowl_series_marathon_-_new_mexico.parquet              369          369 (100.00%)    369 (100.00%)
# dust_bowl_series_marathon_-_oklahoma.parquet                358          358 (100.00%)    358 (100.00%)
# dust_bowl_series_marathon_-_texas.parquet                   279          279 (100.00%)    279 (100.00%)
# dust_bowl_series_marathon_-_texas_ii.parquet                 22           22 (100.00%)     22 (100.00%)
# dutchess_county_classic_marathon.parquet                    518          518 (100.00%)    518 (100.00%)
# dutchess_county_marathon.parquet                             67           67 (100.00%)     67 (100.00%)
# eagle_creek_marathon.parquet                                200          200 (100.00%)    200 (100.00%)
# eagle_creek_trail_marathon.parquet                         1232         1232 (100.00%)   1232 (100.00%)
# earth_day_challenge.parquet                                 300          300 (100.00%)    300 (100.00%)
# earth_day_challenge_marathon.parquet                        347          347 (100.00%)    347 (100.00%)
# earth_rock_run.parquet                                      200          200 (100.00%)    200 (100.00%)
# east_canyon_marathon.parquet                                514          514 (100.00%)    514 (100.00%)
# east_lyme_marathon.parquet                                  200          200 (100.00%)    200 (100.00%)
# easter_bunny_marathon.parquet                                31           31 (100.00%)     31 (100.00%)
# easter_marathon_runoff.parquet                              176          176 (100.00%)    176 (100.00%)
# eastern_panhandle.parquet                                    31           31 (100.00%)     31 (100.00%)
# easy_street_marathon.parquet                                900          900 (100.00%)    900 (100.00%)
# eau_claire_marathon.parquet                                5900         5900 (100.00%)   5900 (100.00%)
# echo_valley_marathon.parquet                                 27           27 (100.00%)     27 (100.00%)
# edge_to_edge_marathon.parquet                              2567         2567 (100.00%)   2567 (100.00%)
# edinburgh_marathon.parquet                                77393        77393 (100.00%)  77393 (100.00%)
# edmonton_centennial_marathon.parquet                       2800         2800 (100.00%)   2800 (100.00%)
# edmonton_festival_marathon.parquet                         2500         2500 (100.00%)   2500 (100.00%)
# edmonton_marathon.parquet                                  7299         7299 (100.00%)   7298 (99.99%)
# eisenbahn_marathon.parquet                                  988          988 (100.00%)    988 (100.00%)
# eisenhower_marathon.parquet                                3396         3396 (100.00%)   3396 (100.00%)
# el_paso_marathon.parquet                                   5373         5373 (100.00%)   5373 (100.00%)
# elands_marathon.parquet                                    1100         1100 (100.00%)   1100 (100.00%)
