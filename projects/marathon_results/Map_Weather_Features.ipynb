# %%
import pandas as pd
import pandas as pd
from datetime import datetime, timedelta

WEATHER_DATA = "data/weather_data_v2.csv"
RACE_DATA = "data/race_final/global/data.csv"

weather_data = pd.read_csv(WEATHER_DATA, parse_dates=['date'])
weather_dfs = {(city, state): group \
                    for (city, state), group in weather_data.groupby(["city","state"])}

race_df = pd.read_csv(RACE_DATA, parse_dates=['date'])

def parse_date_column(col:str) -> datetime:
    (month, day, year) = col.split("_")
    return datetime(int("20"+year), int(month), int(day))

race_df["date"] = race_df["date"].apply(parse_date_column)
race_df.head()
# Out:
# /var/folders/g1/1dxws3zs1djd1ytsd2h9g9wh0000gn/T/ipykernel_1814/1898060491.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   race_df = pd.read_csv(RACE_DATA, parse_dates=['date'])
#     age sex        time               race       date             city state
# 0  50.0   M  181.650000  dog_lake_marathon 2016-10-15  apache junction    az
# 1  39.0   M  188.566667  dog_lake_marathon 2016-10-15        kennewick    wa
# 2  27.0   M  196.483333  dog_lake_marathon 2016-10-15           yakima    wa
# 3  33.0   M  218.666667  dog_lake_marathon 2016-10-15             mesa    az
# 4  26.0   F  219.016667  dog_lake_marathon 2016-10-15       costa mesa    ca

# %%
EARLIEST_WEATHER = weather_data["date"].min()
print(f"Earliest weather date: {EARLIEST_WEATHER}")
race_df_filtered_date = race_df[race_df["date"] > EARLIEST_WEATHER + timedelta(days=365)]
print(f"date filtering: filtered {len(race_df) - len(race_df_filtered_date):,} records, {len(race_df_filtered_date):,} remain")
# Out:
# Earliest weather date: 1999-01-01 00:00:00
# date filtering: filtered 0 records, 7,411,671 remain

# %%
available_weather_cities = weather_dfs.keys()

# Create a set of lowercase (city, state) tuples for fast lookup
available_weather_cities_lower = {(city.lower(), state.lower()) for (city, state) in available_weather_cities}

# Filter to only records with matching weather data
race_df_filtered = race_df_filtered_date[
    race_df_filtered_date.apply(
        lambda row: (row['city'], row['state']) in available_weather_cities_lower, 
        axis=1
    )
]

print(f"Weather city filtering: filtered {len(race_df_filtered_date) - len(race_df_filtered):,} records, {len(race_df_filtered):,} remain")
race_df_filtered.head()
# Out:
# Weather city filtering: filtered 5,721,668 records, 1,690,003 remain
#      age sex        time               race       date       city state
# 7   44.0   F  226.316667  dog_lake_marathon 2016-10-15    seattle    wa
# 8   52.0   M  230.700000  dog_lake_marathon 2016-10-15  vancouver    wa
# 13  62.0   M  239.766667  dog_lake_marathon 2016-10-15    seattle    wa
# 16  39.0   F  248.383333  dog_lake_marathon 2016-10-15   portland    or
# 31  39.0   M  184.550000  dog_lake_marathon 2015-10-24    seattle    wa

# %%
import src.iterator

import importlib
importlib.reload(src.iterator)

from src.iterator import CheckpointIterator

def handle_race(race_meta:tuple[str,str], group:list):
    (race, race_date_dt) = race_meta
    output_data = []
    cities = group.groupby(["city","state"])
    print(f"examining {race}-{race_date_dt}, {len(group)} records, {len(cities)} cities")

    for (city, state), records in group.groupby(["city","state"]):
        lookup = (city.lower(), state.lower())
        if lookup not in weather_dfs:
            print(f"--skipping, no weather data for {city} {state}")
            continue

        weather_records = weather_dfs[lookup]
        full_training_early_date = race_date_dt - timedelta(days=90)
        peak_training_early_date = race_date_dt - timedelta(days=30)

        full_training_records = weather_records[weather_records["date"].between(full_training_early_date, race_date_dt, inclusive='left')]
        peak_training_records = weather_records[weather_records["date"].between(peak_training_early_date, race_date_dt, inclusive='left')]
        
        if len(full_training_records) <= 5 or len(peak_training_records) <= 5:
            print(f"skipping, not enough weather data on {race_date_dt}")
            continue
        
        for period, weather_records in zip(["full","peak"], [full_training_records, peak_training_records]):
            overall_min = weather_records["temp_min"].min()
            overall_max = weather_records["temp_max"].max()
            overall_median_min = weather_records["temp_min"].median()
            overall_median_max = weather_records["temp_max"].median()
            overall_rain = weather_records["precip"].sum()
            overall_days_of_rain = len(weather_records[weather_records["precip"] > 0.2])

            weekend_days = weather_records[weather_records["date"].dt.dayofweek.isin([5, 6])]
            overall_weekend_days_with_rain = len(weekend_days[weekend_days["precip"] > 0.2])
            
            records[period+"_temp_min"] = overall_min
            records[period+"_temp_max"] = overall_max
            records[period+"_temp_median_min"] = overall_median_min
            records[period+"_temp_median_max"] = overall_median_max
            records[period+"_overall_precip"] = overall_rain
            records[period+"_overall_days_of_precip"] = overall_days_of_rain
            records[period+"_overall_weekend_days_of_precip"] = overall_weekend_days_with_rain
        
        output_data.append(records)
    return output_data

iterator = CheckpointIterator(
    items = race_df_filtered.groupby(["race","date"]),
    item_key= lambda x:x[0],
    process_func = handle_race,
    output_path="data/featurized_race_data_v2a.csv",
    key_fields=["race","date"]
)

featurized_df = iterator.process()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[22], line 53
#      50         output_data.append(records)
#      51     return output_data
# ---> 53 iterator = CheckpointIterator(
#      54     items = race_df_filtered.groupby(["race","date"]),
#      55     item_key= lambda x:x[0],
#      56     process_func = handle_race,
#      57     output_path="data/featurized_race_data_v2a.csv",
#      58     key_fields=["race","date"]
#      59 )
#      61 featurized_df = iterator.process()
#
# File ~/dev/analysis/projects/marathon_results/src/iterator.py:44, in CheckpointIterator.__init__(self, items, item_key, process_func, output_path, checkpoint_every, key_fields)
#      42 self.results = []
#      43 self.completed_keys = set()
# ---> 44 self._load_existing()
#
# File ~/dev/analysis/projects/marathon_results/src/iterator.py:49, in CheckpointIterator._load_existing(self)
#      47 """Load existing results if the file exists."""
#      48 if self.output_path.exists():
# ---> 49     existing_df = pd.read_csv(self.output_path)
#      50     self.results = existing_df.to_dict('records')
#      52     # Track completed items by key fields
#
# File ~/dev/analysis/projects/marathon_results/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/dev/analysis/projects/marathon_results/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/dev/analysis/projects/marathon_results/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/dev/analysis/projects/marathon_results/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1919     raise ValueError(msg)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#    1924     if self.handles is not None:
#
# File ~/dev/analysis/projects/marathon_results/.venv/lib/python3.13/site-packages/pandas/io/parsers/c_parser_wrapper.py:95, in CParserWrapper.__init__(self, src, **kwds)
#      92 if kwds["dtype_backend"] == "pyarrow":
#      93     # Fail here loudly instead of in cython after reading
#      94     import_optional_dependency("pyarrow")
# ---> 95 self._reader = parsers.TextReader(src, **kwds)
#      97 self.unnamed_cols = self._reader.unnamed_cols
#      99 passed_names = self.names is None
#
# File pandas/_libs/parsers.pyx:575, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
output_data = []
for (race, race_date_dt), group in race_df_filtered.groupby(["race","date"]):
    cities = group.groupby(["city","state"])
    print(f"examining {race}-{race_date_dt}, {len(group)} records, {len(cities)} cities")

    for (city, state), records in group.groupby(["city","state"]):
        lookup = (city.lower(), state.lower())
        if lookup not in weather_dfs:
            print(f"--skipping, no weather data for {city} {state}")
            continue

        weather_records = weather_dfs[lookup]
        full_training_early_date = race_date_dt - timedelta(days=90)
        peak_training_early_date = race_date_dt - timedelta(days=30)

        full_training_records = weather_records[weather_records["date"].between(full_training_early_date, race_date_dt, inclusive='left')]
        peak_training_records = weather_records[weather_records["date"].between(peak_training_early_date, race_date_dt, inclusive='left')]
        
        if len(full_training_records) <= 5 or len(peak_training_records) <= 5:
            print(f"skipping, not enough weather data on {race_date_dt}")
            continue
        
        for period, weather_records in zip(["full","peak"], [full_training_records, peak_training_records]):
            overall_min = weather_records["temp_min"].min()
            overall_max = weather_records["temp_max"].max()
            overall_median_min = weather_records["temp_min"].median()
            overall_median_max = weather_records["temp_max"].median()
            overall_rain = weather_records["precip"].sum()
            overall_days_of_rain = len(weather_records[weather_records["precip"] > 0.2])

            weekend_days = weather_records[weather_records["date"].dt.dayofweek.isin([5, 6])]
            overall_weekend_days_with_rain = len(weekend_days[weekend_days["precip"] > 0.2])
            
            records[period+"_temp_min"] = overall_min
            records[period+"_temp_max"] = overall_max
            records[period+"_temp_median_min"] = overall_median_min
            records[period+"_temp_median_max"] = overall_median_max
            records[period+"_overall_precip"] = overall_rain
            records[period+"_overall_days_of_precip"] = overall_days_of_rain
            records[period+"_overall_weekend_days_of_precip"] = overall_weekend_days_with_rain
        
        output_data.append(records)

featurized_frame = pd.concat(output_data)
# Out:
# examining "last_chance_for_boston"_marathon-2003-02-02 00:00:00, 18 records, 9 cities
# examining "last_chance_for_boston"_marathon-2004-02-01 00:00:00, 22 records, 9 cities
# examining "last_chance_for_boston"_marathon-2005-02-20 00:00:00, 18 records, 7 cities
# examining "last_chance_for_boston"_marathon-2007-02-11 00:00:00, 28 records, 3 cities
# examining "last_chance_for_boston"_marathon-2010-02-28 00:00:00, 26 records, 6 cities
# examining "last_chance_for_boston"_marathon-2011-02-27 00:00:00, 8 records, 3 cities
# examining "last_chance_for_boston"_marathon-2012-02-26 00:00:00, 12 records, 3 cities
# examining "last_chance_for_boston"_marathon-2016-02-21 00:00:00, 10 records, 3 cities
# examining "running_for_the_bay!"_marathon-2010-10-23 00:00:00, 38 records, 13 cities
# examining "running_for_the_bay!"_marathon-2011-10-23 00:00:00, 19 records, 7 cities
# examining "running_for_the_bay!"_marathon-2012-10-21 00:00:00, 12 records, 6 cities
# examining "running_for_the_bay!"_marathon-2013-10-20 00:00:00, 5 records, 3 cities
# examining "running_for_the_bay!"_marathon-2014-10-26 00:00:00, 8 records, 5 cities
# examining "running_for_the_bay!"_marathon-2015-10-18 00:00:00, 30 records, 7 cities
# examining "running_for_the_bay!"_marathon-2016-10-23 00:00:00, 18 records, 4 cities
# examining "running_for_the_bay!"_marathon-2017-10-22 00:00:00, 5 records, 5 cities
# examining "running_for_the_bay!"_marathon-2019-10-20 00:00:00, 2 records, 2 cities
# examining 11-11-11_marathon_of_sarasota-2011-11-11 00:00:00, 12 records, 7 cities
# examining 2004_usa_olympic_team_trials_-_men's_marathon-2004-02-07 00:00:00, 22 records, 16 cities
# examining 2004_usa_olympic_team_trials_-_women's_marathon-2004-04-03 00:00:00, 40 records, 15 cities
# examining 2008_u.s._olympic_team_trials_-_men's_marathon-2007-11-03 00:00:00, 59 records, 20 cities
# examining 2012_u.s._olympic_team_trials_-_men's_marathon-2012-01-14 00:00:00, 25 records, 11 cities
# examining 2012_u.s._olympic_team_trials_-_women's_marathon-2012-01-14 00:00:00, 57 records, 24 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2009-02-15 00:00:00, 427 records, 32 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2010-02-21 00:00:00, 577 records, 43 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2011-02-13 00:00:00, 508 records, 38 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2012-02-12 00:00:00, 151 records, 30 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2013-02-17 00:00:00, 107 records, 35 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2014-02-23 00:00:00, 51 records, 26 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2015-02-15 00:00:00, 53 records, 18 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2016-02-14 00:00:00, 36 records, 16 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2017-02-12 00:00:00, 294 records, 19 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2018-02-11 00:00:00, 265 records, 20 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2019-02-10 00:00:00, 244 records, 17 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2022-02-06 00:00:00, 134 records, 13 cities
# examining 26.2_with_donna:_the_national_marathon_to_finish_breast_cancer-2023-02-05 00:00:00, 146 records, 15 cities
# examining 3_bridges_marathon-2015-12-19 00:00:00, 27 records, 21 cities
# examining 3_bridges_marathon-2016-12-17 00:00:00, 25 records, 17 cities
# examining 3_bridges_marathon-2017-12-16 00:00:00, 23 records, 11 cities
# examining 3_bridges_marathon-2018-12-15 00:00:00, 32 records, 18 cities
# examining 3_bridges_marathon-2019-12-28 00:00:00, 13 records, 11 cities
# examining 3_bridges_marathon-2022-12-10 00:00:00, 8 records, 6 cities
# examining 3_bridges_marathon-2023-12-09 00:00:00, 7 records, 7 cities
# examining 3rd_marshall_university_marathon-2017-11-05 00:00:00, 41 records, 17 cities
# examining a2a_arbuckles_to_ardmore_race_for_mercy-2010-03-28 00:00:00, 42 records, 3 cities
# examining a2a_arbuckles_to_ardmore_race_for_mercy-2013-03-03 00:00:00, 18 records, 8 cities
# examining a2a_arbuckles_to_ardmore_race_for_mercy-2014-03-30 00:00:00, 50 records, 8 cities
# examining a2a_arbuckles_to_ardmore_race_for_mercy-2015-03-29 00:00:00, 20 records, 6 cities
# examining a2a_arbuckles_to_ardmore_race_for_mercy-2016-03-20 00:00:00, 39 records, 4 cities
# examining a2a_arbuckles_to_ardmore_race_for_mercy-2017-03-26 00:00:00, 21 records, 8 cities
# examining a2a_arbuckles_to_ardmore_race_for_mercy-2018-03-25 00:00:00, 26 records, 11 cities
# examining a2a_arbuckles_to_ardmore_race_for_mercy-2019-03-31 00:00:00, 29 records, 7 cities
# examining a_run_through_time-2006-03-18 00:00:00, 8 records, 3 cities
# examining a_run_through_time-2007-03-17 00:00:00, 18 records, 4 cities
# examining a_run_through_time-2009-03-14 00:00:00, 21 records, 5 cities
# examining a_run_through_time-2010-03-13 00:00:00, 73 records, 7 cities
# examining a_run_through_time-2011-03-12 00:00:00, 75 records, 5 cities
# examining a_run_through_time-2012-03-10 00:00:00, 69 records, 5 cities
# examining a_run_through_time-2013-03-09 00:00:00, 80 records, 4 cities
# examining a_run_through_time-2015-03-14 00:00:00, 59 records, 4 cities
# examining a_run_through_time-2016-03-12 00:00:00, 56 records, 6 cities
# examining a_run_through_time-2017-03-18 00:00:00, 36 records, 8 cities
# examining a_run_through_time-2019-03-09 00:00:00, 51 records, 6 cities
# examining a_run_through_time-2020-10-11 00:00:00, 23 records, 4 cities
# examining a_run_through_time-2021-03-20 00:00:00, 73 records, 6 cities
# examining abebe_bikila_day_international_peace_marathon-2013-09-14 00:00:00, 39 records, 10 cities
# examining abebe_bikila_day_international_peace_marathon-2014-09-13 00:00:00, 67 records, 15 cities
# examining abebe_bikila_day_international_peace_marathon-2015-09-12 00:00:00, 62 records, 13 cities
# examining abebe_bikila_day_international_peace_marathon-2016-09-10 00:00:00, 64 records, 12 cities
# examining abebe_bikila_day_international_peace_marathon-2017-09-16 00:00:00, 61 records, 13 cities
# examining abebe_bikila_day_international_peace_marathon-2018-09-08 00:00:00, 61 records, 11 cities
# examining abebe_bikila_day_international_peace_marathon-2019-09-07 00:00:00, 79 records, 15 cities
# examining abebe_bikila_day_international_peace_marathon-2020-09-12 00:00:00, 10 records, 7 cities
# examining abebe_bikila_day_international_peace_marathon-2021-09-11 00:00:00, 38 records, 14 cities
# examining abebe_bikila_day_international_peace_marathon-2022-09-10 00:00:00, 63 records, 11 cities
# examining abebe_bikila_day_international_peace_marathon-2023-09-09 00:00:00, 88 records, 12 cities
# examining achilles_marathon-2002-04-28 00:00:00, 19 records, 4 cities
# examining adams_county_marathon-2015-09-26 00:00:00, 6 records, 2 cities
# examining adams_county_marathon-2016-09-24 00:00:00, 5 records, 3 cities
# examining adirondack_marathon-2000-09-24 00:00:00, 20 records, 9 cities
# examining adirondack_marathon-2001-09-23 00:00:00, 17 records, 11 cities
# examining adirondack_marathon-2002-09-22 00:00:00, 13 records, 6 cities
# examining adirondack_marathon-2003-09-28 00:00:00, 25 records, 10 cities
# examining adirondack_marathon-2004-09-26 00:00:00, 13 records, 8 cities
# examining adirondack_marathon-2005-09-25 00:00:00, 26 records, 7 cities
# examining adirondack_marathon-2006-09-17 00:00:00, 33 records, 12 cities
# examining adirondack_marathon-2007-09-16 00:00:00, 26 records, 10 cities
# examining adirondack_marathon-2009-09-20 00:00:00, 21 records, 10 cities
# examining adirondack_marathon-2010-09-26 00:00:00, 20 records, 9 cities
# examining adirondack_marathon-2011-09-25 00:00:00, 27 records, 15 cities
# examining adirondack_marathon-2012-09-23 00:00:00, 31 records, 15 cities
# examining adirondack_marathon-2013-09-22 00:00:00, 28 records, 12 cities
# examining adirondack_marathon-2014-09-28 00:00:00, 27 records, 11 cities
# examining adirondack_marathon-2015-09-27 00:00:00, 16 records, 6 cities
# examining adirondack_marathon-2016-09-25 00:00:00, 10 records, 7 cities
# examining adirondack_marathon-2018-09-23 00:00:00, 9 records, 5 cities
# examining adirondack_marathon-2019-09-22 00:00:00, 22 records, 8 cities
# examining adirondack_marathon-2021-10-03 00:00:00, 13 records, 8 cities
# examining adirondack_marathon-2022-09-18 00:00:00, 9 records, 5 cities
# examining adirondack_marathon-2023-10-01 00:00:00, 19 records, 7 cities
# examining air_force_marathon-2004-09-18 00:00:00, 151 records, 31 cities
# examining air_force_marathon-2005-09-17 00:00:00, 196 records, 35 cities
# examining air_force_marathon-2009-09-19 00:00:00, 283 records, 46 cities
# examining air_force_marathon-2010-09-18 00:00:00, 303 records, 50 cities
# examining air_force_marathon-2011-09-17 00:00:00, 350 records, 57 cities
# examining air_force_marathon-2012-09-15 00:00:00, 407 records, 52 cities
# examining air_force_marathon-2013-09-21 00:00:00, 365 records, 54 cities
# examining air_force_marathon-2014-09-20 00:00:00, 396 records, 58 cities
# examining air_force_marathon-2016-09-17 00:00:00, 263 records, 54 cities
# examining air_force_marathon-2018-09-15 00:00:00, 183 records, 49 cities
# examining air_force_marathon-2019-09-21 00:00:00, 153 records, 47 cities
# examining akron_marathon-2003-10-11 00:00:00, 50 records, 18 cities
# examining akron_marathon-2004-10-02 00:00:00, 54 records, 19 cities
# examining akron_marathon-2005-10-01 00:00:00, 42 records, 15 cities
# examining akron_marathon-2006-09-30 00:00:00, 96 records, 24 cities
# examining akron_marathon-2007-09-29 00:00:00, 85 records, 25 cities
# examining akron_marathon-2009-09-26 00:00:00, 78 records, 24 cities
# examining akron_marathon-2010-09-25 00:00:00, 88 records, 24 cities
# examining akron_marathon-2011-09-24 00:00:00, 85 records, 21 cities
# examining akron_marathon-2012-09-29 00:00:00, 96 records, 20 cities
# examining akron_marathon-2013-09-28 00:00:00, 96 records, 25 cities
# examining akron_marathon-2014-09-27 00:00:00, 80 records, 18 cities
# examining akron_marathon-2015-09-26 00:00:00, 62 records, 20 cities
# examining akron_marathon-2016-09-24 00:00:00, 65 records, 22 cities
# examining akron_marathon-2017-09-23 00:00:00, 32 records, 11 cities
# examining akron_marathon-2018-09-29 00:00:00, 50 records, 22 cities
# examining akron_marathon-2021-09-25 00:00:00, 38 records, 15 cities
# examining akron_marathon-2022-09-24 00:00:00, 33 records, 18 cities
# examining akron_marathon-2023-09-30 00:00:00, 28 records, 11 cities
# examining alaska_series_-_day_1-2021-08-03 00:00:00, 2 records, 2 cities
# examining alaska_series_-_day_1-2022-08-02 00:00:00, 4 records, 2 cities
# examining alaska_series_-_day_1-2023-07-25 00:00:00, 1 records, 1 cities
# examining alaska_series_-_day_2-2022-08-03 00:00:00, 2 records, 2 cities
# examining alaska_series_-_day_2-2023-07-26 00:00:00, 1 records, 1 cities
# examining alaska_series_-_day_3-2021-08-05 00:00:00, 3 records, 3 cities
# examining alaska_series_-_day_3-2022-08-04 00:00:00, 2 records, 2 cities
# examining alaska_series_-_day_3-2023-07-27 00:00:00, 2 records, 2 cities
# examining alaska_series_-_day_4-2021-08-06 00:00:00, 1 records, 1 cities
# examining alaska_series_-_day_4-2022-08-05 00:00:00, 1 records, 1 cities
# examining albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon)-2012-03-03 00:00:00, 67 records, 17 cities
# examining albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon)-2013-03-02 00:00:00, 32 records, 9 cities
# examining albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon)-2014-03-01 00:00:00, 62 records, 18 cities
# examining albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon)-2015-03-07 00:00:00, 65 records, 15 cities
# examining albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon)-2016-03-05 00:00:00, 63 records, 19 cities
# examining albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon)-2017-03-04 00:00:00, 49 records, 13 cities
# examining albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon)-2019-03-02 00:00:00, 50 records, 15 cities
# examining albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon)-2020-03-07 00:00:00, 55 records, 17 cities
# examining albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon)-2022-03-05 00:00:00, 64 records, 13 cities
# examining albany_marathon_(formerly_the_snickers_marathon_energy_bar_marathon)-2023-03-04 00:00:00, 34 records, 8 cities
# examining all_american_marathon-2014-05-04 00:00:00, 61 records, 16 cities
# examining all_american_marathon-2015-03-22 00:00:00, 32 records, 12 cities
# examining all_american_marathon-2016-04-03 00:00:00, 23 records, 13 cities
# examining all_american_marathon-2017-03-26 00:00:00, 42 records, 16 cities
# examining all_american_marathon-2018-03-25 00:00:00, 39 records, 14 cities
# examining all_american_marathon-2019-03-24 00:00:00, 43 records, 12 cities
# examining almond_bowl_marathon-2011-11-06 00:00:00, 3 records, 3 cities
# examining almond_bowl_marathon-2013-11-03 00:00:00, 1 records, 1 cities
# examining almond_bowl_marathon-2014-11-02 00:00:00, 1 records, 1 cities
# examining aloha_series_-_day_1-2022-01-20 00:00:00, 3 records, 3 cities
# examining aloha_series_-_day_1-2023-01-19 00:00:00, 3 records, 3 cities
# examining aloha_series_-_day_2-2022-01-21 00:00:00, 1 records, 1 cities
# examining aloha_series_-_day_2-2023-01-20 00:00:00, 2 records, 2 cities
# examining aloha_series_-_day_3-2023-01-21 00:00:00, 1 records, 1 cities
# examining aloha_series_-_day_4-2022-01-23 00:00:00, 1 records, 1 cities
# examining aloha_series_-_day_4-2023-01-22 00:00:00, 1 records, 1 cities
# examining alpharetta_marathon-2007-03-04 00:00:00, 60 records, 12 cities
# examining american_birkebeiner_trail_run-2011-09-24 00:00:00, 14 records, 8 cities
# examining american_birkebeiner_trail_run-2012-09-22 00:00:00, 24 records, 4 cities
# examining american_birkebeiner_trail_run-2013-09-21 00:00:00, 15 records, 4 cities
# examining american_birkebeiner_trail_run-2017-09-30 00:00:00, 8 records, 3 cities
# examining american_birkebeiner_trail_run-2018-09-29 00:00:00, 10 records, 5 cities
# examining american_birkebeiner_trail_run-2019-09-28 00:00:00, 6 records, 3 cities
# examining american_birkebeiner_trail_run-2021-09-25 00:00:00, 14 records, 6 cities
# examining american_birkebeiner_trail_run-2022-09-24 00:00:00, 16 records, 4 cities
# examining american_birkebeiner_trail_run-2023-09-23 00:00:00, 7 records, 2 cities
# examining american_discovery_trail_marathon-2001-09-03 00:00:00, 207 records, 7 cities
# examining american_discovery_trail_marathon-2002-09-02 00:00:00, 25 records, 14 cities
# examining american_discovery_trail_marathon-2003-09-01 00:00:00, 33 records, 15 cities
# examining american_discovery_trail_marathon-2004-09-06 00:00:00, 18 records, 12 cities
# examining american_discovery_trail_marathon-2005-09-05 00:00:00, 32 records, 8 cities
# examining american_discovery_trail_marathon-2006-09-04 00:00:00, 27 records, 10 cities
# examining american_discovery_trail_marathon-2007-09-03 00:00:00, 23 records, 9 cities
# examining american_discovery_trail_marathon-2009-09-07 00:00:00, 41 records, 13 cities
# examining american_discovery_trail_marathon-2010-09-06 00:00:00, 43 records, 15 cities
# examining american_discovery_trail_marathon-2011-09-05 00:00:00, 219 records, 16 cities
# examining american_discovery_trail_marathon-2012-09-03 00:00:00, 179 records, 10 cities
# examining american_discovery_trail_marathon-2013-09-02 00:00:00, 234 records, 18 cities
# examining american_discovery_trail_marathon-2014-09-01 00:00:00, 201 records, 23 cities
# examining american_discovery_trail_marathon-2015-09-07 00:00:00, 137 records, 11 cities
# examining american_discovery_trail_marathon-2016-09-05 00:00:00, 100 records, 7 cities
# examining american_discovery_trail_marathon-2017-09-04 00:00:00, 170 records, 10 cities
# examining american_discovery_trail_marathon-2018-09-03 00:00:00, 157 records, 11 cities
# examining american_discovery_trail_marathon-2019-09-02 00:00:00, 108 records, 8 cities
# examining american_heroes_run-2016-09-10 00:00:00, 1 records, 1 cities
# examining american_heroes_run-2017-09-09 00:00:00, 1 records, 1 cities
# examining american_heroes_run-2019-09-07 00:00:00, 2 records, 2 cities
# examining american_heroes_run-2021-09-11 00:00:00, 2 records, 1 cities
# examining american_heroes_run-2022-09-10 00:00:00, 1 records, 1 cities
# examining anchorage_runfest_humpy's_marathon_(prev._big_wild_life_runs_marathon)-2022-08-21 00:00:00, 77 records, 19 cities
# examining anchorage_runfest_humpy's_marathon_(prev._big_wild_life_runs_marathon)-2023-08-20 00:00:00, 106 records, 21 cities
# examining andrew_jackson_marathon-2001-11-03 00:00:00, 10 records, 4 cities
# examining andrew_jackson_marathon-2012-03-31 00:00:00, 17 records, 6 cities
# examining andrew_jackson_marathon-2013-03-16 00:00:00, 7 records, 5 cities
# examining andrew_jackson_marathon-2014-03-22 00:00:00, 26 records, 7 cities
# examining andrew_jackson_marathon-2015-03-14 00:00:00, 13 records, 7 cities
# examining andrew_jackson_marathon-2017-04-01 00:00:00, 8 records, 5 cities
# examining andrew_jackson_marathon-2018-04-07 00:00:00, 10 records, 6 cities
# examining andrew_jackson_marathon-2021-04-03 00:00:00, 4 records, 4 cities
# examining andrew_jackson_marathon-2022-04-02 00:00:00, 9 records, 6 cities
# examining andrew_jackson_marathon-2023-04-01 00:00:00, 3 records, 1 cities
# examining andy_payne_marathon-2000-05-27 00:00:00, 45 records, 12 cities
# examining andy_payne_marathon-2001-05-26 00:00:00, 9 records, 7 cities
# examining andy_payne_marathon-2002-05-25 00:00:00, 10 records, 4 cities
# examining andy_payne_marathon-2004-05-29 00:00:00, 15 records, 4 cities
# examining andy_payne_marathon-2005-05-28 00:00:00, 14 records, 3 cities
# examining andy_payne_marathon-2006-05-27 00:00:00, 11 records, 6 cities
# examining andy_payne_marathon-2007-05-26 00:00:00, 9 records, 4 cities
# examining andy_payne_marathon-2009-05-23 00:00:00, 49 records, 7 cities
# examining andy_payne_marathon-2010-05-30 00:00:00, 22 records, 6 cities
# examining angel_fire_adventure_marathon-2015-07-04 00:00:00, 3 records, 3 cities
# examining ann_arbor_marathon-2014-03-30 00:00:00, 100 records, 9 cities
# examining ann_arbor_marathon-2015-03-29 00:00:00, 108 records, 13 cities
# examining ann_arbor_marathon-2016-04-03 00:00:00, 90 records, 11 cities
# examining ann_arbor_marathon-2018-05-20 00:00:00, 60 records, 7 cities
# examining ann_arbor_marathon-2019-03-24 00:00:00, 91 records, 14 cities
# examining ann_arbor_marathon-2021-10-24 00:00:00, 50 records, 8 cities
# examining ann_arbor_marathon-2022-10-02 00:00:00, 82 records, 11 cities
# examining ann_arbor_marathon-2023-10-01 00:00:00, 82 records, 12 cities
# examining antarctica_marathon-2007-02-26 00:00:00, 38 records, 16 cities
# examining antarctica_marathon-2011-02-28 00:00:00, 8 records, 6 cities
# examining antarctica_marathon-2012-03-09 00:00:00, 16 records, 11 cities
# examining antarctica_marathon-2013-03-30 00:00:00, 15 records, 11 cities
# examining antarctica_marathon-2014-03-09 00:00:00, 30 records, 14 cities
# examining antarctica_marathon-2015-03-09 00:00:00, 35 records, 13 cities
# examining antarctica_marathon-2016-03-13 00:00:00, 30 records, 15 cities
# examining antarctica_marathon-2017-03-10 00:00:00, 57 records, 24 cities
# examining appalachian_series_-_al-2021-10-22 00:00:00, 1 records, 1 cities
# examining appalachian_series_-_al-2022-03-25 00:00:00, 3 records, 3 cities
# examining appalachian_series_-_al-2023-03-24 00:00:00, 7 records, 6 cities
# skipping, not enough weather data on 2023-03-24 00:00:00
# examining appalachian_series_-_ga-2015-10-16 00:00:00, 5 records, 5 cities
# examining appalachian_series_-_ga-2016-10-14 00:00:00, 11 records, 9 cities
# examining appalachian_series_-_ga-2019-10-10 00:00:00, 5 records, 4 cities
# examining appalachian_series_-_ga-2021-10-21 00:00:00, 2 records, 2 cities
# examining appalachian_series_-_ga-2022-03-26 00:00:00, 4 records, 4 cities
# examining appalachian_series_-_ga-2023-03-25 00:00:00, 6 records, 5 cities
# examining appalachian_series_-_nc-2015-10-14 00:00:00, 8 records, 8 cities
# examining appalachian_series_-_nc-2016-10-12 00:00:00, 6 records, 6 cities
# examining appalachian_series_-_nc-2018-10-09 00:00:00, 1 records, 1 cities
# examining appalachian_series_-_nc-2019-10-08 00:00:00, 2 records, 2 cities
# examining appalachian_series_-_nc-2021-10-19 00:00:00, 4 records, 4 cities
# examining appalachian_series_-_nc-2022-03-28 00:00:00, 7 records, 5 cities
# examining appalachian_series_-_nc-2023-03-27 00:00:00, 6 records, 6 cities
# examining appalachian_series_-_sc-2015-10-15 00:00:00, 4 records, 4 cities
# examining appalachian_series_-_sc-2016-10-13 00:00:00, 11 records, 11 cities
# examining appalachian_series_-_sc-2018-10-10 00:00:00, 1 records, 1 cities
# examining appalachian_series_-_sc-2019-10-09 00:00:00, 3 records, 3 cities
# examining appalachian_series_-_sc-2021-10-20 00:00:00, 4 records, 4 cities
# examining appalachian_series_-_sc-2022-03-27 00:00:00, 7 records, 5 cities
# examining appalachian_series_-_sc-2023-03-26 00:00:00, 5 records, 5 cities
# examining appalachian_series_-_tn-2016-10-11 00:00:00, 6 records, 6 cities
# examining appalachian_series_-_tn-2018-10-08 00:00:00, 2 records, 2 cities
# examining appalachian_series_-_tn-2019-10-07 00:00:00, 3 records, 3 cities
# examining appalachian_series_-_tn-2021-10-18 00:00:00, 2 records, 2 cities
# examining appalachian_series_-_tn-2022-03-29 00:00:00, 4 records, 4 cities
# examining appalachian_series_-_tn-2023-03-28 00:00:00, 5 records, 4 cities
# examining appalachian_series_-_va-2015-10-12 00:00:00, 5 records, 5 cities
# examining appalachian_series_-_va-2016-10-10 00:00:00, 7 records, 7 cities
# examining appalachian_series_-_va-2018-10-07 00:00:00, 5 records, 5 cities
# examining appalachian_series_-_va-2019-10-06 00:00:00, 5 records, 4 cities
# examining appalachian_series_-_va-2021-10-17 00:00:00, 6 records, 4 cities
# examining appalachian_series_-_va-2022-03-31 00:00:00, 2 records, 2 cities
# examining appalachian_series_-_va-2023-03-30 00:00:00, 4 records, 4 cities
# examining appalachian_series_-_wv-2015-10-11 00:00:00, 6 records, 5 cities
# examining appalachian_series_-_wv-2016-10-09 00:00:00, 8 records, 8 cities
# examining appalachian_series_-_wv-2018-10-06 00:00:00, 3 records, 3 cities
# examining appalachian_series_-_wv-2019-10-05 00:00:00, 5 records, 4 cities
# examining appalachian_series_-_wv-2021-10-16 00:00:00, 4 records, 2 cities
# examining appalachian_series_-_wv-2022-03-30 00:00:00, 5 records, 5 cities
# examining appalachian_series_-_wv-2023-03-29 00:00:00, 4 records, 4 cities
# examining apple_tree_marathon-2022-09-18 00:00:00, 30 records, 3 cities
# examining apple_tree_marathon-2023-09-17 00:00:00, 95 records, 11 cities
# examining arena_attack_indoor_marathon-2016-02-28 00:00:00, 4 records, 4 cities
# examining arena_attack_indoor_marathon-2017-01-21 00:00:00, 1 records, 1 cities
# examining arena_attack_indoor_marathon-2018-01-21 00:00:00, 3 records, 3 cities
# examining arena_attack_indoor_marathon-2019-01-19 00:00:00, 2 records, 2 cities
# examining arena_attack_indoor_marathon-2020-01-25 00:00:00, 1 records, 1 cities
# examining arizona_marathon-2009-02-15 00:00:00, 68 records, 10 cities
# examining arizona_marathon-2010-02-14 00:00:00, 48 records, 7 cities
# examining arizona_marathon-2011-02-20 00:00:00, 49 records, 10 cities
# examining arizona_marathon-2012-02-19 00:00:00, 137 records, 22 cities
# examining arizona_marathon-2013-02-17 00:00:00, 119 records, 12 cities
# examining arizona_marathon-2014-02-16 00:00:00, 87 records, 14 cities
# examining arizona_marathon-2015-02-15 00:00:00, 109 records, 14 cities
# examining arizona_marathon-2016-02-14 00:00:00, 134 records, 19 cities
# examining arizona_marathon-2017-02-19 00:00:00, 72 records, 20 cities
# examining arkansas_marathon-2000-10-01 00:00:00, 18 records, 6 cities
# examining arkansas_marathon-2001-10-14 00:00:00, 6 records, 5 cities
# examining arkansas_marathon-2002-10-13 00:00:00, 10 records, 5 cities
# examining arkansas_marathon-2004-10-09 00:00:00, 4 records, 3 cities
# examining arkansas_marathon-2005-09-10 00:00:00, 8 records, 3 cities
# examining arkansas_marathon-2006-09-30 00:00:00, 7 records, 2 cities
# examining arkansas_marathon-2007-09-29 00:00:00, 3 records, 2 cities
# examining arkansas_marathon-2009-09-19 00:00:00, 1 records, 1 cities
# examining arkansas_marathon-2010-10-16 00:00:00, 2 records, 1 cities
# examining arkansas_marathon-2011-10-08 00:00:00, 2 records, 2 cities
# examining arkansas_marathon-2014-10-04 00:00:00, 3 records, 2 cities
# examining arkansas_marathon-2018-10-13 00:00:00, 4 records, 4 cities
# examining arkansas_marathon-2019-10-12 00:00:00, 2 records, 2 cities
# examining arkansas_marathon-2020-10-10 00:00:00, 2 records, 2 cities
# examining arkansas_marathon-2021-10-09 00:00:00, 1 records, 1 cities
# examining arkansas_marathon-2022-10-08 00:00:00, 5 records, 3 cities
# examining arkansas_marathon-2023-10-14 00:00:00, 1 records, 1 cities
# examining arkansas_river_bluegrass_marathon-2011-05-29 00:00:00, 5 records, 3 cities
# examining armed_services_marathon_(prev._oktoberfest_marathon)-2019-09-21 00:00:00, 2 records, 2 cities
# examining around_the_lake_marathon-2001-08-03 00:00:00, 1 records, 1 cities
# examining around_the_lake_marathon-2002-08-02 00:00:00, 4 records, 3 cities
# examining around_the_lake_marathon-2003-08-01 00:00:00, 5 records, 4 cities
# examining around_the_lake_marathon-2004-08-13 00:00:00, 8 records, 5 cities
# examining around_the_lake_marathon-2005-07-29 00:00:00, 4 records, 4 cities
# examining around_the_lake_marathon-2006-07-28 00:00:00, 6 records, 5 cities
# examining around_the_lake_marathon-2007-07-27 00:00:00, 8 records, 6 cities
# examining around_the_lake_marathon-2009-07-24 00:00:00, 27 records, 7 cities
# examining around_the_lake_marathon-2010-07-30 00:00:00, 28 records, 7 cities
# examining around_the_lake_marathon-2011-07-29 00:00:00, 15 records, 10 cities
# examining asbury_park_relay_marathon-2010-10-17 00:00:00, 12 records, 6 cities
# examining asbury_park_relay_marathon-2011-10-16 00:00:00, 7 records, 3 cities
# examining asheville_city_marathon-2013-09-28 00:00:00, 41 records, 13 cities
# examining asheville_marathon-2013-03-03 00:00:00, 104 records, 27 cities
# examining asheville_marathon-2014-03-16 00:00:00, 43 records, 19 cities
# examining asheville_marathon-2015-03-15 00:00:00, 63 records, 22 cities
# examining asheville_marathon-2016-03-13 00:00:00, 80 records, 27 cities
# examining asheville_marathon-2017-03-12 00:00:00, 72 records, 25 cities
# examining asheville_marathon-2018-03-18 00:00:00, 62 records, 35 cities
# examining asheville_marathon-2019-03-17 00:00:00, 97 records, 31 cities
# examining asheville_marathon-2022-03-20 00:00:00, 64 records, 30 cities
# examining asheville_marathon-2023-03-18 00:00:00, 122 records, 28 cities
# examining aspen_backcountry_marathon-2011-08-27 00:00:00, 49 records, 15 cities
# examining aspen_backcountry_marathon-2012-08-26 00:00:00, 47 records, 11 cities
# examining aspen_backcountry_marathon-2013-06-29 00:00:00, 48 records, 6 cities
# examining aspen_backcountry_marathon-2019-08-10 00:00:00, 64 records, 9 cities
# examining aspen_backcountry_marathon-2022-07-30 00:00:00, 18 records, 4 cities
# examining aspen_backcountry_marathon-2023-08-05 00:00:00, 25 records, 9 cities
# examining aspen_trail_race-2000-07-15 00:00:00, 4 records, 2 cities
# examining aspen_trail_race-2002-06-29 00:00:00, 4 records, 3 cities
# examining aspen_valley_marathon-2017-07-15 00:00:00, 69 records, 17 cities
# skipping, not enough weather data on 2017-07-15 00:00:00
# examining aspen_valley_marathon-2018-07-14 00:00:00, 31 records, 12 cities
# examining aspen_valley_marathon-2019-07-13 00:00:00, 76 records, 18 cities
# examining aspen_valley_marathon-2022-07-16 00:00:00, 80 records, 22 cities
# examining aspen_valley_marathon-2023-07-15 00:00:00, 53 records, 20 cities
# examining athens_marathon_(ohio)-2000-04-02 00:00:00, 20 records, 7 cities
# examining athens_marathon_(ohio)-2001-04-08 00:00:00, 16 records, 8 cities
# examining athens_marathon_(ohio)-2002-04-14 00:00:00, 57 records, 5 cities
# examining athens_marathon_(ohio)-2003-04-13 00:00:00, 33 records, 6 cities
# examining athens_marathon_(ohio)-2004-04-04 00:00:00, 28 records, 6 cities
# examining athens_marathon_(ohio)-2005-04-10 00:00:00, 38 records, 5 cities
# examining athens_marathon_(ohio)-2006-04-02 00:00:00, 32 records, 10 cities
# examining athens_marathon_(ohio)-2007-04-01 00:00:00, 41 records, 6 cities
# examining athens_marathon_(ohio)-2009-04-05 00:00:00, 43 records, 9 cities
# examining athens_marathon_(ohio)-2010-04-11 00:00:00, 31 records, 11 cities
# examining athens_marathon_(ohio)-2011-04-03 00:00:00, 33 records, 12 cities
# examining athens_marathon_(ohio)-2012-04-01 00:00:00, 34 records, 8 cities
# examining athens_marathon_(ohio)-2013-04-14 00:00:00, 25 records, 6 cities
# examining athens_marathon_(ohio)-2014-04-13 00:00:00, 22 records, 8 cities
# examining athens_marathon_(ohio)-2015-04-19 00:00:00, 44 records, 11 cities
# examining athens_marathon_(ohio)-2016-04-10 00:00:00, 42 records, 6 cities
# examining athens_marathon_(ohio)-2017-04-09 00:00:00, 24 records, 6 cities
# examining athens_marathon_(ohio)-2018-04-15 00:00:00, 80 records, 10 cities
# examining athens_marathon_(ohio)-2019-04-14 00:00:00, 36 records, 13 cities
# examining athens_marathon_(ohio)-2022-04-10 00:00:00, 39 records, 7 cities
# examining athens_marathon_(ohio)-2023-04-16 00:00:00, 48 records, 8 cities
# examining atlanta_marathon-2000-11-23 00:00:00, 223 records, 27 cities
# examining atlanta_marathon-2001-11-22 00:00:00, 183 records, 24 cities
# examining atlanta_marathon-2002-11-28 00:00:00, 173 records, 26 cities
# examining atlanta_marathon-2003-11-27 00:00:00, 174 records, 28 cities
# examining atlanta_marathon-2004-11-25 00:00:00, 167 records, 27 cities
# examining atlanta_marathon-2005-11-24 00:00:00, 185 records, 23 cities
# examining atlanta_marathon-2006-11-23 00:00:00, 141 records, 19 cities
# examining atlanta_marathon-2007-11-22 00:00:00, 109 records, 21 cities
# examining atlanta_marathon-2009-11-26 00:00:00, 205 records, 24 cities
# examining atlanta_marathon-2011-10-30 00:00:00, 367 records, 31 cities
# examining atlanta_marathon-2012-10-28 00:00:00, 283 records, 30 cities
# examining atlanta_marathon-2013-10-27 00:00:00, 277 records, 35 cities
# examining atlantic_city_marathon-2001-10-14 00:00:00, 12 records, 5 cities
# examining atlantic_city_marathon-2002-10-13 00:00:00, 19 records, 7 cities
# examining atlantic_city_marathon-2003-10-12 00:00:00, 12 records, 5 cities
# examining atlantic_city_marathon-2004-10-17 00:00:00, 9 records, 5 cities
# examining atlantic_city_marathon-2005-10-16 00:00:00, 2 records, 2 cities
# examining atlantic_city_marathon-2009-11-15 00:00:00, 21 records, 6 cities
# examining atlantic_city_marathon-2010-10-17 00:00:00, 57 records, 16 cities
# examining atlantic_city_marathon-2012-10-21 00:00:00, 91 records, 24 cities
# examining atlantic_city_marathon-2013-10-13 00:00:00, 130 records, 19 cities
# examining atlantic_city_marathon-2014-10-19 00:00:00, 111 records, 27 cities
# examining atlantic_city_marathon-2015-10-18 00:00:00, 84 records, 21 cities
# examining atlantic_city_marathon-2016-10-23 00:00:00, 79 records, 24 cities
# examining atlantic_city_marathon-2017-10-22 00:00:00, 76 records, 24 cities
# examining atlantic_city_marathon-2018-10-21 00:00:00, 92 records, 31 cities
# examining atlantic_city_marathon-2019-10-20 00:00:00, 85 records, 30 cities
# examining atlantic_city_marathon-2021-10-17 00:00:00, 135 records, 27 cities
# examining atlantic_city_marathon-2022-10-23 00:00:00, 101 records, 28 cities
# examining austin_marathon-2002-02-17 00:00:00, 2266 records, 54 cities
# examining austin_marathon-2003-02-16 00:00:00, 2601 records, 55 cities
# examining austin_marathon-2004-02-15 00:00:00, 2426 records, 51 cities
# examining austin_marathon-2005-02-13 00:00:00, 2151 records, 57 cities
# examining austin_marathon-2006-02-19 00:00:00, 2251 records, 56 cities
# examining austin_marathon-2007-02-18 00:00:00, 2106 records, 60 cities
# examining austin_marathon-2009-02-15 00:00:00, 2043 records, 56 cities
# examining austin_marathon-2010-02-14 00:00:00, 1946 records, 57 cities
# examining austin_marathon-2011-02-20 00:00:00, 2202 records, 62 cities
# examining austin_marathon-2012-02-19 00:00:00, 1868 records, 53 cities
# examining austin_marathon-2014-02-16 00:00:00, 1958 records, 56 cities
# examining austin_marathon-2015-02-15 00:00:00, 1732 records, 53 cities
# examining austin_marathon-2016-02-14 00:00:00, 1564 records, 12 cities
# examining austin_marathon-2017-02-19 00:00:00, 1387 records, 49 cities
# examining austin_marathon-2018-02-18 00:00:00, 1348 records, 46 cities
# examining austin_marathon-2019-02-17 00:00:00, 1423 records, 53 cities
# examining austin_marathon-2020-02-16 00:00:00, 1488 records, 53 cities
# examining austin_marathon-2022-02-20 00:00:00, 1435 records, 50 cities
# examining austin_marathon-2023-02-19 00:00:00, 1745 records, 62 cities
# examining avalon_park_marathon-2006-11-04 00:00:00, 2 records, 2 cities
# examining ave_maria_marathon-2022-02-12 00:00:00, 2 records, 2 cities
# examining avenue_of_the_giants_marathon-2000-05-07 00:00:00, 176 records, 32 cities
# examining avenue_of_the_giants_marathon-2001-05-06 00:00:00, 177 records, 34 cities
# examining avenue_of_the_giants_marathon-2002-05-05 00:00:00, 192 records, 30 cities
# examining avenue_of_the_giants_marathon-2003-05-04 00:00:00, 158 records, 32 cities
# examining avenue_of_the_giants_marathon-2004-05-02 00:00:00, 158 records, 24 cities
# examining avenue_of_the_giants_marathon-2005-05-01 00:00:00, 143 records, 29 cities
# examining avenue_of_the_giants_marathon-2006-05-07 00:00:00, 90 records, 20 cities
# examining avenue_of_the_giants_marathon-2007-05-06 00:00:00, 70 records, 19 cities
# examining avenue_of_the_giants_marathon-2009-05-03 00:00:00, 103 records, 24 cities
# examining avenue_of_the_giants_marathon-2010-05-02 00:00:00, 113 records, 25 cities
# examining avenue_of_the_giants_marathon-2011-05-01 00:00:00, 138 records, 31 cities
# examining avenue_of_the_giants_marathon-2012-05-06 00:00:00, 108 records, 19 cities
# examining avenue_of_the_giants_marathon-2013-05-05 00:00:00, 134 records, 24 cities
# examining avenue_of_the_giants_marathon-2014-05-04 00:00:00, 157 records, 28 cities
# examining avenue_of_the_giants_marathon-2015-05-03 00:00:00, 117 records, 21 cities
# examining avenue_of_the_giants_marathon-2016-05-01 00:00:00, 152 records, 31 cities
# examining avenue_of_the_giants_marathon-2017-05-07 00:00:00, 115 records, 29 cities
# examining avenue_of_the_giants_marathon-2018-05-06 00:00:00, 79 records, 22 cities
# examining avenue_of_the_giants_marathon-2019-05-05 00:00:00, 78 records, 23 cities
# examining avenue_of_the_giants_marathon-2021-09-19 00:00:00, 50 records, 19 cities
# examining avenue_of_the_giants_marathon-2023-05-07 00:00:00, 110 records, 26 cities
# examining az_legs_for_literacy_marathon-2017-10-22 00:00:00, 1 records, 1 cities
# examining b&a_trail_marathon-2000-03-12 00:00:00, 39 records, 13 cities
# examining b&a_trail_marathon-2001-03-04 00:00:00, 33 records, 10 cities
# examining b&a_trail_marathon-2002-03-03 00:00:00, 41 records, 13 cities
# examining b&a_trail_marathon-2004-03-07 00:00:00, 39 records, 12 cities
# examining b&a_trail_marathon-2005-03-06 00:00:00, 38 records, 11 cities
# examining b&a_trail_marathon-2006-03-05 00:00:00, 39 records, 18 cities
# examining b&a_trail_marathon-2007-03-04 00:00:00, 17 records, 4 cities
# examining b&a_trail_marathon-2009-03-01 00:00:00, 41 records, 14 cities
# examining b&a_trail_marathon-2010-03-07 00:00:00, 31 records, 17 cities
# examining b&a_trail_marathon-2011-03-06 00:00:00, 33 records, 11 cities
# examining b&a_trail_marathon-2012-03-04 00:00:00, 43 records, 16 cities
# examining b&a_trail_marathon-2013-03-16 00:00:00, 12 records, 8 cities
# examining b&a_trail_marathon-2014-03-30 00:00:00, 24 records, 9 cities
# examining b&a_trail_marathon-2016-03-20 00:00:00, 16 records, 7 cities
# examining b&a_trail_marathon-2017-03-26 00:00:00, 18 records, 10 cities
# examining b&a_trail_marathon-2018-04-08 00:00:00, 39 records, 11 cities
# examining b&a_trail_marathon-2019-03-31 00:00:00, 22 records, 7 cities
# examining b&a_trail_marathon-2022-03-27 00:00:00, 37 records, 10 cities
# examining b&a_trail_marathon-2023-03-26 00:00:00, 36 records, 14 cities
# examining back_your_badge_marathon-2023-09-23 00:00:00, 1 records, 1 cities
# examining backside_trail_marathon_and_half-2021-05-16 00:00:00, 12 records, 2 cities
# examining bakersfield_marathon-2016-11-13 00:00:00, 14 records, 9 cities
# examining bakersfield_marathon-2017-11-12 00:00:00, 14 records, 9 cities
# examining bakersfield_marathon-2018-11-18 00:00:00, 21 records, 9 cities
# examining bakersfield_marathon-2019-11-17 00:00:00, 17 records, 11 cities
# examining bakersfield_marathon-2022-03-27 00:00:00, 9 records, 5 cities
# examining bakersfield_marathon-2023-03-26 00:00:00, 8 records, 6 cities
# examining baltimore_marathon-2001-10-20 00:00:00, 715 records, 53 cities
# examining baltimore_marathon-2002-10-19 00:00:00, 290 records, 44 cities
# examining baltimore_marathon-2003-10-18 00:00:00, 230 records, 37 cities
# examining baltimore_marathon-2004-10-16 00:00:00, 253 records, 32 cities
# examining baltimore_marathon-2005-10-15 00:00:00, 265 records, 41 cities
# examining baltimore_marathon-2006-10-14 00:00:00, 283 records, 47 cities
# examining baltimore_marathon-2007-10-13 00:00:00, 347 records, 47 cities
# examining baltimore_marathon-2009-10-10 00:00:00, 484 records, 44 cities
# examining baltimore_marathon-2010-10-16 00:00:00, 481 records, 54 cities
# examining baltimore_marathon-2011-10-15 00:00:00, 425 records, 49 cities
# examining baltimore_marathon-2012-10-13 00:00:00, 439 records, 44 cities
# examining baltimore_marathon-2013-10-12 00:00:00, 414 records, 48 cities
# examining baltimore_marathon-2014-10-18 00:00:00, 404 records, 43 cities
# examining baltimore_marathon-2015-10-17 00:00:00, 389 records, 37 cities
# examining baltimore_marathon-2016-10-15 00:00:00, 362 records, 46 cities
# examining baltimore_marathon-2023-10-14 00:00:00, 203 records, 33 cities
# examining banff_marathon-2014-06-22 00:00:00, 5 records, 5 cities
# examining banff_marathon-2019-06-16 00:00:00, 31 records, 18 cities
# examining banff_marathon-2021-09-12 00:00:00, 9 records, 6 cities
# examining banff_marathon-2022-06-19 00:00:00, 16 records, 13 cities
# examining banff_marathon-2023-06-18 00:00:00, 27 records, 15 cities
# examining bank_of_america_marathon-2001-12-02 00:00:00, 356 records, 37 cities
# examining barnum_rail_trail_marathon-2015-09-26 00:00:00, 8 records, 8 cities
# examining barnum_rail_trail_marathon-2016-09-24 00:00:00, 6 records, 6 cities
# examining barnum_rail_trail_marathon-2017-09-23 00:00:00, 10 records, 9 cities
# examining barnum_rail_trail_marathon-2018-09-29 00:00:00, 6 records, 5 cities
# examining bass_pro_shops_marathon-2007-11-04 00:00:00, 13 records, 9 cities
# examining bass_pro_shops_marathon-2009-11-01 00:00:00, 18 records, 9 cities
# examining bass_pro_shops_marathon-2010-11-07 00:00:00, 8 records, 7 cities
# examining bass_pro_shops_marathon-2011-11-06 00:00:00, 19 records, 9 cities
# examining bass_pro_shops_marathon-2020-11-01 00:00:00, 14 records, 9 cities
# examining bass_pro_shops_marathon-2022-11-06 00:00:00, 7 records, 5 cities
# examining bass_pro_shops_marathon-2023-11-05 00:00:00, 5 records, 4 cities
# examining bataan_memorial_death_march-2004-03-21 00:00:00, 192 records, 31 cities
# examining bataan_memorial_death_march-2005-03-20 00:00:00, 230 records, 33 cities
# examining bataan_memorial_death_march-2007-03-25 00:00:00, 305 records, 51 cities
# examining bataan_memorial_death_march-2009-03-29 00:00:00, 343 records, 47 cities
# examining bataan_memorial_death_march-2010-03-21 00:00:00, 481 records, 54 cities
# examining bataan_memorial_death_march-2011-03-27 00:00:00, 457 records, 51 cities
# examining bataan_memorial_death_march-2012-03-25 00:00:00, 465 records, 57 cities
# examining bataan_memorial_death_march-2013-03-17 00:00:00, 363 records, 50 cities
# examining bataan_memorial_death_march-2014-03-23 00:00:00, 542 records, 58 cities
# examining bataan_memorial_death_march-2015-03-22 00:00:00, 14 records, 12 cities
# examining baton_rouge_beach_marathon-2003-11-08 00:00:00, 18 records, 9 cities
# examining baton_rouge_beach_marathon-2005-12-03 00:00:00, 9 records, 5 cities
# examining baton_rouge_beach_marathon-2006-12-02 00:00:00, 16 records, 11 cities
# examining baton_rouge_beach_marathon-2007-12-01 00:00:00, 25 records, 15 cities
# examining baton_rouge_beach_marathon-2010-12-04 00:00:00, 25 records, 14 cities
# examining baton_rouge_beach_marathon-2015-12-05 00:00:00, 36 records, 20 cities
# examining baton_rouge_beach_marathon-2016-12-03 00:00:00, 13 records, 11 cities
# examining baton_rouge_marathon-2000-10-28 00:00:00, 6 records, 3 cities
# examining bay_of_fundy_international_marathon-2013-06-23 00:00:00, 43 records, 26 cities
# examining bay_of_fundy_international_marathon-2014-06-15 00:00:00, 24 records, 13 cities
# examining bay_of_fundy_international_marathon-2016-06-26 00:00:00, 40 records, 18 cities
# examining bay_of_fundy_international_marathon-2017-06-25 00:00:00, 20 records, 11 cities
# examining bay_of_fundy_international_marathon-2018-06-24 00:00:00, 28 records, 13 cities
# examining bay_of_fundy_international_marathon-2019-06-23 00:00:00, 33 records, 14 cities
# examining bay_state_marathon-2000-10-22 00:00:00, 49 records, 5 cities
# examining bay_state_marathon-2001-10-21 00:00:00, 49 records, 6 cities
# examining bay_state_marathon-2002-10-20 00:00:00, 48 records, 5 cities
# examining bay_state_marathon-2003-10-19 00:00:00, 40 records, 7 cities
# examining bay_state_marathon-2004-10-17 00:00:00, 30 records, 6 cities
# examining bay_state_marathon-2005-10-16 00:00:00, 34 records, 4 cities
# examining bay_state_marathon-2006-10-15 00:00:00, 62 records, 8 cities
# examining bay_state_marathon-2007-10-14 00:00:00, 60 records, 14 cities
# examining bay_state_marathon-2009-10-18 00:00:00, 146 records, 13 cities
# examining bay_state_marathon-2010-10-17 00:00:00, 149 records, 20 cities
# examining bayshore_marathon-2001-05-26 00:00:00, 30 records, 8 cities
# examining bayshore_marathon-2002-05-25 00:00:00, 57 records, 13 cities
# examining bayshore_marathon-2003-05-24 00:00:00, 61 records, 22 cities
# examining bayshore_marathon-2005-05-28 00:00:00, 77 records, 14 cities
# examining bayshore_marathon-2006-05-27 00:00:00, 105 records, 25 cities
# examining bayshore_marathon-2010-05-29 00:00:00, 95 records, 15 cities
# examining bayshore_marathon-2011-05-28 00:00:00, 86 records, 18 cities
# examining bayshore_marathon-2013-05-25 00:00:00, 123 records, 22 cities
# examining bayshore_marathon-2014-05-24 00:00:00, 170 records, 30 cities
# examining bayshore_marathon-2023-05-27 00:00:00, 145 records, 31 cities
# examining baystate_marathon-2011-10-16 00:00:00, 84 records, 21 cities
# examining baystate_marathon-2012-10-21 00:00:00, 120 records, 16 cities
# examining baystate_marathon-2013-10-20 00:00:00, 128 records, 19 cities
# examining baystate_marathon-2014-10-19 00:00:00, 115 records, 17 cities
# examining baystate_marathon-2015-10-18 00:00:00, 131 records, 12 cities
# examining baystate_marathon-2016-10-16 00:00:00, 108 records, 16 cities
# examining baystate_marathon-2017-10-22 00:00:00, 124 records, 18 cities
# examining baystate_marathon-2018-10-21 00:00:00, 121 records, 14 cities
# examining baystate_marathon-2019-10-20 00:00:00, 103 records, 16 cities
# examining baystate_marathon-2021-10-17 00:00:00, 95 records, 18 cities
# examining baystate_marathon-2022-10-16 00:00:00, 115 records, 15 cities
# examining baystate_marathon-2023-10-15 00:00:00, 118 records, 16 cities
# examining beach_to_bay_marathon-2016-05-21 00:00:00, 8 records, 2 cities
# examining beach_to_bay_marathon-2018-05-19 00:00:00, 10 records, 5 cities
# examining beach_to_bay_marathon-2019-05-18 00:00:00, 9 records, 4 cities
# examining beach_to_bay_marathon-2022-05-21 00:00:00, 18 records, 2 cities
# examining bear_brook_trail_marathon-2012-07-21 00:00:00, 2 records, 2 cities
# examining bear_brook_trail_marathon-2013-07-27 00:00:00, 7 records, 4 cities
# examining bear_brook_trail_marathon-2014-07-19 00:00:00, 7 records, 4 cities
# examining bear_brook_trail_marathon-2015-07-12 00:00:00, 6 records, 4 cities
# examining bear_brook_trail_marathon-2016-07-09 00:00:00, 5 records, 5 cities
# examining bear_brook_trail_marathon-2017-07-08 00:00:00, 4 records, 3 cities
# examining bear_brook_trail_marathon-2018-07-14 00:00:00, 2 records, 2 cities
# examining bear_lake_idaho_marathon-2014-06-13 00:00:00, 9 records, 6 cities
# examining bear_lake_idaho_marathon-2016-06-10 00:00:00, 1 records, 1 cities
# examining bear_lake_idaho_marathon-2020-08-13 00:00:00, 12 records, 11 cities
# examining bear_lake_idaho_marathon-2021-06-10 00:00:00, 6 records, 5 cities
# examining bear_lake_idaho_marathon-2022-06-09 00:00:00, 10 records, 10 cities
# examining bear_lake_idaho_marathon-2023-06-08 00:00:00, 3 records, 2 cities
# examining bear_lake_marathon-2012-06-09 00:00:00, 39 records, 11 cities
# examining bear_lake_marathon-2014-06-14 00:00:00, 14 records, 6 cities
# examining bear_lake_marathon-2020-08-15 00:00:00, 10 records, 9 cities
# examining bear_lake_marathon-2021-06-12 00:00:00, 11 records, 7 cities
# examining bear_lake_marathon-2022-06-11 00:00:00, 6 records, 6 cities
# examining bear_lake_marathon-2023-06-10 00:00:00, 4 records, 3 cities
# examining bear_lake_wyoming_marathon-2020-08-14 00:00:00, 9 records, 9 cities
# examining bear_lake_wyoming_marathon-2021-06-11 00:00:00, 8 records, 7 cities
# examining bear_lake_wyoming_marathon-2022-06-10 00:00:00, 5 records, 5 cities
# examining bear_lake_wyoming_marathon-2023-06-09 00:00:00, 4 records, 3 cities
# examining bear_paw_marathon-2021-06-05 00:00:00, 1 records, 1 cities
# examining bear_paw_marathon-2023-06-03 00:00:00, 2 records, 2 cities
# examining beat_the_blerch_saturday_marathon-2016-09-17 00:00:00, 85 records, 17 cities
# examining beat_the_blerch_saturday_marathon-2017-09-16 00:00:00, 53 records, 13 cities
# examining beat_the_blerch_saturday_marathon-2018-09-15 00:00:00, 59 records, 18 cities
# examining beat_the_blerch_saturday_marathon-2019-08-03 00:00:00, 79 records, 15 cities
# examining beat_the_blerch_saturday_marathon-2022-09-10 00:00:00, 40 records, 12 cities
# examining beat_the_blerch_saturday_marathon-2023-09-09 00:00:00, 56 records, 5 cities
# examining beat_the_blerch_sunday_marathon-2016-09-18 00:00:00, 87 records, 12 cities
# examining beat_the_blerch_sunday_marathon-2017-09-17 00:00:00, 30 records, 13 cities
# examining beaver_island_marathon-2009-09-05 00:00:00, 4 records, 3 cities
# examining beaver_island_marathon-2010-09-04 00:00:00, 4 records, 3 cities
# examining beaver_island_marathon-2011-09-03 00:00:00, 2 records, 2 cities
# examining beckley_marathon-2015-09-19 00:00:00, 1 records, 1 cities
# examining bellevue_ghost_marathon-2014-06-22 00:00:00, 7 records, 1 cities
# examining bellevue_ghost_marathon-2015-06-28 00:00:00, 11 records, 1 cities
# examining bellingham_bay_marathon-2015-09-27 00:00:00, 78 records, 15 cities
# examining bellingham_bay_marathon-2016-09-25 00:00:00, 87 records, 13 cities
# examining bellingham_bay_marathon-2017-09-24 00:00:00, 75 records, 16 cities
# examining bellingham_bay_marathon-2018-09-30 00:00:00, 66 records, 6 cities
# examining bellingham_bay_marathon-2019-09-29 00:00:00, 71 records, 10 cities
# examining bellingham_bay_marathon-2021-09-26 00:00:00, 53 records, 8 cities
# examining bellingham_bay_marathon-2022-09-25 00:00:00, 64 records, 9 cities
# examining bellingham_bay_marathon,_half_marathon_&_10k-2009-09-27 00:00:00, 43 records, 7 cities
# examining belmead_trail_fest-2015-09-26 00:00:00, 3 records, 2 cities
# examining bemidji_blue_ox_marathon-2013-10-12 00:00:00, 8 records, 3 cities
# examining bemidji_blue_ox_marathon-2014-10-11 00:00:00, 11 records, 4 cities
# examining bemidji_blue_ox_marathon-2015-10-10 00:00:00, 9 records, 2 cities
# examining bemidji_blue_ox_marathon-2016-10-08 00:00:00, 13 records, 5 cities
# ...
# examining wickham_park_marathon-2001-05-27 00:00:00, 1 records, 1 cities
# examining wickham_park_marathon-2004-05-30 00:00:00, 1 records, 1 cities
# examining wickham_park_marathon-2006-05-28 00:00:00, 1 records, 1 cities
# examining wickham_park_marathon-2009-05-24 00:00:00, 2 records, 1 cities
# examining wickham_park_marathon-2010-05-30 00:00:00, 2 records, 2 cities
# examining wickham_park_marathon-2013-05-26 00:00:00, 2 records, 2 cities
# examining wickham_park_marathon-2014-05-25 00:00:00, 1 records, 1 cities
# examining wild_hog_marathon-2018-09-29 00:00:00, 6 records, 4 cities
# examining wild_hog_marathon-2019-09-28 00:00:00, 8 records, 2 cities
# examining wild_wild_west_marathon-2002-05-05 00:00:00, 18 records, 6 cities
# examining wild_wild_west_marathon-2003-05-03 00:00:00, 15 records, 8 cities
# examining wild_wild_west_marathon-2004-05-01 00:00:00, 10 records, 8 cities
# examining wild_wild_west_marathon-2006-05-06 00:00:00, 6 records, 5 cities
# examining wild_wild_west_marathon-2008-05-03 00:00:00, 8 records, 4 cities
# examining wild_wild_west_marathon-2011-05-07 00:00:00, 9 records, 6 cities
# examining wild_wild_west_marathon-2013-05-04 00:00:00, 10 records, 7 cities
# examining wild_wild_west_marathon-2016-05-07 00:00:00, 9 records, 5 cities
# examining wild_wild_west_marathon-2017-05-06 00:00:00, 3 records, 2 cities
# examining wild_wild_west_marathon-2018-05-05 00:00:00, 9 records, 8 cities
# examining wild_wild_west_marathon-2019-05-04 00:00:00, 11 records, 6 cities
# examining wild_wild_west_marathon-2022-05-07 00:00:00, 13 records, 5 cities
# examining wildwood_marathon-2012-07-28 00:00:00, 31 records, 10 cities
# examining wildwood_marathon-2013-07-27 00:00:00, 40 records, 9 cities
# examining wildwood_trail_marathon-2018-12-02 00:00:00, 3 records, 3 cities
# examining wildwood_trail_marathon-2019-12-08 00:00:00, 4 records, 3 cities
# examining wildwood_trail_marathon-2020-12-06 00:00:00, 2 records, 1 cities
# examining wildwood_trail_marathon-2022-12-04 00:00:00, 2 records, 2 cities
# examining wildwood_trail_marathon-2023-12-02 00:00:00, 2 records, 2 cities
# examining wilmington_marathon-2019-03-09 00:00:00, 93 records, 16 cities
# examining wilmington_marathon-2021-04-17 00:00:00, 78 records, 21 cities
# examining wilmington_marathon-2022-02-26 00:00:00, 109 records, 22 cities
# examining wilmington_marathon-2023-02-25 00:00:00, 127 records, 23 cities
# examining windermere_marathon-2009-05-16 00:00:00, 12 records, 4 cities
# examining windermere_marathon-2010-05-15 00:00:00, 26 records, 11 cities
# examining windermere_marathon-2011-05-14 00:00:00, 21 records, 12 cities
# examining windermere_marathon-2012-05-19 00:00:00, 15 records, 11 cities
# examining windermere_marathon-2013-05-19 00:00:00, 20 records, 10 cities
# examining windermere_marathon-2020-09-06 00:00:00, 13 records, 5 cities
# examining windermere_marathon-2021-05-16 00:00:00, 23 records, 14 cities
# examining windermere_marathon-2022-05-15 00:00:00, 11 records, 5 cities
# examining windsor_marathon-2021-10-10 00:00:00, 2 records, 1 cities
# examining windsor_marathon-2022-10-09 00:00:00, 2 records, 2 cities
# examining windsor_marathon-2023-10-08 00:00:00, 3 records, 3 cities
# examining wineglass_marathon-2000-10-01 00:00:00, 26 records, 14 cities
# examining wineglass_marathon-2001-10-07 00:00:00, 34 records, 11 cities
# examining wineglass_marathon-2002-10-06 00:00:00, 40 records, 16 cities
# examining wineglass_marathon-2003-10-05 00:00:00, 14 records, 8 cities
# examining wineglass_marathon-2004-10-03 00:00:00, 16 records, 9 cities
# examining wineglass_marathon-2005-10-02 00:00:00, 21 records, 13 cities
# examining wineglass_marathon-2007-09-30 00:00:00, 26 records, 14 cities
# examining wineglass_marathon-2009-10-04 00:00:00, 53 records, 27 cities
# examining wineglass_marathon-2011-10-02 00:00:00, 105 records, 26 cities
# examining wineglass_marathon-2012-09-30 00:00:00, 144 records, 28 cities
# examining wineglass_marathon-2013-10-06 00:00:00, 182 records, 35 cities
# examining wineglass_marathon-2014-10-05 00:00:00, 204 records, 40 cities
# examining wineglass_marathon-2018-09-30 00:00:00, 192 records, 39 cities
# examining wineglass_marathon-2019-10-06 00:00:00, 172 records, 39 cities
# examining wineglass_marathon-2021-10-03 00:00:00, 145 records, 29 cities
# examining wineglass_marathon-2022-10-02 00:00:00, 144 records, 31 cities
# examining wineglass_marathon-2023-10-01 00:00:00, 183 records, 43 cities
# examining winthrop_road_marathon-2010-09-26 00:00:00, 13 records, 4 cities
# examining winthrop_road_marathon-2013-06-09 00:00:00, 50 records, 7 cities
# examining winthrop_road_marathon-2014-06-07 00:00:00, 15 records, 4 cities
# examining winthrop_road_marathon-2015-09-27 00:00:00, 4 records, 2 cities
# examining wisconsin_marathon-2010-05-01 00:00:00, 144 records, 14 cities
# examining wisconsin_marathon-2011-05-07 00:00:00, 161 records, 15 cities
# examining wisconsin_marathon-2012-05-05 00:00:00, 175 records, 12 cities
# examining wisconsin_marathon-2013-05-04 00:00:00, 201 records, 27 cities
# examining wisconsin_marathon-2014-05-03 00:00:00, 202 records, 24 cities
# examining wisconsin_marathon-2015-05-02 00:00:00, 164 records, 18 cities
# examining wisconsin_marathon-2016-05-07 00:00:00, 196 records, 19 cities
# examining wisconsin_marathon-2017-05-06 00:00:00, 132 records, 20 cities
# examining wisconsin_marathon-2018-05-05 00:00:00, 126 records, 24 cities
# examining wisconsin_marathon-2019-05-04 00:00:00, 110 records, 17 cities
# examining wisconsin_marathon-2022-05-07 00:00:00, 88 records, 18 cities
# examining wisconsin_marathon-2023-05-06 00:00:00, 64 records, 9 cities
# examining women_rock_marathon-2012-09-01 00:00:00, 36 records, 10 cities
# examining women_rock_marathon-2017-08-26 00:00:00, 4 records, 1 cities
# examining woolley_marathon-2012-02-18 00:00:00, 8 records, 2 cities
# examining wrightsville_beach_marathon-2010-03-21 00:00:00, 59 records, 10 cities
# examining wrightsville_beach_marathon-2011-03-20 00:00:00, 72 records, 13 cities
# examining wrightsville_beach_marathon-2012-03-18 00:00:00, 65 records, 13 cities
# examining wrightsville_beach_marathon-2013-03-17 00:00:00, 60 records, 8 cities
# examining wrightsville_beach_marathon-2014-03-16 00:00:00, 58 records, 15 cities
# examining wrightsville_beach_marathon-2015-03-22 00:00:00, 76 records, 15 cities
# examining wrightsville_beach_marathon-2016-03-20 00:00:00, 98 records, 15 cities
# examining wrightsville_beach_marathon-2017-03-25 00:00:00, 93 records, 24 cities
# examining wrightsville_beach_marathon-2018-03-17 00:00:00, 82 records, 20 cities
# examining wyoming_marathon-2000-05-28 00:00:00, 8 records, 8 cities
# examining wyoming_marathon-2001-05-27 00:00:00, 22 records, 8 cities
# examining wyoming_marathon-2004-05-30 00:00:00, 10 records, 9 cities
# examining wyoming_marathon-2005-05-29 00:00:00, 17 records, 10 cities
# examining wyoming_marathon-2006-05-28 00:00:00, 12 records, 8 cities
# examining wyoming_marathon-2007-05-27 00:00:00, 18 records, 11 cities
# examining wyoming_marathon-2009-05-24 00:00:00, 11 records, 9 cities
# examining wyoming_marathon-2010-05-30 00:00:00, 30 records, 8 cities
# examining wyoming_marathon-2011-05-29 00:00:00, 12 records, 7 cities
# examining wyoming_marathon-2012-05-27 00:00:00, 14 records, 10 cities
# examining wyoming_marathon-2013-05-26 00:00:00, 18 records, 14 cities
# examining wyoming_marathon-2014-05-25 00:00:00, 10 records, 5 cities
# examining wyoming_marathon-2015-05-24 00:00:00, 6 records, 4 cities
# examining x-country_marathon-2004-11-20 00:00:00, 3 records, 1 cities
# examining x-country_marathon-2005-11-19 00:00:00, 4 records, 1 cities
# examining x-country_marathon-2006-11-19 00:00:00, 3 records, 2 cities
# examining x-country_marathon-2007-11-18 00:00:00, 8 records, 2 cities
# examining x-country_marathon-2008-11-23 00:00:00, 1 records, 1 cities
# examining x-country_marathon-2009-11-22 00:00:00, 2 records, 2 cities
# examining x-country_marathon-2010-11-21 00:00:00, 10 records, 1 cities
# examining x-country_marathon-2011-11-20 00:00:00, 19 records, 4 cities
# examining x-country_marathon-2012-11-18 00:00:00, 12 records, 4 cities
# examining x-country_marathon-2014-11-16 00:00:00, 7 records, 2 cities
# examining x-country_marathon-2016-11-20 00:00:00, 2 records, 2 cities
# examining x-country_marathon-2018-11-25 00:00:00, 4 records, 2 cities
# examining xterra_marathon_of_trail_races-2013-09-22 00:00:00, 18 records, 4 cities
# examining xterra_thrill_in_the_hills_marathon_trail_run-2010-02-27 00:00:00, 15 records, 5 cities
# examining yakima_river_canyon_marathon-2001-03-31 00:00:00, 48 records, 11 cities
# examining yakima_river_canyon_marathon-2002-04-06 00:00:00, 69 records, 14 cities
# examining yakima_river_canyon_marathon-2003-04-05 00:00:00, 81 records, 13 cities
# examining yakima_river_canyon_marathon-2004-04-03 00:00:00, 48 records, 9 cities
# examining yakima_river_canyon_marathon-2005-04-02 00:00:00, 64 records, 12 cities
# examining yakima_river_canyon_marathon-2006-04-01 00:00:00, 56 records, 12 cities
# examining yakima_river_canyon_marathon-2007-03-31 00:00:00, 83 records, 15 cities
# examining yakima_river_canyon_marathon-2008-04-05 00:00:00, 75 records, 10 cities
# examining yakima_river_canyon_marathon-2009-04-04 00:00:00, 79 records, 11 cities
# examining yakima_river_canyon_marathon-2010-03-27 00:00:00, 111 records, 13 cities
# examining yakima_river_canyon_marathon-2011-04-02 00:00:00, 84 records, 12 cities
# examining yakima_river_canyon_marathon-2012-03-31 00:00:00, 94 records, 12 cities
# examining yakima_river_canyon_marathon-2013-04-06 00:00:00, 50 records, 9 cities
# examining yakima_river_canyon_marathon-2014-04-05 00:00:00, 61 records, 9 cities
# examining yakima_river_canyon_marathon-2015-03-28 00:00:00, 50 records, 8 cities
# examining yakima_river_canyon_marathon-2016-04-02 00:00:00, 64 records, 8 cities
# examining yakima_river_canyon_marathon-2017-04-01 00:00:00, 35 records, 10 cities
# examining yakima_river_canyon_marathon-2018-04-07 00:00:00, 37 records, 6 cities
# examining yakima_river_canyon_marathon-2019-03-30 00:00:00, 32 records, 8 cities
# examining yakima_river_canyon_marathon-2022-04-02 00:00:00, 33 records, 5 cities
# examining yakima_river_canyon_marathon-2023-04-01 00:00:00, 9 records, 6 cities
# examining yonkers_marathon-2000-09-17 00:00:00, 55 records, 5 cities
# examining yonkers_marathon-2004-09-19 00:00:00, 46 records, 3 cities
# examining yonkers_marathon-2005-09-18 00:00:00, 44 records, 3 cities
# examining yonkers_marathon-2006-09-17 00:00:00, 37 records, 3 cities
# examining yonkers_marathon-2007-09-16 00:00:00, 18 records, 3 cities
# examining yonkers_marathon-2008-09-21 00:00:00, 29 records, 3 cities
# examining yonkers_marathon-2009-09-20 00:00:00, 22 records, 5 cities
# examining yonkers_marathon-2010-09-19 00:00:00, 33 records, 4 cities
# examining yonkers_marathon-2011-09-18 00:00:00, 48 records, 7 cities
# examining yonkers_marathon-2012-09-16 00:00:00, 93 records, 8 cities
# examining yonkers_marathon-2013-09-29 00:00:00, 54 records, 5 cities
# examining yonkers_marathon-2014-09-28 00:00:00, 49 records, 3 cities
# examining yonkers_marathon-2015-10-18 00:00:00, 93 records, 3 cities
# examining yonkers_marathon-2018-10-21 00:00:00, 16 records, 2 cities
# examining yonkers_marathon-2019-10-20 00:00:00, 38 records, 4 cities
# examining york_marathon_and_half_marathon-2016-05-15 00:00:00, 3 records, 3 cities
# examining york_marathon_and_half_marathon-2017-05-14 00:00:00, 6 records, 4 cities
# examining york_marathon_and_half_marathon-2018-05-20 00:00:00, 11 records, 7 cities
# examining york_marathon_and_half_marathon-2019-05-19 00:00:00, 31 records, 13 cities
# examining york_marathon_and_half_marathon-2020-10-11 00:00:00, 6 records, 4 cities
# examining york_marathon_and_half_marathon-2021-05-16 00:00:00, 40 records, 13 cities
# examining york_marathon_and_half_marathon-2022-05-15 00:00:00, 22 records, 10 cities
# examining york_marathon_and_half_marathon-2023-05-07 00:00:00, 18 records, 5 cities
# examining youngstown_marathon-2018-06-03 00:00:00, 26 records, 6 cities
# examining youngstown_marathon-2019-10-27 00:00:00, 13 records, 5 cities
# examining youngstown_marathon-2021-10-24 00:00:00, 3 records, 2 cities
# examining youngstown_marathon-2022-10-23 00:00:00, 5 records, 3 cities
# examining yukon_do_it!_marathon-2018-12-30 00:00:00, 13 records, 6 cities
# examining yukon_do_it!_marathon-2019-12-29 00:00:00, 9 records, 4 cities
# examining yukon_do_it!_marathon-2021-12-18 00:00:00, 18 records, 6 cities
# examining yukon_river_trail_marathon-2007-08-05 00:00:00, 1 records, 1 cities
# examining yukon_river_trail_marathon-2008-08-03 00:00:00, 2 records, 1 cities
# examining yukon_river_trail_marathon-2011-08-07 00:00:00, 2 records, 1 cities
# examining yukon_river_trail_marathon-2012-08-05 00:00:00, 3 records, 2 cities
# examining yukon_river_trail_marathon-2013-08-04 00:00:00, 3 records, 3 cities
# examining yukon_river_trail_marathon-2014-08-03 00:00:00, 1 records, 1 cities
# examining yuma_territorial_marathon_and_half_marathon-2010-01-23 00:00:00, 5 records, 4 cities
# examining yuma_territorial_marathon_and_half_marathon-2011-01-29 00:00:00, 10 records, 6 cities
# examining yuma_territorial_marathon_and_half_marathon-2012-01-28 00:00:00, 10 records, 4 cities
# examining yuma_territorial_marathon_and_half_marathon-2013-01-26 00:00:00, 10 records, 5 cities
# examining yuma_territorial_marathon_and_half_marathon-2014-01-25 00:00:00, 4 records, 3 cities
# examining yuma_territorial_marathon_and_half_marathon-2015-01-31 00:00:00, 7 records, 5 cities
# examining yuma_territorial_marathon_and_half_marathon-2016-01-30 00:00:00, 5 records, 2 cities
# examining yuma_territorial_marathon_and_half_marathon-2017-01-28 00:00:00, 10 records, 8 cities
# examining yuma_territorial_marathon_and_half_marathon-2018-01-28 00:00:00, 4 records, 4 cities
# examining yuma_territorial_marathon_and_half_marathon-2019-01-26 00:00:00, 4 records, 3 cities
# examining yuma_territorial_marathon_and_half_marathon-2020-01-25 00:00:00, 3 records, 3 cities
# examining yuma_territorial_marathon_and_half_marathon-2021-01-30 00:00:00, 16 records, 7 cities
# examining yuma_territorial_marathon_and_half_marathon-2022-01-29 00:00:00, 3 records, 3 cities
# examining yuma_territorial_marathon_and_half_marathon-2023-01-28 00:00:00, 2 records, 2 cities
# examining zoom!_yah!_yah!_indoor_marathon-2007-01-14 00:00:00, 1 records, 1 cities
# examining zoom!_yah!_yah!_indoor_marathon-2009-01-11 00:00:00, 3 records, 2 cities
# examining zoom!_yah!_yah!_indoor_marathon-2010-01-10 00:00:00, 4 records, 3 cities
# examining zoom!_yah!_yah!_indoor_marathon-2011-01-09 00:00:00, 5 records, 4 cities
# examining zoom!_yah!_yah!_indoor_marathon-2012-01-08 00:00:00, 5 records, 5 cities
# examining zoom!_yah!_yah!_indoor_marathon-2013-01-06 00:00:00, 6 records, 3 cities
# examining zoom!_yah!_yah!_indoor_marathon-2014-01-12 00:00:00, 2 records, 2 cities
# examining zoom!_yah!_yah!_indoor_marathon-2015-01-11 00:00:00, 5 records, 4 cities
# examining zoom!_yah!_yah!_indoor_marathon-2016-01-10 00:00:00, 1 records, 1 cities
# examining zoom!_yah!_yah!_indoor_marathon-2017-01-08 00:00:00, 6 records, 5 cities
# examining zoom!_yah!_yah!_indoor_marathon-2018-01-07 00:00:00, 5 records, 3 cities
# examining zoom!_yah!_yah!_indoor_marathon-2019-01-06 00:00:00, 3 records, 2 cities
# examining zoom!_yah!_yah!_indoor_marathon-2020-01-05 00:00:00, 2 records, 2 cities
# examining zoombierunner_halloween_marathon-2023-10-29 00:00:00, 13 records, 4 cities
# examining zydeco_marathon-2014-03-30 00:00:00, 32 records, 10 cities
# examining zydeco_marathon-2015-03-08 00:00:00, 13 records, 5 cities
# examining zydeco_marathon-2016-03-13 00:00:00, 21 records, 11 cities
# examining zydeco_marathon-2017-03-12 00:00:00, 21 records, 9 cities
# examining zydeco_marathon-2018-03-04 00:00:00, 21 records, 10 cities
# examining zydeco_marathon-2019-03-10 00:00:00, 12 records, 8 cities
# examining zydeco_marathon-2020-03-08 00:00:00, 12 records, 7 cities
# examining zydeco_marathon-2021-03-14 00:00:00, 18 records, 5 cities
# examining zydeco_marathon-2022-03-13 00:00:00, 21 records, 12 cities
# examining zydeco_marathon-2023-03-12 00:00:00, 21 records, 8 cities

# %%
featurized_frame.to_csv("data/featurized_race_data_v2.csv", index=False)

# %%
missing_cities = race_cities_df[~race_cities_df.city.isin(merged.city)]

mapped_amount = race_cities_df.runner_count.sum() / (missing_cities.runner_count.sum() + race_cities_df.runner_count.sum())
print(f"Mapped: {race_cities_df.runner_count.sum()}")
print(f"Unmapped: {missing_cities.runner_count.sum()}")
print(f"Coverage: {mapped_amount*100:>11.2f}%")
# Out:
# Mapped: 3711663
# Unmapped: 284532
# Coverage:       92.88%

# %%
import pandas as pd
import requests
from time import sleep
from tqdm.notebook import tqdm
from pathlib import Path

def get_historical_weather(lat, lon, start_date, end_date):
    """Fetch daily weather from Open-Meteo archive API."""
    url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
        "latitude": lat,
        "longitude": lon,
        "start_date": start_date,
        "end_date": end_date,
        "daily": ["temperature_2m_max", "temperature_2m_min", "precipitation_sum"],
        "temperature_unit": "fahrenheit",
        "timezone": "auto"
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()
    return None

def fetch_weather_for_cities(df, start_date, end_date, output_path="data/weather_data.csv", save_every=10):
    """
    Fetch weather for all cities, with progress bar and checkpoint saving.
    
    Args:
        df: DataFrame with city, state, lat, lng columns
        start_date: Start date string "YYYY-MM-DD"
        end_date: End date string "YYYY-MM-DD"
        output_path: Where to save intermediate/final results
        save_every: Save checkpoint every N cities
    """
    output_path = Path(output_path)
    
    # Load existing results if resuming
    if output_path.exists():
        existing_df = pd.read_csv(output_path)
        completed = set(zip(existing_df['city'], existing_df['state']))
        weather_records = existing_df.to_dict('records')
        print(f"Resuming: found {len(completed)} cities already processed")
    else:
        completed = set()
        weather_records = []
    
    # Filter to only cities we haven't done yet
    remaining = df[~df.apply(lambda r: (r['city'], r['state']) in completed, axis=1)]
    
    if len(remaining) == 0:
        print("All cities already processed!")
        return pd.read_csv(output_path)
    
    print(f"Fetching weather for {len(remaining)} cities...")
    
    for i, (idx, row) in enumerate(tqdm(remaining.iterrows(), total=len(remaining), desc="Fetching weather")):
        try:
            data = get_historical_weather(row['lat'], row['lng'], start_date, end_date)
            
            if data and 'daily' in data:
                daily = data['daily']
                for j, date in enumerate(daily['time']):
                    weather_records.append({
                        'city': row['city'],
                        'state': row['state'],
                        'date': date,
                        'temp_max': daily['temperature_2m_max'][j],
                        'temp_min': daily['temperature_2m_min'][j],
                        'precip': daily['precipitation_sum'][j]
                    })
            
            # Save checkpoint periodically
            if (i + 1) % save_every == 0:
                pd.DataFrame(weather_records).to_csv(output_path, index=False)
                
        except Exception as e:
            tqdm.write(f"Error fetching {row['city']}, {row['state']}: {e}")
        
        sleep(0.1)
    
    # Final save
    result_df = pd.DataFrame(weather_records)
    result_df.to_csv(output_path, index=False)
    print(f"Saved {len(result_df)} records to {output_path}")
    
    return result_df

# %%
# Fetch weather data (can be interrupted and resumed)
weather_df = fetch_weather_for_cities(
    merged, 
    "2015-01-01", 
    "2025-03-01",
    output_path="data/weather_data.csv",
    save_every=10
)
weather_df.head()
# Out:
# Resuming: found 32 cities already processed
# Fetching weather for 458 cities...
# Fetching weather:   0%|          | 0/458 [00:00<?, ?it/s]
# Saved 233919 records to data/weather_data.csv
#           city state        date  temp_max  temp_min  precip
# 0  los angeles    ca  2015-01-01      53.1      30.8     0.0
# 1  los angeles    ca  2015-01-02      55.0      31.5     0.0
# 2  los angeles    ca  2015-01-03      55.5      31.5     0.0
# 3  los angeles    ca  2015-01-04      64.3      33.8     0.0
# 4  los angeles    ca  2015-01-05      73.1      41.5     0.0
